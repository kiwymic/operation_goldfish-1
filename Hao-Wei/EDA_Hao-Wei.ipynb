# %%
import numpy as np
import pandas as pd
# %matplotlib inline 

import numpy as np
import pandas as pd
import plotly.express as px
from scipy import stats

# housing = pd.read_csv("C:/Users/kiwym/operation_goldfish/data", index_col=0)
# housing = pd.read_csv("C:/Users/kiwym/operation_goldfish/data/Ames_Housing_Price_Data_raw.csv", index_col=0);
housing = pd.read_csv("../data/Ames_Housing_Price_Data_raw.csv", index_col=0);
housing.shape
# Out:
# (2580, 81)

# %%
housing.head()
# Out:
#          PID  GrLivArea  SalePrice  MSSubClass MSZoning  LotFrontage  LotArea  \
# 1  909176150        856     126000          30       RL          NaN     7890
# 2  905476230       1049     139500         120       RL         42.0     4235
# 3  911128020       1001     124900          30  C (all)         60.0     6060
# 4  535377150       1039     114000          70       RL         80.0     8146
# 5  534177230       1665     227000          60       RL         70.0     8400
#
#   Street Alley LotShape  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 1   Pave   NaN      Reg  ...         166        0    NaN   NaN         NaN
# 2   Pave   NaN      Reg  ...           0        0    NaN   NaN         NaN
# 3   Pave   NaN      Reg  ...           0        0    NaN   NaN         NaN
# 4   Pave   NaN      Reg  ...         111        0    NaN   NaN         NaN
# 5   Pave   NaN      Reg  ...           0        0    NaN   NaN         NaN
#
# ...

# %%
from matplotlib import pyplot as plt;
plt.style.use('ggplot');

# Create a function which creates the relation between a categorical variable and the box plot
# As a remark, SalePrice is the target.
def category_box(df, cat="LotShape"):
    '''
    Enter the data frame and the name of a categorical variable, return a box plot between the categorical
    variable and the SalePrice.
    Input variables:
    df: the data frame. Usually just Ames_Housing_Price_Data_raw or something derived from it.
    cat: a string which is a column in df. It's the user's responsibility to make sure it is categorical.
    '''
    if cat not in df.columns:
        raise ValueError("No such column!");
    housing.boxplot(by = cat, column = "SalePrice");
    return;

# %%
category_box(housing)
