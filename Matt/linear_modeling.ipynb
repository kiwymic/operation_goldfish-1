# %%
import numpy as np
import pandas as pd
from scipy import stats
from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression
import plotly.express as px
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.model_selection import cross_val_score
import time
import re
from datetime import datetime
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
pd.set_option('display.max_rows', 500)

# %%
def dummify_linear(data, to_dummify, drops):
    
    bsmt_categoricals = [
        'BsmtCond_ord',
        'BsmtQual_ord',
        'BsmtExposure_ord']
    
    grg_categoricals = [ 
        'GarageQual',
        'GarageCond',
        'GarageType_com',
        'Garage_age_bin',
        'GarageFinish']
    
    dummies = to_dummify
        
    for item in drops:
        if item in grg_categoricals:
            grg_categoricals.remove(item)      
        if item in dummies:
            dummies.remove(item)
        if item in bsmt_categoricals:
            bsmt_categoricals.remove(item)
    
    df = data.drop(columns = drops, axis = 1)
    print('before dummifying: ', df.shape)
    df = pd.get_dummies(df, columns = grg_categoricals)
    for col in grg_categoricals:
        if f'{col}_0' in df.columns:
            df = df.drop(columns = [f'{col}_0'], axis = 1)
        if f'{col}_No garage' in df.columns:
            df = df.drop(columns = [f'{col}_No garage'], axis = 1)
    print('after garage stuff: ', df.shape)     
    df = pd.get_dummies(df, columns = bsmt_categoricals)
    for col in bsmt_categoricals:
        if f'{col}_0' in df.columns:
            df = df.drop(columns = [f'{col}_0'], axis = 1)
    print('after basement stuff: ', df.shape)
    
    df = pd.get_dummies(df, columns = to_dummify, drop_first = True)
    print('after full dummification: ', df.shape)
    
    return df

# %%
def drop_dummies(dummified, orig_col):
    keep_list = []
    for col in dummified.columns:
        if not f'{orig_col}_' in col:
            keep_list.append(col)
    return dummified.loc[:, keep_list]

# %%
df = pd.read_csv('./../data/ames_housing_price_data_v5.csv')
df = df[(df['PID'] != 902207130) & (df['PID'] != 908154205)]
df = df[(df['SaleCondition'] == 'Normal') | (df['SaleCondition'] == 'Partial')]
df = df[df['BedroomAbvGr'] != 0]
df = df[df['MSZoning_com'] != 'Nonresidential']
df.reset_index(drop=True, inplace = True)

price = df.loc[:,'SalePrice']
price_log = df.loc[:,'SalePrice_log']

# %%
df['PID']
# Out:
# 0       909176150
# 1       905476230
# 2       535377150
# 3       534177230
# 4       908128060
#           ...
# 2466    903205040
# 2467    905402060
# 2468    909275030
# 2469    907192040
# 2470    906223180
# Name: PID, Length: 2471, dtype: int64

# %%
all_dummies = to_dummify + garage_categoricals + basement_categoricals

# %%
df2 = df.drop(columns = always_drop, axis = 1)
kfold = KFold(n_splits=5, shuffle = True, random_state = 1)

# %%
# kfold = KFold(n_splits=5, shuffle = True, random_state = 1)
# folds = list(kfold.split(df3))
# xtrain = [0]*5
# ytrain = [0]*5
# xtest = [0]*5
# ytest = [0]*5
# for i in range(0,5):
#     xtrain[i] = df3.loc[folds[i][0],:].drop(columns = 'SalePrice_log')
#     ytrain[i] = df3.loc[folds[i][0],'SalePrice_log']
#     xtest[i] = df3.loc[folds[i][1],:].drop(columns = 'SalePrice_log')
#     ytest[i] = df3.loc[folds[i][1],'SalePrice_log']

# feature_selection_df = df2.drop(columns = ['SalePrice_log'], axis = 1)
# score_dict_total={}
# col_dict_total2={}
# j=1
# xtrain_red = xtrain.copy()
# xtest_red = xtest.copy()
# start = datetime.now()
# while len(feature_selection_df.columns)> 50:
#     score_dict={}
#     for col in feature_selection_df.columns:
#         if col in all_dummies:
#             xtrain_red = list(map(lambda x: drop_dummies(x, col), xtrain))
#             xtest_red = list(map(lambda x: drop_dummies(x, col), xtest))
#         else:
#             xtrain_red = list(map(lambda x: x.drop(col, axis = 1), xtrain))
#             xtest_red = list(map(lambda x: x.drop(col, axis = 1), xtest))
            
#         #adjust these lines to reflect your model
#         models = list(map(lambda x, y: Lasso(alpha = 1e-6, normalize = True, max_iter = 1000, tol = 0.001).fit(x, y), xtrain, ytrain))
#         scores = list(map(lambda x, y, z: x.score(y, z), models, xtest, ytest))
#         score_dict[col] = np.mean(scores)
#         #-------

#     min_col=max(score_dict.items(), key=lambda x: x[1])[0]
#     score_dict_total[j]=max(score_dict.items(), key=lambda x: x[1])[1]
#     col_dict_total2[j]=min_col
#     feature_selection_df = feature_selection_df.drop(min_col, axis=1)
#     if min_col in all_dummies:
#         xtrain = list(map(lambda x: drop_dummies(x, min_col), xtrain))
#         xtest = list(map(lambda x: drop_dummies(x, min_col), xtest))
#     else:
#         xtrain = list(map(lambda x: x.drop(min_col, axis = 1), xtrain))
#         xtest = list(map(lambda x: x.drop(min_col, axis = 1), xtest))
#     print(f'{j} columns removed: {min_col}, best score is {score_dict_total[j]}; time elapsed is {datetime.now()-start}')
#     j+=1

# %%
# col_dict_total2

# %%
# folds = list(kfold.split(df3))
# xtrain = [0]*5
# ytrain = [0]*5
# xtest = [0]*5
# ytest = [0]*5
# for i in range(0,5):
#     xtrain[i] = df3.loc[folds[i][0],:].drop(columns = 'SalePrice_log')
#     ytrain[i] = df3.loc[folds[i][0],'SalePrice_log']
#     xtest[i] = df3.loc[folds[i][1],:].drop(columns = 'SalePrice_log')
#     ytest[i] = df3.loc[folds[i][1],'SalePrice_log']

# feature_selection_df = df2.drop(columns = ['SalePrice_log'], axis = 1)
# score_dict_total={}
# col_dict_total_neighborhood={}
# j=1
# xtrain_red = xtrain.copy()
# xtest_red = xtest.copy()
# start = datetime.now()
# while len(feature_selection_df.columns)> 50:
#     score_dict={}
#     for col in feature_selection_df.columns:
#         if col in all_dummies:
#             xtrain_red = list(map(lambda x: drop_dummies(x, col), xtrain))
#             xtest_red = list(map(lambda x: drop_dummies(x, col), xtest))
#         else:
#             xtrain_red = list(map(lambda x: x.drop(col, axis = 1), xtrain))
#             xtest_red = list(map(lambda x: x.drop(col, axis = 1), xtest))
            
#         #adjust these lines to reflect your model
#         models = list(map(lambda x, y: Lasso(alpha = 1e-6, normalize = True, max_iter = 1000, tol = 0.001).fit(x, y), xtrain, ytrain))
#         scores = list(map(lambda x, y, z: x.score(y, z), models, xtest, ytest))
#         score_dict[col] = np.mean(scores)
#         #-------

#     min_col=max(score_dict.items(), key=lambda x: x[1])[0]
#     score_dict_total[j]=max(score_dict.items(), key=lambda x: x[1])[1]
#     col_dict_total_neighborhood[j]=min_col
#     feature_selection_df = feature_selection_df.drop(min_col, axis=1)
#     if min_col in all_dummies:
#         xtrain = list(map(lambda x: drop_dummies(x, min_col), xtrain))
#         xtest = list(map(lambda x: drop_dummies(x, min_col), xtest))
#     else:
#         xtrain = list(map(lambda x: x.drop(min_col, axis = 1), xtrain))
#         xtest = list(map(lambda x: x.drop(min_col, axis = 1), xtest))
#     print(f'{j} columns removed: {min_col}, best score is {score_dict_total[j]}; time elapsed is {datetime.now()-start}')
#     j+=1

# %%
# col_dict_total_neighborhood

# %%
# score_dict_total

# %%
# train, test = train_test_split(df3, test_size = 0.2, shuffle = True, random_state = 0)
# x_train = train.drop(columns = 'SalePrice_log')
# x_test = test.drop(columns = 'SalePrice_log')
# y_train = train['SalePrice_log']
# y_test = test['SalePrice_log']

# %%
# x_train2, x_test2, y_train2, y_test2 = x_train.copy(), x_test.copy(), y_train.copy(), y_test.copy()
# feature_selection_df = df2.drop(columns = ['SalePrice_log'], axis = 1)
# score_dict_total={}
# col_dict_total={}
# j=1
# start = datetime.now()
# while len(feature_selection_df.columns)> 20:
#     score_dict={}
#     for col in feature_selection_df.columns:
#         if col in all_dummies:
#             x_train_red = drop_dummies(x_train2, col)
#             x_test_red = drop_dummies(x_test2, col)
#         else:
#             x_train_red = x_train2.drop(col, axis = 1)
#             x_test_red = x_test2.drop(col, axis = 1)
#         #adjust these lines to reflect your model
#         model = Lasso(alpha = 1e-6, normalize = True, max_iter = 1000, tol = 0.001).fit(x_train_red, y_train2)
#         score=model.score(x_test_red, y_test2)
#         score_dict[col]=score
#         #-------

#     min_col=max(score_dict.items(), key=lambda x: x[1])[0]
#     score_dict_total[j]=max(score_dict.items(), key=lambda x: x[1])[1]
#     col_dict_total[j]=min_col
#     feature_selection_df = feature_selection_df.drop(min_col,axis=1)
#     if min_col in all_dummies:
#         x_train2 = drop_dummies(x_train2, min_col)
#         x_test2 = drop_dummies(x_test2, min_col)
#     else:
#         x_train2 = x_train2.drop(min_col, axis = 1)
#         x_test2 = x_test2.drop(min_col, axis = 1)
#     print(f'{j} columns removed: {min_col}, best score is {score_dict_total[j]}; time elapsed is {datetime.now()-start}')
#     j+=1

# %%
droplist = ['TotalBsmtSF',
            'BsmtCond_ord',
            'BsmtQual_ord',
            'GarageCond',
            'GarageQual',
            'GarageType_com',
            'SalePrice_log',
            'Garage_age_bin',
            'Remod_age_bin',
            '1stFlrSF_log',
            '2ndFlrSF',
            'KitchenAbvGr',
            'TotRmsAbvGrd',
            'GarageArea',
            'GarageFinish',
            'Fence',
            'Alley',
            'number_floors',
            'FireplaceQu',
            'LotFrontage',
            'LowQualFinSF',
            'BsmtExposure_ord',
            'MasVnrArea'
           ]

droplist3 = ['SalePrice_log']

# %%
df3 = dummify_linear(df2, to_dummify, droplist)
# Out:
# before dummifying:  (2471, 58)
# after garage stuff:  (2471, 58)
# after basement stuff:  (2471, 58)
# after full dummification:  (2471, 124)

# %%
params_log = {'alpha' : [1e-7, 1e-6, 1e-5, 1e-4]
          }

# %%
lasso2 = Lasso(normalize = True, max_iter = 1000, tol = 0.001)
lasso_tuner2 = GridSearchCV(lasso2, params_log, cv=kfold, return_train_score = True)
lasso_tuner2.fit(df3, price_log)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=Lasso(normalize=True, tol=0.001),
#              param_grid={'alpha': [1e-07, 1e-06, 1e-05, 0.0001]},
#              return_train_score=True)

# %%
#lasso_tuner2.cv_results_

# %%
lasso_tuner2.cv_results_['mean_test_score']
# Out:
# array([0.94744747, 0.94757162, 0.94470538, 0.91400025])

# %%
lasso_tuner2.cv_results_['mean_train_score']
# Out:
# array([0.95496864, 0.95486537, 0.95097223, 0.91901587])

# %%
feat_imp_log = pd.Series(data = lasso_tuner2.best_estimator_.coef_, index = df3.columns)
feat_imp_log = feat_imp_log.sort_values(ascending = False)
ignored_log = feat_imp_log[feat_imp_log == 0]
feat_imp_log = feat_imp_log[feat_imp_log != 0]
print(len(feat_imp_log))
print(feat_imp_log)
print(len(ignored_log))
print(ignored_log)
# Out:
# 118
# GrLivArea_log                                                 0.424990
# OverallQual_10                                                0.184668
# Neighborhood_GrnHill                                          0.181966
# OverallQual_9                                                 0.152077
# OverallCond_9                                                 0.135713
# OverallCond_8                                                 0.120620
# OverallCond_7                                                 0.108497
# OverallQual_8                                                 0.105630
# LotArea_log                                                   0.098563
# OverallCond_6                                                 0.084857
# OverallQual_7                                                 0.074798
# OverallCond_5                                                 0.068410
# Functional_ord_7                                              0.067255
# OverallQual_6                                                 0.055466
# Functional_ord_5                                              0.046094
# OverallCond_4                                                 0.043038
# OverallQual_5                                                 0.042903
# Functional_ord_6                                              0.041775
# Neighborhood_Greens                                           0.036982
# Functional_ord_4                                              0.036547
# Neighborhood_Crawfor                                          0.033575
# ext_Brick                                                     0.029227
# Neighborhood_StoneBr                                          0.025908
# OverallQual_4                                                 0.023852
# attic_Unfinished                                              0.022878
# Heating_com_Gas-powered water/steam heating                   0.019951
# KitchenQual_5                                                 0.019160
# LotConfig_com_Cul-de-sac lot                                  0.018546
# CentralAir_Y                                                  0.018346
# LotConfig_com_Inside lot (1 side frontage)                    0.017792
# GarageCars                                                    0.017394
# Neighborhood_Somerst                                          0.016639
# ext_Stucco                                                    0.016140
# HeatingQC_ord_5                                               0.015732
# Pool                                                          0.014753
# Neighborhood_Blueste                                          0.014646
# MSZoning_com_Residential, village                             0.014438
# LotConfig_com_Corner lot                                      0.014129
# LandContour_Hillside (downward slope on both sides)           0.013065
# ExterQual_5                                                   0.012337
# MSZoning_com_Residential, low density                         0.011718
# PavedDrive_Paved                                              0.011575
# HeatingQC_ord_4                                               0.011022
# Neighborhood_BrkSide                                          0.009802
# Fireplaces                                                    0.009399
# Neighborhood_ClearCr                                          0.008967
# Foundation_PConc                                              0.008614
# Neighborhood_NridgHt                                          0.008547
# BsmtFullBath                                                  0.008485
# Neighborhood_NoRidge                                          0.008263
# Electrical_com_Standard circuit breakers, all Romex wiring    0.008251
# KitchenQual_4                                                 0.007544
# RoofStyle_Other                                               0.007334
# attic_No attic                                                0.006461
# HeatingQC_ord_3                                               0.006291
# FullBath                                                      0.005859
# ExterCond_3                                                   0.005490
# ExterCond_4                                                   0.005370
# ext_Other                                                     0.005184
# LandContour_Level                                             0.005127
# LandSlope_Moderate-severe                                     0.005111
# BsmtHalfBath                                                  0.004753
# Foundation_CBlock                                             0.004745
# ext_Cement_Board                                              0.004303
# ext_Vinyl_Siding                                              0.004058
# Electrical_com_>60 Amp fuse box, all Romex wiring             0.003518
# HalfBath                                                      0.002617
# MasVnrType_Stone                                              0.002487
# LF_Near_Positive_Feature                                      0.001891
# ExterQual_4                                                   0.001878
# LotShape_com_Regular                                          0.000547
# ScreenPorch                                                   0.000083
# BSMT_GLQ                                                      0.000079
# BSMT_ALQ                                                      0.000067
# BSMT_BLQ                                                      0.000057
# 3SsnPorch                                                     0.000043
# BSMT_Rec                                                      0.000041
# EnclosedPorch                                                 0.000040
# OpenPorchSF                                                   0.000038
# BsmtUnfSF                                                     0.000035
# BSMT_LwQ                                                      0.000034
# WoodDeckSF                                                    0.000023
# Foundation_Other                                             -0.000069
# LandContour_Depression (upward slope on both sides)          -0.000135
# Heating_com_Other                                            -0.000382
# ext_Metal_Siding                                             -0.000927
# house_age_years                                              -0.001029
# LotShape_com_Slightly irregular                              -0.001134
# ext_Wood                                                     -0.001629
# RoofStyle_Hip                                                -0.001824
# PavedDrive_Partial Pavement                                  -0.002081
# BedroomAbvGr                                                 -0.003389
# MasVnrType_None                                              -0.003533
# Neighborhood_Sawyer                                          -0.008116
# Neighborhood_SWISU                                           -0.008392
# Neighborhood_BrDale                                          -0.008425
# Neighborhood_IDOTRR                                          -0.008705
# Neighborhood_Veenker                                         -0.009006
# Neighborhood_NPkVill                                         -0.010249
# Neighborhood_Timber                                          -0.011381
# BldgType_Twnhs                                               -0.012058
# LF_Near_NS_RR                                                -0.014661
# Neighborhood_NAmes                                           -0.015063
# Neighborhood_CollgCr                                         -0.015620
# BldgType_2fmCon                                              -0.015920
# Neighborhood_OldTown                                         -0.016151
# Neighborhood_Landmrk                                         -0.017450
# Neighborhood_Mitchel                                         -0.017561
# LF_Adjacent_Feeder_St                                        -0.018871
# Neighborhood_Gilbert                                         -0.019356
# ext_Asbestos_Shingles                                        -0.022362
# Neighborhood_SawyerW                                         -0.025791
# Neighborhood_NWAmes                                          -0.025922
# Neighborhood_Edwards                                         -0.028771
# LF_Near_EW_RR                                                -0.028861
# LF_Adjacent_Arterial_St                                      -0.029329
# BldgType_Duplex                                              -0.043363
# Neighborhood_MeadowV                                         -0.046943
# dtype: float64
# 6
# PUD_1                                      -0.0
# KitchenQual_3                              -0.0
# ExterQual_3                                 0.0
# BldgType_TwnhsE                             0.0
# MSZoning_com_Residential, medium density   -0.0
# ExterCond_5                                -0.0
# dtype: float64

# %%
# preds_log = lasso_tuner2.predict(df4)

# fig = px.scatter(x = preds_log, y = price_log, hover_name = df['PID'])
# fig.update_layout(
#                     xaxis_title = 'predicted',
#                     yaxis_title = 'actual'
#                 )

# %%
# resid = abs(preds_log - price_log)

# fig = px.histogram(x = resid)
# fig.update_layout(
#                     xaxis_title = 'residuals'
#                 )

# %%
# 10**np.mean(price_log)*(1-lasso_tuner2.best_score_)

# %%
df4 = dummify_linear(df2, to_dummify, droplist)
# Out:
# before dummifying:  (2471, 58)
# after garage stuff:  (2471, 58)
# after basement stuff:  (2471, 58)
# after full dummification:  (2471, 124)

# %%
vif_df = pd.DataFrame()
vif_df['feature'] = df4.columns
vif_df['vif'] = [variance_inflation_factor(df4.values, i)
                          for i in range(len(df4.columns))]

# %%
vif_df.sort_values(by = 'vif', ascending = False)
# Out:
#                                                feature          vif
# 32                                       GrLivArea_log  1778.268217
# 18                                         LotArea_log  1091.801677
# 107              MSZoning_com_Residential, low density   110.706511
# 123                                   Functional_ord_7   107.267290
# 87                                         ExterQual_3    86.996665
# 119                                              PUD_1    69.835688
# 113  Electrical_com_Standard circuit breakers, all ...    68.648088
# 90                                         ExterCond_3    59.048342
# 88                                         ExterQual_4    50.074533
# 69                                     BldgType_TwnhsE    45.904481
# 78                                       OverallCond_5    44.421623
# 37                                   LandContour_Level    33.203678
# 96                                        CentralAir_Y    33.009423
# 5                                         BedroomAbvGr    31.123316
# 3                                             FullBath    28.671673
# 71                                       OverallQual_5    27.613575
# 108           MSZoning_com_Residential, medium density    27.401426
# 97                                       KitchenQual_3    27.011502
# 72                                       OverallQual_6    26.652020
# 53                                  Neighborhood_NAmes    26.064568
# 33                                     house_age_years    25.801324
# 105                               LotShape_com_Regular    24.920581
# 104                                    HeatingQC_ord_5    24.470880
# 116         LotConfig_com_Inside lot (1 side frontage)    24.432304
# 98                                       KitchenQual_4    24.181157
# 101                                   PavedDrive_Paved    23.628788
# 68                                      BldgType_Twnhs    23.454968
# 73                                       OverallQual_7    23.399429
# 58                                Neighborhood_OldTown    18.168918
# 19                                            ext_Wood    16.998720
# 79                                       OverallCond_6    16.083892
# 21                                    ext_Vinyl_Siding    15.456636
# 7                                           GarageCars    14.911066
# 74                                       OverallQual_8    14.734789
# 43                                Neighborhood_CollgCr    13.888621
# 117                                     attic_No attic    13.664669
# 62                                Neighborhood_Somerst    13.191748
# 102                                    HeatingQC_ord_3    12.939039
# 106                    LotShape_com_Slightly irregular    12.644549
# 80                                       OverallCond_7    12.533833
# 95                                    Foundation_PConc    12.148272
# 109                  MSZoning_com_Residential, village    11.628583
# 45                                Neighborhood_Edwards    10.866360
# 93                                   Foundation_CBlock     9.844073
# 60                                 Neighborhood_Sawyer     9.539079
# 46                                Neighborhood_Gilbert     9.325569
# 0                                            BsmtUnfSF     8.473252
# 91                                         ExterCond_4     8.420503
# 41                                Neighborhood_BrkSide     8.349416
# 55                                 Neighborhood_NWAmes     8.293608
# 103                                    HeatingQC_ord_4     8.269841
# 57                                Neighborhood_NridgHt     7.931197
# 20                                    ext_Metal_Siding     7.300799
# 61                                Neighborhood_SawyerW     7.155869
# 70                                       OverallQual_4     7.032416
# 52                                Neighborhood_Mitchel     7.017746
# 44                                Neighborhood_Crawfor     6.920206
# 89                                         ExterQual_5     6.678740
# 27                                            BSMT_GLQ     6.580366
# 114                           LotConfig_com_Corner lot     6.449935
# 75                                       OverallQual_9     5.994426
# 49                                 Neighborhood_IDOTRR     5.846973
# 81                                       OverallCond_8     5.838611
# 99                                       KitchenQual_5     5.454442
# 112  Electrical_com_>60 Amp fuse box, all Romex wiring     5.278743
# 56                                Neighborhood_NoRidge     5.040394
# 85                                     MasVnrType_None     4.667661
# 51                                Neighborhood_MeadowV     4.356848
# 64                                 Neighborhood_Timber     4.114744
# 1                                         BsmtFullBath     4.012259
# 121                                   Functional_ord_5     3.991871
# 59                                  Neighborhood_SWISU     3.722984
# 122                                   Functional_ord_6     3.614280
# 63                                Neighborhood_StoneBr     3.585588
# 42                                Neighborhood_ClearCr     3.448062
# 23                                    ext_Cement_Board     3.400332
# 77                                       OverallCond_4     3.287924
# 115                       LotConfig_com_Cul-de-sac lot     3.220473
# 4                                             HalfBath     3.214204
# 6                                           Fireplaces     3.205749
# 40                                 Neighborhood_BrDale     3.116988
# 28                                            BSMT_ALQ     2.896273
# 82                                       OverallCond_9     2.750519
# 76                                      OverallQual_10     2.632377
# 54                                Neighborhood_NPkVill     2.618957
# 36   LandContour_Hillside (downward slope on both s...     2.449922
# 120                                   Functional_ord_4     2.430477
# 65                                Neighborhood_Veenker     2.373471
# 8                                           WoodDeckSF     2.037607
# 9                                          OpenPorchSF     1.995223
# 29                                            BSMT_BLQ     1.983520
# 24                                           ext_Brick     1.923533
# 35   LandContour_Depression (upward slope on both s...     1.918831
# 31                                            BSMT_Rec     1.828084
# 39                                Neighborhood_Blueste     1.781272
# 38                           LandSlope_Moderate-severe     1.736445
# 94                                    Foundation_Other     1.709766
# 83                                       RoofStyle_Hip     1.621754
# 47                                 Neighborhood_Greens     1.616421
# 92                                         ExterCond_5     1.559709
# 86                                    MasVnrType_Stone     1.554853
# 67                                     BldgType_Duplex     1.541015
# 100                        PavedDrive_Partial Pavement     1.521398
# 22                                          ext_Stucco     1.502518
# 10                                       EnclosedPorch     1.485428
# 25                               ext_Asbestos_Shingles     1.452318
# 30                                            BSMT_LwQ     1.365772
# 111                                  Heating_com_Other     1.355476
# 2                                         BsmtHalfBath     1.295455
# 66                                     BldgType_2fmCon     1.287793
# 118                                   attic_Unfinished     1.276858
# 12                                         ScreenPorch     1.259163
# 17                               LF_Adjacent_Feeder_St     1.256839
# 110        Heating_com_Gas-powered water/steam heating     1.249489
# 15                             LF_Adjacent_Arterial_St     1.216035
# 13                                       LF_Near_NS_RR     1.207883
# 14                            LF_Near_Positive_Feature     1.176044
# 16                                       LF_Near_EW_RR     1.175385
# 26                                           ext_Other     1.171484
# 48                                Neighborhood_GrnHill     1.171060
# 84                                     RoofStyle_Other     1.161057
# 50                                Neighborhood_Landmrk     1.141944
# 34                                                Pool     1.113188
# 11                                           3SsnPorch     1.067969

# %%
print('No radials: ', droplist, ': ', lasso_tuner2.best_params_['alpha'], ', ', max(lasso_tuner2.cv_results_['mean_test_score']), ', ', sum(vif_df['vif'])/len(vif_df))
# Out:
# No radials:  ['TotalBsmtSF', 'BsmtCond_ord', 'BsmtQual_ord', 'GarageCond', 'GarageQual', 'GarageType_com', 'SalePrice_log', 'Garage_age_bin', 'Remod_age_bin', '1stFlrSF_log', '2ndFlrSF', 'KitchenAbvGr', 'TotRmsAbvGrd', 'GarageArea', 'GarageFinish', 'Fence', 'Alley', 'number_floors', 'FireplaceQu', 'LotFrontage', 'LowQualFinSF', 'BsmtExposure_ord', 'MasVnrArea'] :  1e-06 ,  0.9475716176776527 ,  36.054356259285186

# %% [markdown]
# log:  ['TotalBsmtSF', 'BsmtCond_ord', 'BsmtQual_ord', 'GarageCond', 'GarageQual', 'GarageType_com', 'SalePrice_log', 'Garage_age_bin', 'Remod_age_bin'] :  1e-06 ,  0.943454281780628
#
# log:  ['TotalBsmtSF', 'BsmtCond_ord', 'BsmtQual_ord', 'GarageCond', 'GarageQual', 'GarageType_com', 'SalePrice_log', 'Garage_age_bin', 'Remod_age_bin', '1stFlrSF_log'] :  1e-06 ,  0.9424740060473317
#
# log:  ['TotalBsmtSF', 'BsmtCond_ord', 'BsmtQual_ord', 'GarageCond', 'GarageQual', 'GarageType_com', 'SalePrice_log', 'Garage_age_bin', 'Remod_age_bin', '1stFlrSF_log', '2ndFlrSF'] :  1e-06 ,  0.9420770647332499
#
# log:  ['TotalBsmtSF', 'BsmtCond_ord', 'BsmtQual_ord', 'GarageCond', 'GarageQual', 'GarageType_com', 'SalePrice_log', 'Garage_age_bin', 'Remod_age_bin', '1stFlrSF_log', '2ndFlrSF', 'KitchenAbvGr'] :  1e-06 ,  0.9417616764602397
#
# ['TotalBsmtSF', 'BsmtCond_ord', 'BsmtQual_ord', 'GarageCond', 'GarageQual', 'GarageType_com', 'SalePrice_log', 'Garage_age_bin', 'Remod_age_bin', '1stFlrSF_log', '2ndFlrSF', 'KitchenAbvGr', 'TotRmsAbvGrd', 'GarageArea'] :  1e-06 ,  0.9416195613781179 ,  39.9001979416710
#
# ['TotalBsmtSF', 'BsmtCond_ord', 'BsmtQual_ord', 'GarageCond', 'GarageQual', 'GarageType_com', 'SalePrice_log', 'Garage_age_bin', 'Remod_age_bin', '1stFlrSF_log', '2ndFlrSF', 'KitchenAbvGr', 'TotRmsAbvGrd', 'GarageArea', 'GarageFinish', 'Fence'] :  1e-06 ,  0.9417193728756516 ,  41.05487105565105
#
# ['TotalBsmtSF', 'BsmtCond_ord', 'BsmtQual_ord', 'GarageCond', 'GarageQual', 'SalePrice_log', 'Garage_age_bin', 'Remod_age_bin', '1stFlrSF_log', '2ndFlrSF', 'KitchenAbvGr', 'TotRmsAbvGrd', 'GarageArea', 'GarageFinish', 'Fence'] :  1e-06 ,  0.9416530339287166 ,  39.99237976054064
#
# ['TotalBsmtSF', 'BsmtCond_ord', 'BsmtQual_ord', 'GarageCond', 'GarageQual', 'GarageType_com', 'SalePrice_log', 'Garage_age_bin', 'Remod_age_bin', '1stFlrSF_log', '2ndFlrSF', 'KitchenAbvGr', 'TotRmsAbvGrd', 'GarageArea', 'GarageFinish', 'Fence', 'Alley'] :  1e-06 ,  0.9417665575176081 ,  41.1929734948757
#
# ['TotalBsmtSF', 'BsmtCond_ord', 'BsmtQual_ord', 'GarageCond', 'GarageQual', 'GarageType_com', 'SalePrice_log', 'Garage_age_bin', 'Remod_age_bin', '1stFlrSF_log', '2ndFlrSF', 'KitchenAbvGr', 'TotRmsAbvGrd', 'GarageArea', 'GarageFinish', 'Fence', 'Alley', 'number_floors'] :  1e-06 ,  0.9418035097906687 ,  39.559875261890845
#
# ['TotalBsmtSF', 'BsmtCond_ord', 'BsmtQual_ord', 'GarageCond', 'GarageQual', 'GarageType_com', 'SalePrice_log', 'Garage_age_bin', 'Remod_age_bin', '1stFlrSF_log', '2ndFlrSF', 'KitchenAbvGr', 'TotRmsAbvGrd', 'GarageArea', 'GarageFinish', 'Fence', 'Alley', 'number_floors', 'FireplaceQu'] :  1e-06 ,  0.9417500104695516 ,  40.30945260646638
#
# ['TotalBsmtSF', 'BsmtCond_ord', 'BsmtQual_ord', 'GarageCond', 'GarageQual', 'GarageType_com', 'SalePrice_log', 'Garage_age_bin', 'Remod_age_bin', '1stFlrSF_log', '2ndFlrSF', 'KitchenAbvGr', 'TotRmsAbvGrd', 'GarageArea', 'GarageFinish', 'Fence', 'Alley', 'number_floors', 'FireplaceQu', 'LotFrontage', 'LowQualFinSF', 'BsmtExposure_ord', 'MasVnrArea'] :  1e-06 ,  0.9468407408759749 ,  36.57884336374308
#
# No radials:  ['TotalBsmtSF', 'BsmtCond_ord', 'BsmtQual_ord', 'GarageCond', 'GarageQual', 'GarageType_com', 'SalePrice_log', 'Garage_age_bin', 'Remod_age_bin', '1stFlrSF_log', '2ndFlrSF', 'KitchenAbvGr', 'TotRmsAbvGrd', 'GarageArea', 'GarageFinish', 'Fence', 'Alley', 'number_floors', 'FireplaceQu', 'LotFrontage', 'LowQualFinSF', 'BsmtExposure_ord', 'MasVnrArea', 'LotShape_com'] :  1e-06 ,  0.946833771716485 ,  35.69657081462711

# %%
radial = pd.read_csv('./../data/house_coordinates_1.0.csv')
radial.drop(columns = ('2204_park'), inplace = True)
for col in radial.columns:
    prefix = str(col)[0:4]
    if re.search('^\d\d\d\d_', str(col)):
        radial.rename(columns = {col: col[5:]}, inplace = True)

rad_drops = [
    'Address',
    'Coords4',
    'latitude',
    'longitude',
    'town_hall',
    'cemetery',
    'motel',
    'camp_site',
    'general',
    'picnic_site',
    'wastewater_plant',
    'spring',
    'beach',
    'street_lamp',
    'helipad',
    'vineyard',
    'crossing',
    'tree',
    'grass',
    'christian',
    'bus_stop',
    'parking',
    'toilet',
    'bench',
    'commercial',
    'waste_basket',
    'drinking_water',
    'convenience',
    'camera_surveillance',
    'comms_tower',
    'residential',
    'gift_shop',
    'jeweller',
    'hairdresser',
    'bookshop',
    'clothes',
    'retail',
    'food_court',
    'artwork',
    'cafe',
    'traffic_signals',
    'beauty_shop',
    'sports_shop',
    'weir',
    'track',
    'turning_circle',
    'computer_shop',
    'bicycle_shop',
    'department_store',
    'parking_bicycle',
    'golf_course',
    'tower',
    'beverages',
    'university'
]

radial.drop(columns = rad_drops, inplace = True)
sub = df.loc[:,['PID', 'SalePrice_log']]
radial = pd.merge(radial, sub, how = 'right', on = 'PID')

# %%
radial.drop(columns = ['PID','SalePrice_log'], inplace = True)

# %%
lasso_tuner3 = GridSearchCV(lasso2, params_log, cv=kfold, return_train_score = True)
lasso_tuner3.fit(radial, price_log)
# Out:
# C:\Users\fayma\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.4000420988997435, tolerance: 0.05269718428892526
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\fayma\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.077725734932085, tolerance: 0.053310157776091265
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\fayma\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.352380284036142, tolerance: 0.052416803797445045
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\fayma\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.039264465442119, tolerance: 0.05283066189970751
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\fayma\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.485298222037337, tolerance: 0.05280269175669625
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\fayma\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3811063725551058, tolerance: 0.05269718428892526
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\fayma\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6017739064574457, tolerance: 0.053310157776091265
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\fayma\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5830709124574334, tolerance: 0.052416803797445045
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\fayma\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13016821176102766, tolerance: 0.05283066189970751
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\fayma\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.44194427738791475, tolerance: 0.05280269175669625
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\fayma\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.48045348879476535, tolerance: 0.06601867232247279
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=Lasso(normalize=True, tol=0.001),
#              param_grid={'alpha': [1e-07, 1e-06, 1e-05, 0.0001]},
#              return_train_score=True)

# %%
lasso_tuner3.cv_results_['mean_test_score']
# Out:
# array([0.54590049, 0.54646727, 0.54404021, 0.46670631])

# %%
lasso_tuner3.cv_results_['mean_train_score']
# Out:
# array([0.58646805, 0.58634686, 0.57780744, 0.48220605])

# %%
len(radial.columns)
# Out:
# 81

# %%
feat_imp_rad = pd.Series(data = lasso_tuner3.best_estimator_.coef_, index = radial.columns)
feat_imp_rad = feat_imp_rad.sort_values(ascending = False)
ignored_rad = feat_imp_rad[feat_imp_rad == 0]
feat_imp_rad = feat_imp_rad[feat_imp_rad != 0]
print(len(feat_imp_rad))
print(feat_imp_rad)
print(len(ignored_rad))
print(ignored_rad)
# Out:
# 81
# slipway                  0.166635
# garden_centre            0.157494
# guesthouse               0.101396
# stop                     0.083934
# library                  0.073591
# dam                      0.059375
# furniture_shop           0.050300
# christian_catholic       0.045075
# stationery               0.040657
# viewpoint                0.040383
# laundry                  0.039904
# tourist_info             0.039035
# pier                     0.037632
# theatre                  0.036032
# recreation_ground        0.034843
# pub                      0.034486
# dog_park                 0.032927
# water_tower              0.031247
# doctors                  0.029168
# apron                    0.026762
# scrub                    0.025278
# hotel                    0.024577
# shoe_shop                0.021256
# jewish                   0.019733
# pharmacy                 0.017854
# christian_lutheran       0.017127
# playground               0.016967
# fire_station             0.015375
# doityourself             0.014012
# nursing_home             0.012659
# fountain                 0.011773
# motorway_junction        0.009218
# fuel                     0.009079
# mall                     0.008292
# christian_methodist      0.007525
# water                    0.006372
# bar                      0.004079
# forest                   0.002936
# farmyard                 0.002007
# swimming_pool            0.001976
# car_dealership           0.001677
# shelter                  0.001340
# farmland                 0.001145
# cinema                   0.001120
# christian_evangelical   -0.001480
# nature_reserve          -0.001995
# supermarket             -0.002174
# pitch                   -0.002298
# reservoir               -0.002696
# bank                    -0.003053
# post_office             -0.003131
# water_works             -0.005239
# fast_food               -0.005570
# industrial              -0.005789
# park                    -0.006004
# restaurant              -0.007645
# memorial                -0.008727
# meadow                  -0.010815
# optician                -0.012230
# mobile_phone_shop       -0.015602
# bakery                  -0.016299
# graveyard               -0.017676
# stadium                 -0.021274
# atm                     -0.021408
# museum                  -0.022771
# wetland                 -0.028776
# parking_multistorey     -0.032774
# outdoor_shop            -0.033650
# sports_centre           -0.033942
# florist                 -0.034342
# school                  -0.035507
# dentist                 -0.043472
# police                  -0.050209
# airport                 -0.051078
# car_wash                -0.054314
# muslim                  -0.061573
# post_box                -0.062323
# attraction              -0.062522
# hospital                -0.063010
# orchard                 -0.082023
# veterinary              -0.151589
# dtype: float64
# 0
# Series([], dtype: float64)

# %%
vif_rad = pd.DataFrame()
vif_rad['feature'] = radial.columns
vif_rad['vif'] = [variance_inflation_factor(radial.values, i)
                          for i in range(len(radial.columns))]

# %%
print(sum(vif_rad['vif'])/len(vif_rad))
vif_rad.sort_values(by = 'vif', ascending = False)
# Out:
# 32.2462129077583
#                   feature         vif
# 15             playground  116.693882
# 21             restaurant  115.125299
# 69                   park  102.889255
# 24                    bar   96.291573
# 43                   bank   94.572975
# 62    parking_multistorey   87.753351
# 68                 forest   84.649819
# 44                    atm   83.004114
# 61                   fuel   76.037614
# 27                shelter   71.530917
# 22              fast_food   70.035075
# 3             post_office   70.034243
# 29                 bakery   60.811457
# 18                  pitch   60.665904
# 78                  water   57.934348
# 32              shoe_shop   54.547086
# 37         car_dealership   49.319957
# 39         furniture_shop   46.084535
# 10                doctors   45.920959
# 8                pharmacy   45.054561
# 2                post_box   43.030900
# 28            supermarket   42.430267
# 74                orchard   39.189875
# 38           doityourself   37.095051
# 50               fountain   36.167210
# 41               car_wash   34.889473
# 33               optician   34.349983
# 55     christian_lutheran   32.942384
# 11                dentist   32.617626
# 42                laundry   31.500613
# 7                  school   31.408665
# 45           tourist_info   30.735615
# 47                 museum   29.846276
# 9                hospital   29.563854
# 77               farmland   27.896993
# 48               memorial   26.587316
# 13                theatre   26.275330
# 23                    pub   24.454237
# 17          sports_centre   23.937057
# 4                 library   21.597994
# 51            water_tower   21.528271
# 0                  police   21.410069
# 1            fire_station   20.887627
# 14                 cinema   20.053692
# 73      recreation_ground   19.077270
# 26             guesthouse   18.953412
# 53     christian_catholic   18.925370
# 31                florist   18.643584
# 25                  hotel   17.072035
# 30                   mall   16.473244
# 76               farmyard   16.401174
# 56    christian_methodist   16.271417
# 49              viewpoint   16.174850
# 35           outdoor_shop   16.101631
# 12             veterinary   15.791394
# 19          swimming_pool   14.974192
# 71                 meadow   14.253177
# 36      mobile_phone_shop   14.044082
# 54  christian_evangelical   13.257186
# 20                stadium   12.920556
# 5            nursing_home   12.071275
# 6               graveyard   11.892618
# 79              reservoir   10.812643
# 16               dog_park   10.565950
# 60      motorway_junction   10.409192
# 75                  scrub    9.566965
# 80                wetland    9.280147
# 72         nature_reserve    8.348799
# 57                 jewish    7.807106
# 46             attraction    7.534821
# 70             industrial    7.464405
# 58                 muslim    5.321539
# 59                   stop    5.297481
# 64                   pier    4.533992
# 63                slipway    4.245628
# 67                  apron    4.101817
# 40          garden_centre    4.065850
# 66                airport    3.270252
# 52            water_works    3.054513
# 34             stationery    2.126441
# 65                    dam    1.483936

# %%
radial.columns
# Out:
# Index(['police', 'fire_station', 'post_box', 'post_office', 'library',
#        'nursing_home', 'graveyard', 'school', 'pharmacy', 'hospital',
#        'doctors', 'dentist', 'veterinary', 'theatre', 'cinema', 'playground',
#        'dog_park', 'sports_centre', 'pitch', 'swimming_pool', 'stadium',
#        'restaurant', 'fast_food', 'pub', 'bar', 'hotel', 'guesthouse',
#        'shelter', 'supermarket', 'bakery', 'mall', 'florist', 'shoe_shop',
#        'optician', 'stationery', 'outdoor_shop', 'mobile_phone_shop',
#        'car_dealership', 'doityourself', 'furniture_shop', 'garden_centre',
#        'car_wash', 'laundry', 'bank', 'atm', 'tourist_info', 'attraction',
#        'museum', 'memorial', 'viewpoint', 'fountain', 'water_tower',
#        'water_works', 'christian_catholic', 'christian_evangelical',
#        'christian_lutheran', 'christian_methodist', 'jewish', 'muslim', 'stop',
#        'motorway_junction', 'fuel', 'parking_multistorey', 'slipway', 'pier',
#        'dam', 'airport', 'apron', 'forest', 'park', 'industrial', 'meadow',
#        'nature_reserve', 'recreation_ground', 'orchard', 'scrub', 'farmyard',
#        'farmland', 'water', 'reservoir', 'wetland'],
#       dtype='object')

# %%
radial = pd.read_csv('./../data/house_coordinates_1.0.csv')
radial.drop(columns = ('2204_park'), inplace = True)
for col in radial.columns:
    prefix = str(col)[0:4]
    if re.search('^\d\d\d\d_', str(col)):
        radial.rename(columns = {col: col[5:]}, inplace = True)

# %%
df6 = pd.merge(df.copy(), radial, on = 'PID', how = 'left')

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
def fit_scale(df, col):
    scaler.fit(df[[col]])
    df[[col]]=scaler.transform(df[[col]])
fit_scale(df6, 'OverallQual')
fit_scale(df6, 'ExterQual')
fit_scale(df6, 'OverallCond')
fit_scale(df6, 'KitchenQual')
#df2['Porch']=((df2['OpenPorchSF']>0) | (df2['EnclosedPorch']>0) | (df2['3SsnPorch']>0) | (df2['ScreenPorch']>0))
df6['PorchSF']=df6['OpenPorchSF']+df6['EnclosedPorch']+df6['3SsnPorch']+df6['ScreenPorch']
#df2['1stFloorArea%']=df2['1stFlrSF']/df2['GrLivArea']
#df2['2ndFloorArea%']=df2['2ndFlrSF']/df2['GrLivArea']
df6['ExterQualDisc'] = df6['ExterQual'] - df6['OverallQual']
df6['OverallCondDisc'] = df6['OverallCond'] - df6['OverallQual']
df6['KitchenQualDisc'] = df6['KitchenQual'] - df6['OverallQual']
df6['SaleTypeNew']=(df6['SaleType']=='New')
df6['SaleTypeNew']=df6['SaleTypeNew'].apply(lambda x: 1 if x==True else 0)
#df2['BSMT_GLQ%']=df2['BSMT_GLQ']/df2['TotalBsmtSF']
#df2['BSMT_ALQ%']=df2['BSMT_ALQ']/df2['TotalBsmtSF']
#df2['BSMT_GLQ%']=df2['BSMT_GLQ%'].fillna(0)
#df2['BSMT_ALQ%']=df2['BSMT_ALQ%'].fillna(0)
df6['BSMT_LowQual']=df6['TotalBsmtSF']-df6['BSMT_GLQ']-df6['BSMT_ALQ']
df6['BSMT_HighQual']=df6['BSMT_GLQ']+df6['BSMT_ALQ']
df6['AreaPerPerson'] = np.log10(df6['GrLivArea']/df6['BedroomAbvGr'])

# %%
df6['BSMT_HighQual_bin'] = pd.cut(df6['BSMT_HighQual'], [-1, 1, 500, 1000, 1500, 2500], labels = ['No basement', '0-500', '500-1000', '1000-1500', '1500+'])

# %%
df6['BSMT_LowQual_bin'] = pd.cut(df6['BSMT_LowQual'], [-1, 1, 500, 1000, 1500, 2500], labels = ['No basement', '0-500', '500-1000', '1000-1500', '1500+'])

# %%
feat_incl =[
    ### from original dataset
    'GrLivArea', 
    'LotArea', 
    'OverallQual',
    'BSMT_LowQual', 
    'house_age_years', 
    'GarageCars',
    'MasVnrType',
    'FullBath',
    'HalfBath',
    'BsmtExposure_ord',
    'SaleTypeNew',
    'Neighborhood',
    'BldgType',
    'PorchSF',
    'BSMT_HighQual',
    'Fireplaces',
    'Pool',
    'BedroomAbvGr',
    'ExterQual',
    'OverallCond',
    'KitchenQual',
    
    ### from radial location data
    'water_tower',
    'graveyard',
    'police', 
    'optician',
    'slipway',
    'bar',
    'cinema',
    'supermarket',
    'hotel',
    'stop',
    'farmyard',
    'christian_catholic', 
    'jewish',
    'muslim',
    'garden_centre',
    'christian_lutheran'                 
]

# %%
list(radial.columns)
# Out:
# ['PID',
#  'Address',
#  'Coords4',
#  'latitude',
#  'longitude',
#  'police',
#  'fire_station',
#  'post_box',
#  'post_office',
#  'library',
#  'town_hall',
#  'nursing_home',
#  'graveyard',
#  'university',
#  'school',
#  'pharmacy',
#  'hospital',
#  'doctors',
#  'dentist',
#  'veterinary',
#  'theatre',
#  'cinema',
#  'playground',
#  'dog_park',
#  'sports_centre',
#  'pitch',
#  'swimming_pool',
#  'golf_course',
#  'stadium',
#  'track',
#  'restaurant',
#  'fast_food',
#  'cafe',
#  'pub',
#  'bar',
#  'food_court',
#  'hotel',
#  'motel',
#  'guesthouse',
#  'shelter',
#  'camp_site',
#  'supermarket',
#  'bakery',
#  'mall',
#  'department_store',
#  'general',
#  'convenience',
#  'clothes',
#  'florist',
#  'bookshop',
#  'shoe_shop',
#  'beverages',
#  'optician',
#  'jeweller',
#  'gift_shop',
#  'sports_shop',
#  'stationery',
#  'outdoor_shop',
#  'mobile_phone_shop',
#  'beauty_shop',
#  'car_dealership',
#  'bicycle_shop',
#  'doityourself',
#  'furniture_shop',
#  'computer_shop',
#  'garden_centre',
#  'hairdresser',
#  'car_wash',
#  'laundry',
#  'bank',
#  'atm',
#  'tourist_info',
#  'attraction',
#  'museum',
#  'memorial',
#  'artwork',
#  'picnic_site',
#  'viewpoint',
#  'toilet',
#  'bench',
#  'drinking_water',
#  'fountain',
#  'waste_basket',
#  'camera_surveillance',
#  'tower',
#  'comms_tower',
#  'water_tower',
#  'wastewater_plant',
#  'water_works',
#  'christian',
#  'christian_catholic',
#  'christian_evangelical',
#  'christian_lutheran',
#  'christian_methodist',
#  'jewish',
#  'muslim',
#  'spring',
#  'tree',
#  'beach',
#  'traffic_signals',
#  'stop',
#  'crossing',
#  'motorway_junction',
#  'turning_circle',
#  'street_lamp',
#  'fuel',
#  'parking',
#  'parking_multistorey',
#  'parking_bicycle',
#  'slipway',
#  'pier',
#  'dam',
#  'weir',
#  'bus_stop',
#  'airport',
#  'helipad',
#  'apron',
#  'forest',
#  'park',
#  'residential',
#  'industrial',
#  'cemetery',
#  'meadow',
#  'commercial',
#  'nature_reserve',
#  'recreation_ground',
#  'retail',
#  'orchard',
#  'vineyard',
#  'scrub',
#  'grass',
#  'farmyard',
#  'farmland',
#  'water',
#  'reservoir',
#  'wetland']

# %%
df7 = df6.loc[:,feat_incl]
df7
# Out:
#       GrLivArea  LotArea  OverallQual BSMT_LowQual_bin  house_age_years  \
# 0           856     7890     0.428571         500-1000        71.210959
# 1          1049     4235     0.285714            0-500        25.104110
# 2          1039     8146     0.142857            0-500       109.402740
# 3          1665     8400     0.714286            0-500         8.838356
# 4          1922     7301     0.571429      No basement         6.501370
# ...         ...      ...          ...              ...              ...
# 2466        952     8854     0.428571         500-1000        93.394521
# 2467       1733    13680     0.000000      No basement        54.452055
# 2468       2002     6270     0.285714        1000-1500        58.619178
# 2469       1842     8826     0.571429            0-500         7.501370
# 2470       1911     9554     0.714286            0-500        13.673973
#
#       GarageCars  MasVnrType  FullBath  HalfBath  BsmtExposure_ord  ...  \
# 0            2.0        None         1         0                 1  ...
# 1            1.0  Brick Face         2         0                 2  ...
# 2            1.0        None         1         0                 1  ...
# 3            2.0        None         2         1                 1  ...
# 4            2.0  Brick Face         3         0                 0  ...
# ...          ...         ...       ...       ...               ...  ...
# 2466         1.0        None         1         0                 1  ...
# 2467         2.0        None         2         0                 0  ...
# 2468         3.0        None         2         0                 1  ...
# 2469         2.0  Brick Face         2         1                 1  ...
# 2470         2.0  Brick Face         2         1                 1  ...
#
#       Neighborhood BldgType PorchSF  BSMT_HighQual_bin Fireplaces  Pool  \
# 0            SWISU     1Fam     166        No basement          1     0
# 1          Edwards   TwnhsE     105           500-1000          0     0
# 2          OldTown     1Fam     279        No basement          0     0
# 3           NWAmes     1Fam      45           500-1000          0     0
# 4          Edwards     1Fam     177        No basement          1     0
# ...            ...      ...     ...                ...        ...   ...
# 2466       BrkSide     1Fam     138        No basement          1     0
# 2467       Edwards     1Fam       0        No basement          1     0
# 2468       Crawfor   Duplex       0        No basement          0     0
# 2469       CollgCr     1Fam      96           500-1000          1     0
# 2470       SawyerW     1Fam      81              0-500          1     0
#
#       BedroomAbvGr  ExterQual  OverallCond  KitchenQual
# 0                2   0.333333     0.500000     0.333333
# 1                2   0.666667     0.333333     0.666667
# 2                2   0.666667     0.833333     0.333333
# 3                3   0.666667     0.500000     0.666667
# 4                4   0.666667     0.333333     0.666667
# ...            ...        ...          ...          ...
# 2466             2   0.333333     0.500000     0.000000
# 2467             4   0.333333     0.333333     0.333333
# 2468             4   0.333333     0.500000     0.333333
# 2469             3   0.666667     0.333333     0.666667
# 2470             3   0.666667     0.333333     0.666667
#
# [2471 rows x 21 columns]

# %%
non_dummies = [
    'MasVnrType',
    'Neighborhood',
    'BldgType',
    'BSMT_HighQual_bin',
    'BSMT_LowQual_bin'
]

# %%
dummies = [
    'Neighborhood_Blueste',
       'Neighborhood_BrDale', 'Neighborhood_BrkSide', 'Neighborhood_ClearCr',
       'Neighborhood_CollgCr', 'Neighborhood_Crawfor', 'Neighborhood_Edwards',
       'Neighborhood_Gilbert', 'Neighborhood_Greens', 'Neighborhood_GrnHill',
       'Neighborhood_IDOTRR', 'Neighborhood_Landmrk', 'Neighborhood_MeadowV',
       'Neighborhood_Mitchel', 'Neighborhood_NAmes', 'Neighborhood_NPkVill',
       'Neighborhood_NWAmes', 'Neighborhood_NoRidge', 'Neighborhood_NridgHt',
       'Neighborhood_OldTown', 'Neighborhood_SWISU', 'Neighborhood_Sawyer',
       'Neighborhood_SawyerW', 'Neighborhood_Somerst', 'Neighborhood_StoneBr',
       'Neighborhood_Timber', 'Neighborhood_Veenker', 'BldgType_2fmCon',
       'BldgType_Duplex', 'BldgType_Twnhs', 'BldgType_TwnhsE',
       'MasVnrType_None', 'MasVnrType_Stone',
    
        'BSMT_HighQual_bin_500-1000', 'BSMT_HighQual_bin_0-500',
    'BSMT_HighQual_bin_1000-1500', 'BSMT_HighQual_bin_1500+',
    'BSMT_LowQual_bin_0-500', 'BSMT_LowQual_bin_500-1000', 'BSMT_LowQual_bin_1000-1500',
    'BSMT_LowQual_bin_1500+'
]

# %%
def dummify(df, non_dummies, dummies):
    for dummified in dummies:
        for original in non_dummies:
            if original in dummified:
                orig_name = f'{original}_'
                value = dummified.replace(orig_name, '')
                df[dummified] = df[original].map(lambda x: 1 if x == value else 0)
    df = df.drop(columns = non_dummies, axis = 1)
    return df

# %%
df7.columns
# Out:
# Index(['GrLivArea', 'LotArea', 'OverallQual', 'BSMT_LowQual_bin',
#        'house_age_years', 'GarageCars', 'MasVnrType', 'FullBath', 'HalfBath',
#        'BsmtExposure_ord', 'SaleTypeNew', 'Neighborhood', 'BldgType',
#        'PorchSF', 'BSMT_HighQual_bin', 'Fireplaces', 'Pool', 'BedroomAbvGr',
#        'ExterQual', 'OverallCond', 'KitchenQual'],
#       dtype='object')

# %%
df7 = dummify(df7, non_dummies, dummies)

# %%
lasso_tuner4 = GridSearchCV(lasso2, params_log, cv=kfold, return_train_score = True)
lasso_tuner4.fit(df7, price_log)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=Lasso(normalize=True, tol=0.001),
#              param_grid={'alpha': [1e-07, 1e-06, 1e-05, 0.0001]},
#              return_train_score=True)

# %%
lasso_tuner4.cv_results_['mean_test_score']
# Out:
# array([0.93103317, 0.93108776, 0.93068733, 0.91015996])

# %%
lasso_tuner4.best_params_
# Out:
# {'alpha': 1e-06}

# %%
import pickle

# %%
lasso_tuner4.best_estimator_.predict(df7)
# Out:
# array([5.05790928, 5.10238662, 5.00562717, ..., 5.22816107, 5.34002457,
#        5.32274894])

# %%
asdf = open('linear_model.txt', mode = 'wb')

# %%
asdf.close()

# %%
with open('linearmodel.pickle', mode = 'wb') as file:
    pickle.dump(lasso_tuner4.best_estimator_, file)

# %%
with open('linearmodel.pickle', mode = 'rb') as file:
    lm = pickle.load(file)

# %%
loaded_obj.predict(df7)
# Out:
# array([5.05790928, 5.10238662, 5.00562717, ..., 5.22816107, 5.34002457,
#        5.32274894])

# %%
print(loc_feat_incl, ': ', max(lasso_tuner4.cv_results_['mean_test_score']), ', ', sum(vif_df['vif'])/len(vif_df))
# Out:
# ['slipway', 'bar', 'farmyard', 'christian_catholic', 'jewish', 'muslim', 'garden_centre', 'christian_methodist', 'christian_evangelical', 'christian_lutheran'] :  0.9345469007364361 ,  36.054356259285186

# %% [markdown]
# ['slipway', 'bar', 'cinema', 'supermarket', 'farmyard', 'christian_catholic', 'jewish', 'muslim', 'garden_centre', 'christian_methodist', 'christian_evangelical', 'christian_lutheran'] :  0.9350983215981801 ,  36.054356259285186
#
# ['slipway', 'bar', 'cinema', 'supermarket', 'farmyard', 'christian_catholic', 'jewish', 'muslim', 'garden_centre', 'christian_methodist', 'christian_evangelical', 'christian_lutheran'] :  0.9351894282916218 ,  36.054356259285186

# %%
feat_imp_min = pd.Series(data = lasso_tuner4.best_estimator_.coef_, index = df7.columns)
feat_imp_min = feat_imp_min.sort_values(ascending = False)
ignored_min = feat_imp_min[feat_imp_min == 0]
feat_imp_min = feat_imp_min[feat_imp_min != 0]
print(len(feat_imp_min))
print(feat_imp_min)
print(len(ignored_min))
print(ignored_min)
# Out:
# 69
# GrLivArea_log                  0.427147
# OverallQual                    0.153860
# OverallCond                    0.133836
# BSMT_HighQual_bin_1500+        0.122679
# LotArea_log                    0.101925
# BSMT_HighQual_bin_1000-1500    0.083916
# Neighborhood_Crawfor           0.054819
# BSMT_LowQual_bin_1500+         0.051154
# Neighborhood_StoneBr           0.048564
# BSMT_HighQual_bin_500-1000     0.047971
# BSMT_LowQual_bin_1000-1500     0.047562
# garden_centre                  0.036461
# KitchenQual                    0.034954
# BSMT_LowQual_bin_500-1000      0.030745
# ExterQual                      0.029386
# Neighborhood_NridgHt           0.026092
# Neighborhood_Blueste           0.026039
# Neighborhood_NPkVill           0.024142
# Neighborhood_Greens            0.023714
# Neighborhood_NoRidge           0.020121
# BSMT_HighQual_bin_0-500        0.020092
# Neighborhood_Somerst           0.019603
# BSMT_LowQual_bin_0-500         0.019339
# SaleTypeNew                    0.018759
# GarageCars                     0.017028
# Neighborhood_Timber            0.014834
# Fireplaces                     0.012070
# optician                       0.007536
# BsmtExposure_ord               0.007117
# Neighborhood_BrkSide           0.005124
# muslim                         0.004258
# Neighborhood_ClearCr           0.003903
# Neighborhood_CollgCr           0.002284
# Neighborhood_BrDale            0.002143
# Pool                           0.002034
# FullBath                       0.001595
# HalfBath                       0.001118
# bar                            0.000677
# stop                           0.000135
# Neighborhood_SWISU             0.000073
# PorchSF                        0.000054
# slipway                       -0.000864
# water_tower                   -0.001025
# farmyard                      -0.001145
# police                        -0.001246
# house_age_years               -0.001387
# Neighborhood_IDOTRR           -0.001554
# supermarket                   -0.001634
# MasVnrType_None               -0.001636
# MasVnrType_Stone              -0.001925
# BedroomAbvGr                  -0.002405
# christian_lutheran            -0.004102
# graveyard                     -0.004354
# hotel                         -0.006337
# BldgType_TwnhsE               -0.006627
# Neighborhood_Mitchel          -0.008598
# cinema                        -0.009142
# christian_catholic            -0.011166
# Neighborhood_NWAmes           -0.014309
# Neighborhood_Sawyer           -0.014664
# Neighborhood_OldTown          -0.015763
# Neighborhood_Gilbert          -0.020817
# BldgType_Twnhs                -0.020929
# BldgType_2fmCon               -0.022925
# Neighborhood_Veenker          -0.023253
# Neighborhood_Edwards          -0.024006
# Neighborhood_MeadowV          -0.032405
# Neighborhood_SawyerW          -0.034014
# BldgType_Duplex               -0.040058
# dtype: float64
# 4
# Neighborhood_Landmrk    0.0
# Neighborhood_NAmes      0.0
# jewish                 -0.0
# Neighborhood_GrnHill    0.0
# dtype: float64

# %%
vif_min = pd.DataFrame()
vif_min['feature'] = df7.columns
vif_min['vif'] = [variance_inflation_factor(df7.values, i)
                          for i in range(len(df7.columns))]

# %%
print(sum(vif_min['vif'])/len(vif_min))
vif_min.sort_values(by = 'vif', ascending = False)
# Out:
# 36.862252944353344
#                         feature          vif
# 0                 GrLivArea_log  1181.094634
# 1                   LotArea_log   898.646589
# 55           Neighborhood_NAmes    30.625920
# 12                 BedroomAbvGr    28.824356
# 5                      FullBath    25.182219
# 2                   OverallQual    24.678437
# 28           christian_lutheran    23.071881
# 29                    ExterQual    22.379857
# 62         Neighborhood_CollgCr    22.197046
# 3               house_age_years    19.249966
# 51         Neighborhood_OldTown    18.971149
# 20                  supermarket    16.736403
# 60         Neighborhood_Edwards    16.520740
# 31                  KitchenQual    15.692948
# 4                    GarageCars    14.106326
# 45          Neighborhood_Sawyer    13.972852
# 23                     farmyard    13.596363
# 13                  water_tower    12.859764
# 65    BSMT_LowQual_bin_500-1000    12.755842
# 61       BSMT_LowQual_bin_0-500    12.024818
# 18                          bar    11.514158
# 54         Neighborhood_Crawfor    11.163763
# 16                     optician    10.611720
# 30                  OverallCond    10.289090
# 32         Neighborhood_Mitchel    10.160919
# 42         Neighborhood_Somerst     9.508768
# 38         Neighborhood_SawyerW     9.310441
# 63         Neighborhood_NridgHt     9.254023
# 67         Neighborhood_BrkSide     9.172221
# 34         Neighborhood_Gilbert     9.102175
# 21                        hotel     9.005285
# 44          Neighborhood_NWAmes     8.899711
# 15                       police     7.937676
# 14                    graveyard     7.626450
# 68   BSMT_LowQual_bin_1000-1500     6.979603
# 36          Neighborhood_IDOTRR     6.950081
# 70          Neighborhood_Timber     6.743647
# 24           christian_catholic     6.512705
# 39         Neighborhood_NoRidge     6.092314
# 25                       jewish     6.012979
# 26                       muslim     5.835580
# 7              BsmtExposure_ord     5.431375
# 43         Neighborhood_StoneBr     5.194839
# 56           Neighborhood_SWISU     5.134651
# 19                       cinema     4.765246
# 46              MasVnrType_None     4.403492
# 48         Neighborhood_MeadowV     4.295056
# 72         Neighborhood_ClearCr     4.265429
# 58   BSMT_HighQual_bin_500-1000     3.771724
# 22                         stop     3.556519
# 17                      slipway     3.150236
# 10                   Fireplaces     2.992305
# 69         Neighborhood_Veenker     2.967434
# 40       BSMT_LowQual_bin_1500+     2.897087
# 6                      HalfBath     2.870418
# 47          Neighborhood_BrDale     2.804518
# 64  BSMT_HighQual_bin_1000-1500     2.732392
# 66               BldgType_Twnhs     2.620054
# 50         Neighborhood_NPkVill     2.546964
# 37              BldgType_TwnhsE     2.430084
# 59         Neighborhood_Blueste     2.380005
# 9                       PorchSF     2.074189
# 27                garden_centre     1.929503
# 52          Neighborhood_Greens     1.809079
# 41      BSMT_HighQual_bin_0-500     1.723463
# 49      BSMT_HighQual_bin_1500+     1.512035
# 35             MasVnrType_Stone     1.492395
# 71              BldgType_Duplex     1.490937
# 8                   SaleTypeNew     1.248684
# 53         Neighborhood_GrnHill     1.242945
# 33              BldgType_2fmCon     1.158071
# 57         Neighborhood_Landmrk     1.134069
# 11                         Pool     1.047848

# %%
column_title_dict = {
    ### from original dataset
    'GrLivArea' : 'Above-ground living area in sq ft',
    'LotArea' : 'Lot area in sq ft',
    'OverallQual' : 'Overall quality',
    'BSMT_LowQual' : 'Low-quality basement area in sq ft',
    'BSMT_HighQual' : 'High-quality basement area in sq ft',
    'house_age_years' : 'House age in years',
    'GarageCars' : 'Number of cars held by garage',
    'FullBath' : 'Number of full bathrooms',
    'HalfBath' : 'Number of half-bathrooms',
    'BsmtExposure_ord' : 'Basement exposure',
    'Neighborhood' : 'Neighborhood',
    'BldgType' : 'Building type',
    'PorchSF' : 'Porch area in sq ft',
    'ExterQualDisc' : 'Exterior quality score - overall quality score',
    'OverallCondDisc' : 'Overall condition score - overall quality score',
    'KitchenQualDisc' : 'Kitchen quality score - overall quality score',
    'Fireplaces' : 'Number of fireplaces',
    'Pool' : 'Pool',
    'BedroomAbvGr' : 'Number of bedrooms',
    'ext_Asbestos_Shingles' : 'Asbestos used in walls',
    
    ### location features
    'graveyard' : 'Number graveyards within 1 mile',
    'police' : 'Number of police stations within 1 mile',
    'optician' : 'Number of opticians within 1 mile',
    'stop' : 'Number of stop signs within 1 mile',
    'slipway' : 'Number of slipways within 1 mile',
    'bar' : 'Number of bars within 1 mile',
    'cinema' : 'Number of cinemas within 1 mile',
    'supermarket' : 'Number of supermarkets within 1 mile',
    'hotel' : 'Number of hotels within 1 mile',
    'farmyard' : 'Number of farmyards within 1 mile',
    'water_tower' : 'Number of water towers within 1 mile',
    'christian_catholic' : 'Number of catholic churches within 1 mile',
    'jewish' : 'Number of synagogues within 1 mile',
    'muslim' : 'Number of mosques within 1 mile',
    'garden_centre' : 'Number of garden centers within 1 mile',
    'christian_lutheran' : 'Number of lutheran churches within 1 mile'
}
