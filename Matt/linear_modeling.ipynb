# %%
import numpy as np
import pandas as pd
from scipy import stats
from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression
import plotly.express as px
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.model_selection import cross_val_score
import time
import re
from datetime import datetime
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
pd.set_option('display.max_rows', 500)

# %%
def dummify_linear(data, to_dummify, drops):
    
    bsmt_categoricals = [
        'BsmtCond_ord',
        'BsmtQual_ord',
        'BsmtExposure_ord']
    
    grg_categoricals = [ 
        'GarageQual',
        'GarageCond',
        'GarageType_com',
        'Garage_age_bin',
        'GarageFinish']
    
    dummies = to_dummify
        
    for item in drops:
        if item in grg_categoricals:
            grg_categoricals.remove(item)      
        if item in dummies:
            dummies.remove(item)
        if item in bsmt_categoricals:
            bsmt_categoricals.remove(item)
    
    df = data.drop(columns = drops, axis = 1)
    print('before dummifying: ', df.shape)
    df = pd.get_dummies(df, columns = grg_categoricals)
    for col in grg_categoricals:
        if f'{col}_0' in df.columns:
            df = df.drop(columns = [f'{col}_0'], axis = 1)
        if f'{col}_No garage' in df.columns:
            df = df.drop(columns = [f'{col}_No garage'], axis = 1)
    print('after garage stuff: ', df.shape)     
    df = pd.get_dummies(df, columns = bsmt_categoricals)
    for col in bsmt_categoricals:
        if f'{col}_0' in df.columns:
            df = df.drop(columns = [f'{col}_0'], axis = 1)
    print('after basement stuff: ', df.shape)
    
    df = pd.get_dummies(df, columns = to_dummify, drop_first = True)
    print('after full dummification: ', df.shape)
    
    return df

# %%
def drop_dummies(dummified, orig_col):
    keep_list = []
    for col in dummified.columns:
        if not f'{orig_col}_' in col:
            keep_list.append(col)
    return dummified.loc[:, keep_list]

# %%
df = pd.read_csv('./../data/ames_housing_price_data_v5.csv')
df = df[(df['PID'] != 902207130) & (df['PID'] != 908154205)]
df = df[(df['SaleCondition'] == 'Normal') | (df['SaleCondition'] == 'Partial')]
df = df[df['BedroomAbvGr'] != 0]
df = df[df['MSZoning_com'] != 'Nonresidential']
df = df[(df['Neighborhood'] != 'GrnHill') & (df['Neighborhood'] != 'Landmrk')]
df.reset_index(drop=True, inplace = True)

price = df.loc[:,'SalePrice']
price_log = df.loc[:,'SalePrice_log']

basement_categoricals = [
    'BsmtCond_ord',
    'BsmtQual_ord',
    'BsmtExposure_ord']

garage_categoricals = [ 
    'GarageQual',
    'GarageCond',
    'GarageType_com',
    'Garage_age_bin',
    'GarageFinish']

always_drop = [
    'Street_paved',
    'RoofMatl',
    'SaleType',
    'SaleCondition',
    'Garage_age_years',
    'Remod_age_years',
    'MoSold',
    'Utilities',
    'PID',
    'PoolArea',
    'PoolQC',
    'SalePrice',
    'sold_datetime',
    '2ndFlrSF_log',
    'GrLivArea',
    'MiscVal',
    'MiscFeature',
    '1stFlrSF',
    'LotArea',
    'LotFrontage_log',
    'YrSold'
]

droplist = []

to_dummify = [
    #'Street_paved',
    'Alley',
    'LandContour',
    #'Utilities',
    'LandSlope',
    'Neighborhood',
    'BldgType',
    'OverallQual',
    'OverallCond',
    'RoofStyle',
    #'RoofMatl',
    'MasVnrType',
    'ExterQual',
    'ExterCond',
    'Foundation',
    'CentralAir',
    'KitchenQual',
    'FireplaceQu',
    'PavedDrive',
    #'PoolQC',
    'Fence',
    #'MiscFeature',
    #'MoSold',
    'HeatingQC_ord',
    'LotShape_com',
    'MSZoning_com',
    'Heating_com',
    'Electrical_com',
    'LotConfig_com',
    'number_floors',
    'attic',
    'PUD',
    'Functional_ord',
    'Remod_age_bin'
    #'SaleType',
    #'SaleCondition'
]

# %%
list(df.columns)
# Out:
# ['PID',
#  'GrLivArea',
#  'SalePrice',
#  'LotFrontage',
#  'LotArea',
#  'Street_paved',
#  'Alley',
#  'LandContour',
#  'Utilities',
#  'LandSlope',
#  'Neighborhood',
#  'BldgType',
#  'OverallQual',
#  'OverallCond',
#  'RoofStyle',
#  'RoofMatl',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'CentralAir',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageFinish',
#  'GarageCars',
#  'GarageArea',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SaleType',
#  'SaleCondition',
#  'SalePrice_log',
#  'HeatingQC_ord',
#  'LotShape_com',
#  'MSZoning_com',
#  'LF_Near_NS_RR',
#  'LF_Near_Positive_Feature',
#  'LF_Adjacent_Arterial_St',
#  'LF_Near_EW_RR',
#  'LF_Adjacent_Feeder_St',
#  'Heating_com',
#  'Electrical_com',
#  'LotConfig_com',
#  'LotFrontage_log',
#  'LotArea_log',
#  'ext_Wood',
#  'ext_Metal_Siding',
#  'ext_Vinyl_Siding',
#  'ext_Stucco',
#  'ext_Cement_Board',
#  'ext_Brick',
#  'ext_Asbestos_Shingles',
#  'ext_Other',
#  'BsmtCond_ord',
#  'BsmtQual_ord',
#  'BsmtExposure_ord',
#  'BSMT_GLQ',
#  'BSMT_ALQ',
#  'BSMT_BLQ',
#  'BSMT_LwQ',
#  'BSMT_Rec',
#  'GarageType_com',
#  'number_floors',
#  'attic',
#  'PUD',
#  'Functional_ord',
#  '1stFlrSF_log',
#  '2ndFlrSF_log',
#  'GrLivArea_log',
#  'sold_datetime',
#  'Garage_age_years',
#  'Garage_age_bin',
#  'house_age_years',
#  'Remod_age_years',
#  'Remod_age_bin',
#  'Pool']

# %%
all_dummies = to_dummify + garage_categoricals + basement_categoricals

# %%
df2 = df.drop(columns = always_drop, axis = 1)
kfold = KFold(n_splits=5, shuffle = True, random_state = 1)

# %%
# kfold = KFold(n_splits=5, shuffle = True, random_state = 1)
# folds = list(kfold.split(df3))
# xtrain = [0]*5
# ytrain = [0]*5
# xtest = [0]*5
# ytest = [0]*5
# for i in range(0,5):
#     xtrain[i] = df3.loc[folds[i][0],:].drop(columns = 'SalePrice_log')
#     ytrain[i] = df3.loc[folds[i][0],'SalePrice_log']
#     xtest[i] = df3.loc[folds[i][1],:].drop(columns = 'SalePrice_log')
#     ytest[i] = df3.loc[folds[i][1],'SalePrice_log']

# feature_selection_df = df2.drop(columns = ['SalePrice_log'], axis = 1)
# score_dict_total={}
# col_dict_total2={}
# j=1
# xtrain_red = xtrain.copy()
# xtest_red = xtest.copy()
# start = datetime.now()
# while len(feature_selection_df.columns)> 50:
#     score_dict={}
#     for col in feature_selection_df.columns:
#         if col in all_dummies:
#             xtrain_red = list(map(lambda x: drop_dummies(x, col), xtrain))
#             xtest_red = list(map(lambda x: drop_dummies(x, col), xtest))
#         else:
#             xtrain_red = list(map(lambda x: x.drop(col, axis = 1), xtrain))
#             xtest_red = list(map(lambda x: x.drop(col, axis = 1), xtest))
            
#         #adjust these lines to reflect your model
#         models = list(map(lambda x, y: Lasso(alpha = 1e-6, normalize = True, max_iter = 1000, tol = 0.001).fit(x, y), xtrain, ytrain))
#         scores = list(map(lambda x, y, z: x.score(y, z), models, xtest, ytest))
#         score_dict[col] = np.mean(scores)
#         #-------

#     min_col=max(score_dict.items(), key=lambda x: x[1])[0]
#     score_dict_total[j]=max(score_dict.items(), key=lambda x: x[1])[1]
#     col_dict_total2[j]=min_col
#     feature_selection_df = feature_selection_df.drop(min_col, axis=1)
#     if min_col in all_dummies:
#         xtrain = list(map(lambda x: drop_dummies(x, min_col), xtrain))
#         xtest = list(map(lambda x: drop_dummies(x, min_col), xtest))
#     else:
#         xtrain = list(map(lambda x: x.drop(min_col, axis = 1), xtrain))
#         xtest = list(map(lambda x: x.drop(min_col, axis = 1), xtest))
#     print(f'{j} columns removed: {min_col}, best score is {score_dict_total[j]}; time elapsed is {datetime.now()-start}')
#     j+=1

# %%
# col_dict_total2

# %%
# folds = list(kfold.split(df3))
# xtrain = [0]*5
# ytrain = [0]*5
# xtest = [0]*5
# ytest = [0]*5
# for i in range(0,5):
#     xtrain[i] = df3.loc[folds[i][0],:].drop(columns = 'SalePrice_log')
#     ytrain[i] = df3.loc[folds[i][0],'SalePrice_log']
#     xtest[i] = df3.loc[folds[i][1],:].drop(columns = 'SalePrice_log')
#     ytest[i] = df3.loc[folds[i][1],'SalePrice_log']

# feature_selection_df = df2.drop(columns = ['SalePrice_log'], axis = 1)
# score_dict_total={}
# col_dict_total_neighborhood={}
# j=1
# xtrain_red = xtrain.copy()
# xtest_red = xtest.copy()
# start = datetime.now()
# while len(feature_selection_df.columns)> 50:
#     score_dict={}
#     for col in feature_selection_df.columns:
#         if col in all_dummies:
#             xtrain_red = list(map(lambda x: drop_dummies(x, col), xtrain))
#             xtest_red = list(map(lambda x: drop_dummies(x, col), xtest))
#         else:
#             xtrain_red = list(map(lambda x: x.drop(col, axis = 1), xtrain))
#             xtest_red = list(map(lambda x: x.drop(col, axis = 1), xtest))
            
#         #adjust these lines to reflect your model
#         models = list(map(lambda x, y: Lasso(alpha = 1e-6, normalize = True, max_iter = 1000, tol = 0.001).fit(x, y), xtrain, ytrain))
#         scores = list(map(lambda x, y, z: x.score(y, z), models, xtest, ytest))
#         score_dict[col] = np.mean(scores)
#         #-------

#     min_col=max(score_dict.items(), key=lambda x: x[1])[0]
#     score_dict_total[j]=max(score_dict.items(), key=lambda x: x[1])[1]
#     col_dict_total_neighborhood[j]=min_col
#     feature_selection_df = feature_selection_df.drop(min_col, axis=1)
#     if min_col in all_dummies:
#         xtrain = list(map(lambda x: drop_dummies(x, min_col), xtrain))
#         xtest = list(map(lambda x: drop_dummies(x, min_col), xtest))
#     else:
#         xtrain = list(map(lambda x: x.drop(min_col, axis = 1), xtrain))
#         xtest = list(map(lambda x: x.drop(min_col, axis = 1), xtest))
#     print(f'{j} columns removed: {min_col}, best score is {score_dict_total[j]}; time elapsed is {datetime.now()-start}')
#     j+=1

# %%
# col_dict_total_neighborhood

# %%
# score_dict_total

# %%
# train, test = train_test_split(df3, test_size = 0.2, shuffle = True, random_state = 0)
# x_train = train.drop(columns = 'SalePrice_log')
# x_test = test.drop(columns = 'SalePrice_log')
# y_train = train['SalePrice_log']
# y_test = test['SalePrice_log']

# %%
# x_train2, x_test2, y_train2, y_test2 = x_train.copy(), x_test.copy(), y_train.copy(), y_test.copy()
# feature_selection_df = df2.drop(columns = ['SalePrice_log'], axis = 1)
# score_dict_total={}
# col_dict_total={}
# j=1
# start = datetime.now()
# while len(feature_selection_df.columns)> 20:
#     score_dict={}
#     for col in feature_selection_df.columns:
#         if col in all_dummies:
#             x_train_red = drop_dummies(x_train2, col)
#             x_test_red = drop_dummies(x_test2, col)
#         else:
#             x_train_red = x_train2.drop(col, axis = 1)
#             x_test_red = x_test2.drop(col, axis = 1)
#         #adjust these lines to reflect your model
#         model = Lasso(alpha = 1e-6, normalize = True, max_iter = 1000, tol = 0.001).fit(x_train_red, y_train2)
#         score=model.score(x_test_red, y_test2)
#         score_dict[col]=score
#         #-------

#     min_col=max(score_dict.items(), key=lambda x: x[1])[0]
#     score_dict_total[j]=max(score_dict.items(), key=lambda x: x[1])[1]
#     col_dict_total[j]=min_col
#     feature_selection_df = feature_selection_df.drop(min_col,axis=1)
#     if min_col in all_dummies:
#         x_train2 = drop_dummies(x_train2, min_col)
#         x_test2 = drop_dummies(x_test2, min_col)
#     else:
#         x_train2 = x_train2.drop(min_col, axis = 1)
#         x_test2 = x_test2.drop(min_col, axis = 1)
#     print(f'{j} columns removed: {min_col}, best score is {score_dict_total[j]}; time elapsed is {datetime.now()-start}')
#     j+=1

# %%
droplist = ['TotalBsmtSF',
            'BsmtCond_ord',
            'BsmtQual_ord',
            'GarageCond',
            'GarageQual',
            'GarageType_com',
            'SalePrice_log',
            'Garage_age_bin',
            'Remod_age_bin',
            '1stFlrSF_log',
            '2ndFlrSF',
            'KitchenAbvGr',
            'TotRmsAbvGrd',
            'GarageArea',
            'GarageFinish',
            'Fence',
            'Alley',
            'number_floors',
            'FireplaceQu',
            'LotFrontage',
            'LowQualFinSF',
            'BsmtExposure_ord',
            'MasVnrArea'
           ]

droplist3 = ['SalePrice_log']

# %%
df3 = dummify_linear(df2, to_dummify, droplist)
# Out:
# before dummifying:  (2468, 58)
# after garage stuff:  (2468, 58)
# after basement stuff:  (2468, 58)
# after full dummification:  (2468, 122)

# %%
params_log = {'alpha' : [1e-7, 1e-6, 1e-5, 1e-4]
          }

# %%
lasso2 = Lasso(normalize = True, max_iter = 1000, tol = 0.001)
lasso_tuner2 = GridSearchCV(lasso2, params_log, cv=kfold, return_train_score = True)
lasso_tuner2.fit(df3, price_log)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=Lasso(normalize=True, tol=0.001),
#              param_grid={'alpha': [1e-07, 1e-06, 1e-05, 0.0001]},
#              return_train_score=True)

# %%
#lasso_tuner2.cv_results_

# %%
lasso_tuner2.cv_results_['mean_test_score']
# Out:
# array([0.94652735, 0.94684074, 0.94405976, 0.91442563])

# %%
lasso_tuner2.cv_results_['mean_train_score']
# Out:
# array([0.95495403, 0.95483818, 0.95089   , 0.919555  ])

# %%
feat_imp_log = pd.Series(data = lasso_tuner2.best_estimator_.coef_, index = df3.columns)
feat_imp_log = feat_imp_log.sort_values(ascending = False)
ignored_log = feat_imp_log[feat_imp_log == 0]
feat_imp_log = feat_imp_log[feat_imp_log != 0]
print(len(feat_imp_log))
print(feat_imp_log)
print(len(ignored_log))
print(ignored_log)
# Out:
# 116
# GrLivArea_log                                                 0.424936
# OverallQual_10                                                0.184730
# OverallQual_9                                                 0.152125
# OverallCond_9                                                 0.135703
# OverallCond_8                                                 0.120612
# OverallCond_7                                                 0.108493
# OverallQual_8                                                 0.105671
# LotArea_log                                                   0.098530
# OverallCond_6                                                 0.084854
# OverallQual_7                                                 0.074826
# OverallCond_5                                                 0.068409
# Functional_ord_7                                              0.067265
# OverallQual_6                                                 0.055502
# Functional_ord_5                                              0.046105
# OverallCond_4                                                 0.043039
# OverallQual_5                                                 0.042932
# Functional_ord_6                                              0.041789
# Neighborhood_Greens                                           0.036999
# Functional_ord_4                                              0.036555
# Neighborhood_Crawfor                                          0.033615
# ext_Brick                                                     0.029259
# Neighborhood_StoneBr                                          0.025945
# OverallQual_4                                                 0.023874
# attic_Unfinished                                              0.022879
# Heating_com_Gas-powered water/steam heating                   0.019947
# KitchenQual_5                                                 0.019162
# LotConfig_com_Cul-de-sac lot                                  0.018551
# CentralAir_Y                                                  0.018344
# LotConfig_com_Inside lot (1 side frontage)                    0.017793
# GarageCars                                                    0.017404
# Neighborhood_Somerst                                          0.016673
# ext_Stucco                                                    0.016149
# HeatingQC_ord_5                                               0.015739
# Pool                                                          0.014757
# Neighborhood_Blueste                                          0.014643
# MSZoning_com_Residential, village                             0.014442
# LotConfig_com_Corner lot                                      0.014132
# LandContour_Hillside (downward slope on both sides)           0.013065
# ExterQual_5                                                   0.012333
# MSZoning_com_Residential, low density                         0.011735
# PavedDrive_Paved                                              0.011570
# HeatingQC_ord_4                                               0.011034
# Neighborhood_BrkSide                                          0.009844
# Fireplaces                                                    0.009397
# Neighborhood_ClearCr                                          0.009005
# Foundation_PConc                                              0.008610
# Neighborhood_NridgHt                                          0.008581
# BsmtFullBath                                                  0.008483
# Neighborhood_NoRidge                                          0.008310
# Electrical_com_Standard circuit breakers, all Romex wiring    0.008250
# KitchenQual_4                                                 0.007540
# RoofStyle_Other                                               0.007338
# attic_No attic                                                0.006463
# HeatingQC_ord_3                                               0.006298
# FullBath                                                      0.005876
# ExterCond_3                                                   0.005490
# ExterCond_4                                                   0.005368
# ext_Other                                                     0.005191
# LandContour_Level                                             0.005129
# LandSlope_Moderate-severe                                     0.005121
# Foundation_CBlock                                             0.004752
# BsmtHalfBath                                                  0.004750
# ext_Cement_Board                                              0.004322
# ext_Vinyl_Siding                                              0.004080
# Electrical_com_>60 Amp fuse box, all Romex wiring             0.003519
# HalfBath                                                      0.002606
# MasVnrType_Stone                                              0.002487
# LF_Near_Positive_Feature                                      0.001886
# ExterQual_4                                                   0.001871
# LotShape_com_Regular                                          0.000542
# ScreenPorch                                                   0.000083
# BSMT_GLQ                                                      0.000079
# BSMT_ALQ                                                      0.000067
# BSMT_BLQ                                                      0.000057
# 3SsnPorch                                                     0.000043
# BSMT_Rec                                                      0.000041
# EnclosedPorch                                                 0.000040
# OpenPorchSF                                                   0.000038
# BsmtUnfSF                                                     0.000035
# BSMT_LwQ                                                      0.000034
# WoodDeckSF                                                    0.000023
# Foundation_Other                                             -0.000085
# LandContour_Depression (upward slope on both sides)          -0.000128
# Heating_com_Other                                            -0.000380
# ext_Metal_Siding                                             -0.000918
# house_age_years                                              -0.001029
# LotShape_com_Slightly irregular                              -0.001139
# ext_Wood                                                     -0.001625
# RoofStyle_Hip                                                -0.001819
# PavedDrive_Partial Pavement                                  -0.002083
# BedroomAbvGr                                                 -0.003380
# MasVnrType_None                                              -0.003522
# Neighborhood_Sawyer                                          -0.008083
# Neighborhood_SWISU                                           -0.008362
# Neighborhood_BrDale                                          -0.008422
# Neighborhood_IDOTRR                                          -0.008660
# Neighborhood_Veenker                                         -0.008959
# Neighborhood_NPkVill                                         -0.010294
# Neighborhood_Timber                                          -0.011346
# BldgType_Twnhs                                               -0.012016
# LF_Near_NS_RR                                                -0.014666
# Neighborhood_NAmes                                           -0.015030
# Neighborhood_CollgCr                                         -0.015586
# BldgType_2fmCon                                              -0.015923
# Neighborhood_OldTown                                         -0.016109
# Neighborhood_Mitchel                                         -0.017529
# LF_Adjacent_Feeder_St                                        -0.018874
# Neighborhood_Gilbert                                         -0.019329
# ext_Asbestos_Shingles                                        -0.022353
# Neighborhood_SawyerW                                         -0.025752
# Neighborhood_NWAmes                                          -0.025886
# Neighborhood_Edwards                                         -0.028737
# LF_Near_EW_RR                                                -0.028860
# LF_Adjacent_Arterial_St                                      -0.029332
# BldgType_Duplex                                              -0.043372
# Neighborhood_MeadowV                                         -0.046939
# dtype: float64
# 6
# PUD_1                                      -0.0
# KitchenQual_3                              -0.0
# MSZoning_com_Residential, medium density   -0.0
# ExterCond_5                                -0.0
# ExterQual_3                                 0.0
# BldgType_TwnhsE                             0.0
# dtype: float64

# %%
# preds_log = lasso_tuner2.predict(df4)

# fig = px.scatter(x = preds_log, y = price_log, hover_name = df['PID'])
# fig.update_layout(
#                     xaxis_title = 'predicted',
#                     yaxis_title = 'actual'
#                 )

# %%
# resid = abs(preds_log - price_log)

# fig = px.histogram(x = resid)
# fig.update_layout(
#                     xaxis_title = 'residuals'
#                 )

# %%
# 10**np.mean(price_log)*(1-lasso_tuner2.best_score_)

# %%
df4 = dummify_linear(df2, to_dummify, droplist)
# Out:
# before dummifying:  (2468, 58)
# after garage stuff:  (2468, 58)
# after basement stuff:  (2468, 58)
# after full dummification:  (2468, 122)

# %%
vif_df = pd.DataFrame()
vif_df['feature'] = df4.columns
vif_df['vif'] = [variance_inflation_factor(df4.values, i)
                          for i in range(len(df4.columns))]

# %%
vif_df.sort_values(by = 'vif', ascending = False)
# Out:
#                                                feature          vif
# 32                                       GrLivArea_log  1776.147576
# 18                                         LotArea_log  1090.567331
# 105              MSZoning_com_Residential, low density   110.706635
# 121                                   Functional_ord_7   107.133418
# 85                                         ExterQual_3    86.942267
# 117                                              PUD_1    69.136631
# 111  Electrical_com_Standard circuit breakers, all ...    68.557545
# 88                                         ExterCond_3    58.967279
# 86                                         ExterQual_4    49.952552
# 67                                     BldgType_TwnhsE    45.445438
# 76                                       OverallCond_5    44.324427
# 37                                   LandContour_Level    33.159927
# 94                                        CentralAir_Y    32.967088
# 5                                         BedroomAbvGr    31.119033
# 3                                             FullBath    28.657537
# 69                                       OverallQual_5    27.617167
# 106           MSZoning_com_Residential, medium density    27.263186
# 95                                       KitchenQual_3    26.993147
# 70                                       OverallQual_6    26.616501
# 51                                  Neighborhood_NAmes    26.068217
# 33                                     house_age_years    25.798390
# 103                               LotShape_com_Regular    24.920653
# 102                                    HeatingQC_ord_5    24.431782
# 114         LotConfig_com_Inside lot (1 side frontage)    24.391795
# 96                                       KitchenQual_4    24.133391
# 99                                    PavedDrive_Paved    23.597273
# 71                                       OverallQual_7    23.315080
# 66                                      BldgType_Twnhs    23.208624
# 56                                Neighborhood_OldTown    18.170376
# 19                                            ext_Wood    16.995878
# 77                                       OverallCond_6    16.084972
# 21                                    ext_Vinyl_Siding    15.470783
# 7                                           GarageCars    14.904791
# 72                                       OverallQual_8    14.741278
# 43                                Neighborhood_CollgCr    13.888941
# 115                                     attic_No attic    13.646073
# 60                                Neighborhood_Somerst    13.191760
# 100                                    HeatingQC_ord_3    12.939292
# 104                    LotShape_com_Slightly irregular    12.598791
# 78                                       OverallCond_7    12.535255
# 93                                    Foundation_PConc    12.130232
# 107                  MSZoning_com_Residential, village    11.628841
# 45                                Neighborhood_Edwards    10.867120
# 91                                   Foundation_CBlock     9.839210
# 58                                 Neighborhood_Sawyer     9.539992
# 46                                Neighborhood_Gilbert     9.326203
# 0                                            BsmtUnfSF     8.537684
# 89                                         ExterCond_4     8.420825
# 41                                Neighborhood_BrkSide     8.349886
# 53                                 Neighborhood_NWAmes     8.294148
# 101                                    HeatingQC_ord_4     8.253098
# 55                                Neighborhood_NridgHt     7.931198
# 20                                    ext_Metal_Siding     7.314915
# 59                                Neighborhood_SawyerW     7.156091
# 68                                       OverallQual_4     7.032725
# 50                                Neighborhood_Mitchel     7.018024
# 44                                Neighborhood_Crawfor     6.920612
# 87                                         ExterQual_5     6.678825
# 27                                            BSMT_GLQ     6.611074
# 112                           LotConfig_com_Corner lot     6.449935
# 73                                       OverallQual_9     5.997545
# 48                                 Neighborhood_IDOTRR     5.847475
# 79                                       OverallCond_8     5.839658
# 97                                       KitchenQual_5     5.454515
# 110  Electrical_com_>60 Amp fuse box, all Romex wiring     5.278834
# 54                                Neighborhood_NoRidge     5.040437
# 83                                     MasVnrType_None     4.663891
# 49                                Neighborhood_MeadowV     4.357050
# 62                                 Neighborhood_Timber     4.114846
# 1                                         BsmtFullBath     4.008790
# 119                                   Functional_ord_5     3.991898
# 57                                  Neighborhood_SWISU     3.723337
# 120                                   Functional_ord_6     3.614298
# 61                                Neighborhood_StoneBr     3.585644
# 42                                Neighborhood_ClearCr     3.448280
# 23                                    ext_Cement_Board     3.403751
# 75                                       OverallCond_4     3.288105
# 113                       LotConfig_com_Cul-de-sac lot     3.220473
# 4                                             HalfBath     3.217776
# 6                                           Fireplaces     3.204830
# 40                                 Neighborhood_BrDale     3.117099
# 28                                            BSMT_ALQ     2.906947
# 80                                       OverallCond_9     2.751007
# 74                                      OverallQual_10     2.633684
# 52                                Neighborhood_NPkVill     2.623904
# 36   LandContour_Hillside (downward slope on both s...     2.449923
# 118                                   Functional_ord_4     2.430478
# 63                                Neighborhood_Veenker     2.373552
# 8                                           WoodDeckSF     2.037963
# 9                                          OpenPorchSF     1.995828
# 29                                            BSMT_BLQ     1.987997
# 24                                           ext_Brick     1.922938
# 35   LandContour_Depression (upward slope on both s...     1.918868
# 31                                            BSMT_Rec     1.833272
# 39                                Neighborhood_Blueste     1.781618
# 38                           LandSlope_Moderate-severe     1.736506
# 92                                    Foundation_Other     1.711884
# 81                                       RoofStyle_Hip     1.621914
# 47                                 Neighborhood_Greens     1.616541
# 90                                         ExterCond_5     1.559794
# 84                                    MasVnrType_Stone     1.554902
# 65                                     BldgType_Duplex     1.541016
# 98                         PavedDrive_Partial Pavement     1.521404
# 22                                          ext_Stucco     1.503315
# 10                                       EnclosedPorch     1.485438
# 25                               ext_Asbestos_Shingles     1.452764
# 30                                            BSMT_LwQ     1.367507
# 109                                  Heating_com_Other     1.355484
# 2                                         BsmtHalfBath     1.295460
# 64                                     BldgType_2fmCon     1.287804
# 116                                   attic_Unfinished     1.276875
# 12                                         ScreenPorch     1.259392
# 17                               LF_Adjacent_Feeder_St     1.256895
# 108        Heating_com_Gas-powered water/steam heating     1.249569
# 15                             LF_Adjacent_Arterial_St     1.216068
# 13                                       LF_Near_NS_RR     1.207903
# 14                            LF_Near_Positive_Feature     1.176096
# 16                                       LF_Near_EW_RR     1.175394
# 26                                           ext_Other     1.171488
# 82                                     RoofStyle_Other     1.161065
# 34                                                Pool     1.113215
# 11                                           3SsnPorch     1.067970

# %%
print('No radials: ', droplist, ': ', lasso_tuner2.best_params_['alpha'], ', ', max(lasso_tuner2.cv_results_['mean_test_score']), ', ', sum(vif_df['vif'])/len(vif_df))
# Out:
# No radials:  ['TotalBsmtSF', 'BsmtCond_ord', 'BsmtQual_ord', 'GarageCond', 'GarageQual', 'GarageType_com', 'SalePrice_log', 'Garage_age_bin', 'Remod_age_bin', '1stFlrSF_log', '2ndFlrSF', 'KitchenAbvGr', 'TotRmsAbvGrd', 'GarageArea', 'GarageFinish', 'Fence', 'Alley', 'number_floors', 'FireplaceQu', 'LotFrontage', 'LowQualFinSF', 'BsmtExposure_ord', 'MasVnrArea'] :  1e-06 ,  0.9468407408759749 ,  36.57884336374308

# %% [markdown]
# log:  ['TotalBsmtSF', 'BsmtCond_ord', 'BsmtQual_ord', 'GarageCond', 'GarageQual', 'GarageType_com', 'SalePrice_log', 'Garage_age_bin', 'Remod_age_bin'] :  1e-06 ,  0.943454281780628
#
# log:  ['TotalBsmtSF', 'BsmtCond_ord', 'BsmtQual_ord', 'GarageCond', 'GarageQual', 'GarageType_com', 'SalePrice_log', 'Garage_age_bin', 'Remod_age_bin', '1stFlrSF_log'] :  1e-06 ,  0.9424740060473317
#
# log:  ['TotalBsmtSF', 'BsmtCond_ord', 'BsmtQual_ord', 'GarageCond', 'GarageQual', 'GarageType_com', 'SalePrice_log', 'Garage_age_bin', 'Remod_age_bin', '1stFlrSF_log', '2ndFlrSF'] :  1e-06 ,  0.9420770647332499
#
# log:  ['TotalBsmtSF', 'BsmtCond_ord', 'BsmtQual_ord', 'GarageCond', 'GarageQual', 'GarageType_com', 'SalePrice_log', 'Garage_age_bin', 'Remod_age_bin', '1stFlrSF_log', '2ndFlrSF', 'KitchenAbvGr'] :  1e-06 ,  0.9417616764602397
#
# ['TotalBsmtSF', 'BsmtCond_ord', 'BsmtQual_ord', 'GarageCond', 'GarageQual', 'GarageType_com', 'SalePrice_log', 'Garage_age_bin', 'Remod_age_bin', '1stFlrSF_log', '2ndFlrSF', 'KitchenAbvGr', 'TotRmsAbvGrd', 'GarageArea'] :  1e-06 ,  0.9416195613781179 ,  39.9001979416710
#
# ['TotalBsmtSF', 'BsmtCond_ord', 'BsmtQual_ord', 'GarageCond', 'GarageQual', 'GarageType_com', 'SalePrice_log', 'Garage_age_bin', 'Remod_age_bin', '1stFlrSF_log', '2ndFlrSF', 'KitchenAbvGr', 'TotRmsAbvGrd', 'GarageArea', 'GarageFinish', 'Fence'] :  1e-06 ,  0.9417193728756516 ,  41.05487105565105
#
# ['TotalBsmtSF', 'BsmtCond_ord', 'BsmtQual_ord', 'GarageCond', 'GarageQual', 'SalePrice_log', 'Garage_age_bin', 'Remod_age_bin', '1stFlrSF_log', '2ndFlrSF', 'KitchenAbvGr', 'TotRmsAbvGrd', 'GarageArea', 'GarageFinish', 'Fence'] :  1e-06 ,  0.9416530339287166 ,  39.99237976054064
#
# ['TotalBsmtSF', 'BsmtCond_ord', 'BsmtQual_ord', 'GarageCond', 'GarageQual', 'GarageType_com', 'SalePrice_log', 'Garage_age_bin', 'Remod_age_bin', '1stFlrSF_log', '2ndFlrSF', 'KitchenAbvGr', 'TotRmsAbvGrd', 'GarageArea', 'GarageFinish', 'Fence', 'Alley'] :  1e-06 ,  0.9417665575176081 ,  41.1929734948757
#
# ['TotalBsmtSF', 'BsmtCond_ord', 'BsmtQual_ord', 'GarageCond', 'GarageQual', 'GarageType_com', 'SalePrice_log', 'Garage_age_bin', 'Remod_age_bin', '1stFlrSF_log', '2ndFlrSF', 'KitchenAbvGr', 'TotRmsAbvGrd', 'GarageArea', 'GarageFinish', 'Fence', 'Alley', 'number_floors'] :  1e-06 ,  0.9418035097906687 ,  39.559875261890845
#
# ['TotalBsmtSF', 'BsmtCond_ord', 'BsmtQual_ord', 'GarageCond', 'GarageQual', 'GarageType_com', 'SalePrice_log', 'Garage_age_bin', 'Remod_age_bin', '1stFlrSF_log', '2ndFlrSF', 'KitchenAbvGr', 'TotRmsAbvGrd', 'GarageArea', 'GarageFinish', 'Fence', 'Alley', 'number_floors', 'FireplaceQu'] :  1e-06 ,  0.9417500104695516 ,  40.30945260646638
#
# ['TotalBsmtSF', 'BsmtCond_ord', 'BsmtQual_ord', 'GarageCond', 'GarageQual', 'GarageType_com', 'SalePrice_log', 'Garage_age_bin', 'Remod_age_bin', '1stFlrSF_log', '2ndFlrSF', 'KitchenAbvGr', 'TotRmsAbvGrd', 'GarageArea', 'GarageFinish', 'Fence', 'Alley', 'number_floors', 'FireplaceQu', 'LotFrontage', 'LowQualFinSF', 'BsmtExposure_ord', 'MasVnrArea'] :  1e-06 ,  0.9468407408759749 ,  36.57884336374308
#
# No radials:  ['TotalBsmtSF', 'BsmtCond_ord', 'BsmtQual_ord', 'GarageCond', 'GarageQual', 'GarageType_com', 'SalePrice_log', 'Garage_age_bin', 'Remod_age_bin', '1stFlrSF_log', '2ndFlrSF', 'KitchenAbvGr', 'TotRmsAbvGrd', 'GarageArea', 'GarageFinish', 'Fence', 'Alley', 'number_floors', 'FireplaceQu', 'LotFrontage', 'LowQualFinSF', 'BsmtExposure_ord', 'MasVnrArea', 'LotShape_com'] :  1e-06 ,  0.946833771716485 ,  35.69657081462711

# %%
radial = pd.read_csv('./../data/house_coordinates_1.0.csv')
radial.drop(columns = ('2204_park'), inplace = True)
for col in radial.columns:
    prefix = str(col)[0:4]
    if re.search('^\d\d\d\d_', str(col)):
        radial.rename(columns = {col: col[5:]}, inplace = True)

rad_drops = [
    'Address',
    'Coords4',
    'latitude',
    'longitude',
    'town_hall',
    'cemetery',
    'motel',
    'camp_site',
    'general',
    'picnic_site',
    'wastewater_plant',
    'spring',
    'beach',
    'street_lamp',
    'helipad',
    'vineyard',
    'crossing',
    'tree',
    'grass',
    'christian',
    'bus_stop',
    'parking',
    'toilet',
    'bench',
    'commercial',
    'waste_basket',
    'drinking_water',
    'convenience',
    'camera_surveillance',
    'comms_tower',
    'residential',
    'gift_shop',
    'jeweller',
    'hairdresser',
    'bookshop',
    'clothes',
    'retail',
    'food_court',
    'artwork',
    'cafe',
    'traffic_signals',
    'beauty_shop',
    'sports_shop',
    'weir',
    'track',
    'turning_circle',
    'computer_shop',
    'bicycle_shop',
    'department_store',
    'parking_bicycle',
    'golf_course',
    'tower',
    'beverages',
    'university'
]

radial.drop(columns = rad__drops, inplace = True)
sub = df.loc[:,['PID', 'SalePrice_log']]
radial = pd.merge(radial, sub, how = 'right', on = 'PID')

# %%
radial.drop(columns = ['PID','SalePrice_log'], inplace = True)

# %%
lasso_tuner3 = GridSearchCV(lasso2, params_log, cv=kfold, return_train_score = True)
lasso_tuner3.fit(radial, price_log)
# Out:
# C:\Users\fayma\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.955116797256687, tolerance: 0.05305141285654394
#
# C:\Users\fayma\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.381514007039373, tolerance: 0.052336872663819166
#
# C:\Users\fayma\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.427493329731139, tolerance: 0.051061058295919795
#
# C:\Users\fayma\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.7689193441595865, tolerance: 0.052618075782521756
#
# C:\Users\fayma\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.586756643909953, tolerance: 0.05453971457129174
#
# C:\Users\fayma\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.19609948564901458, tolerance: 0.05305141285654394
#
# C:\Users\fayma\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2770455097750393, tolerance: 0.052336872663819166
#
# C:\Users\fayma\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4425173706106875, tolerance: 0.051061058295919795
#
# C:\Users\fayma\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5051031410125191, tolerance: 0.052618075782521756
#
# C:\Users\fayma\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5227360827881995, tolerance: 0.05453971457129174
#
# C:\Users\fayma\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4317215006261641, tolerance: 0.06590422769382415
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=Lasso(normalize=True, tol=0.001),
#              param_grid={'alpha': [1e-07, 1e-06, 1e-05, 0.0001]},
#              return_train_score=True)

# %%
lasso_tuner3.cv_results_['mean_test_score']
# Out:
# array([0.54699519, 0.54812924, 0.5465938 , 0.4685587 ])

# %%
lasso_tuner3.cv_results_['mean_train_score']
# Out:
# array([0.58798742, 0.58786236, 0.57901633, 0.48368547])

# %%
len(radial.columns)
# Out:
# 81

# %%
feat_imp_rad = pd.Series(data = lasso_tuner3.best_estimator_.coef_, index = radial.columns)
feat_imp_rad = feat_imp_rad.sort_values(ascending = False)
ignored_rad = feat_imp_rad[feat_imp_rad == 0]
feat_imp_rad = feat_imp_rad[feat_imp_rad != 0]
print(len(feat_imp_rad))
print(feat_imp_rad)
print(len(ignored_rad))
print(ignored_rad)
# Out:
# 81
# slipway                  0.166349
# garden_centre            0.158015
# guesthouse               0.100381
# stop                     0.084030
# library                  0.075354
# dam                      0.059508
# furniture_shop           0.045728
# christian_catholic       0.041627
# stationery               0.040014
# viewpoint                0.039960
# pier                     0.038627
# laundry                  0.038289
# tourist_info             0.037387
# theatre                  0.035459
# recreation_ground        0.035184
# pub                      0.034113
# dog_park                 0.033463
# doctors                  0.031921
# water_tower              0.031064
# apron                    0.026628
# scrub                    0.025461
# hotel                    0.024240
# shoe_shop                0.022265
# jewish                   0.020430
# pharmacy                 0.017237
# playground               0.017033
# christian_lutheran       0.016568
# doityourself             0.015603
# fire_station             0.014000
# nursing_home             0.012592
# fountain                 0.011757
# mall                     0.009288
# motorway_junction        0.009224
# fuel                     0.008826
# christian_methodist      0.007636
# water                    0.006335
# bar                      0.005104
# forest                   0.002837
# farmyard                 0.002145
# swimming_pool            0.001914
# car_dealership           0.001766
# shelter                  0.001278
# farmland                 0.001163
# cinema                   0.000315
# christian_evangelical   -0.001649
# nature_reserve          -0.001745
# supermarket             -0.001988
# pitch                   -0.002273
# bank                    -0.002726
# reservoir               -0.002861
# post_office             -0.003337
# fast_food               -0.005393
# water_works             -0.005627
# industrial              -0.005636
# park                    -0.006000
# restaurant              -0.007763
# memorial                -0.008798
# meadow                  -0.009906
# mobile_phone_shop       -0.015481
# bakery                  -0.015569
# optician                -0.016746
# stadium                 -0.017481
# graveyard               -0.017883
# museum                  -0.022139
# atm                     -0.022160
# wetland                 -0.028519
# florist                 -0.031371
# parking_multistorey     -0.032002
# sports_centre           -0.033778
# outdoor_shop            -0.034000
# school                  -0.035465
# dentist                 -0.044969
# airport                 -0.050679
# police                  -0.052602
# car_wash                -0.053668
# muslim                  -0.060106
# hospital                -0.060318
# post_box                -0.062534
# attraction              -0.063319
# orchard                 -0.084634
# veterinary              -0.151798
# dtype: float64
# 0
# Series([], dtype: float64)

# %%
vif_rad = pd.DataFrame()
vif_rad['feature'] = radial.columns
vif_rad['vif'] = [variance_inflation_factor(radial.values, i)
                          for i in range(len(radial.columns))]

# %%
print(sum(vif_rad['vif'])/len(vif_rad))
vif_rad.sort_values(by = 'vif', ascending = False)
# Out:
# 32.204337348989
#                   feature         vif
# 15             playground  116.533916
# 21             restaurant  114.899792
# 69                   park  102.726909
# 24                    bar   96.702999
# 43                   bank   94.417276
# 62    parking_multistorey   87.607495
# 68                 forest   84.558339
# 44                    atm   82.510259
# 61                   fuel   75.957378
# 27                shelter   71.289965
# 22              fast_food   69.993617
# 3             post_office   69.819884
# 29                 bakery   60.732603
# 18                  pitch   60.555404
# 78                  water   57.917663
# 32              shoe_shop   54.523075
# 37         car_dealership   49.320143
# 10                doctors   46.133686
# 39         furniture_shop   45.895593
# 8                pharmacy   44.960771
# 2                post_box   42.957733
# 28            supermarket   42.343238
# 74                orchard   39.201241
# 38           doityourself   37.120942
# 50               fountain   36.055716
# 41               car_wash   34.904780
# 33               optician   34.474937
# 55     christian_lutheran   32.678662
# 11                dentist   32.536563
# 42                laundry   31.465341
# 7                  school   31.377559
# 45           tourist_info   30.713714
# 47                 museum   29.645590
# 9                hospital   29.612098
# 77               farmland   27.898961
# 48               memorial   26.539794
# 13                theatre   26.094219
# 23                    pub   24.455558
# 17          sports_centre   23.903529
# 4                 library   21.534026
# 51            water_tower   21.529389
# 0                  police   21.142012
# 1            fire_station   20.864115
# 14                 cinema   20.057891
# 73      recreation_ground   19.021116
# 26             guesthouse   18.956310
# 53     christian_catholic   18.730382
# 31                florist   18.689611
# 25                  hotel   17.076883
# 30                   mall   16.479029
# 76               farmyard   16.409547
# 56    christian_methodist   16.244047
# 49              viewpoint   16.178197
# 35           outdoor_shop   16.102149
# 12             veterinary   15.791515
# 19          swimming_pool   14.944492
# 71                 meadow   14.263101
# 36      mobile_phone_shop   14.044149
# 54  christian_evangelical   13.257225
# 20                stadium   12.948040
# 5            nursing_home   12.071305
# 6               graveyard   11.893035
# 79              reservoir   10.825448
# 16               dog_park   10.566311
# 60      motorway_junction   10.409193
# 75                  scrub    9.568731
# 80                wetland    9.282402
# 72         nature_reserve    8.329604
# 57                 jewish    7.809953
# 46             attraction    7.535911
# 70             industrial    7.449457
# 58                 muslim    5.327920
# 59                   stop    5.297485
# 64                   pier    4.534754
# 63                slipway    4.245657
# 67                  apron    4.102028
# 40          garden_centre    4.065908
# 66                airport    3.270405
# 52            water_works    3.055168
# 34             stationery    2.126526
# 65                    dam    1.483957

# %%
df6 = df.copy()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
def fit_scale(df, col):
    scaler.fit(df[[col]])
    df[[col]]=scaler.transform(df[[col]])
fit_scale(df6, 'OverallQual')
fit_scale(df6, 'ExterQual')
fit_scale(df6, 'OverallCond')
fit_scale(df6, 'KitchenQual')
#df2['Porch']=((df2['OpenPorchSF']>0) | (df2['EnclosedPorch']>0) | (df2['3SsnPorch']>0) | (df2['ScreenPorch']>0))
df6['PorchSF']=df6['OpenPorchSF']+df6['EnclosedPorch']+df6['3SsnPorch']+df6['ScreenPorch']
#df2['1stFloorArea%']=df2['1stFlrSF']/df2['GrLivArea']
#df2['2ndFloorArea%']=df2['2ndFlrSF']/df2['GrLivArea']
df6['ExterQualDisc']=df6['OverallQual']-df6['ExterQual']
df6['OverallCondDisc']=df6['OverallQual']-df6['OverallCond']
df6['KitchenQualDisc']=df6['OverallQual']-df6['KitchenQual']
#df2['BSMT_GLQ%']=df2['BSMT_GLQ']/df2['TotalBsmtSF']
#df2['BSMT_ALQ%']=df2['BSMT_ALQ']/df2['TotalBsmtSF']
#df2['BSMT_GLQ%']=df2['BSMT_GLQ%'].fillna(0)
#df2['BSMT_ALQ%']=df2['BSMT_ALQ%'].fillna(0)
df6['BSMT_LowQual']=df6['TotalBsmtSF']-df6['BSMT_GLQ']-df6['BSMT_ALQ']
df6['BSMT_HighQual']=df6['BSMT_GLQ']+df6['BSMT_ALQ']

# %%
df6['BSMT_HighQual_bin'] = pd.cut(df6['BSMT_HighQual'], [-1, 1, 500, 1000, 1500, 2500], labels = ['No basement', '0-500', '500-1000', '1000-1500', '1500+'])

# %%
df6['BSMT_LowQual_bin'] = pd.cut(df6['BSMT_LowQual'], [-1, 1, 500, 1000, 1500, 2500], labels = ['No basement', '0-500', '500-1000', '1000-1500', '1500+'])

# %%
feat_incl = ['GrLivArea_log', 'LotArea_log', 'OverallQual',
    'BSMT_LowQual_bin', 'house_age_years', 'GarageCars','MasVnrType',
                 'FullBath','HalfBath',
                'BsmtExposure_ord',
                 'Neighborhood',
                 'BldgType','PorchSF',
                 'ExterQualDisc','OverallCondDisc','BSMT_HighQual_bin',
                 'KitchenQualDisc',
                'Fireplaces','Pool','BedroomAbvGr'
]

# %%
df7 = df6.loc[:,feat_incl]
df7
# Out:
#       GrLivArea_log  LotArea_log  OverallQual BSMT_LowQual_bin  \
# 0          2.932474     3.897077     0.428571         500-1000
# 1          3.020775     3.626853     0.285714            0-500
# 2          3.016616     3.910944     0.142857            0-500
# 3          3.221414     3.924279     0.714286            0-500
# 4          3.283753     3.863382     0.571429      No basement
# ...             ...          ...          ...              ...
# 2463       2.978637     3.947140     0.428571         500-1000
# 2464       3.238799     4.136086     0.000000      No basement
# 2465       3.301464     3.797268     0.285714        1000-1500
# 2466       3.265290     3.945764     0.571429            0-500
# 2467       3.281261     3.980185     0.714286            0-500
#
#       house_age_years  GarageCars  MasVnrType  FullBath  HalfBath  \
# 0           71.210959         2.0        None         1         0
# 1           25.104110         1.0  Brick Face         2         0
# 2          109.402740         1.0        None         1         0
# 3            8.838356         2.0        None         2         1
# 4            6.501370         2.0  Brick Face         3         0
# ...               ...         ...         ...       ...       ...
# 2463        93.394521         1.0        None         1         0
# 2464        54.452055         2.0        None         2         0
# 2465        58.619178         3.0        None         2         0
# 2466         7.501370         2.0  Brick Face         2         1
# 2467        13.673973         2.0  Brick Face         2         1
#
#       BsmtExposure_ord Neighborhood BldgType  PorchSF  ExterQualDisc  \
# 0                    1        SWISU     1Fam      166       0.095238
# 1                    2      Edwards   TwnhsE      105      -0.380952
# 2                    1      OldTown     1Fam      279      -0.523810
# 3                    1       NWAmes     1Fam       45       0.047619
# 4                    0      Edwards     1Fam      177      -0.095238
# ...                ...          ...      ...      ...            ...
# 2463                 1      BrkSide     1Fam      138       0.095238
# 2464                 0      Edwards     1Fam        0      -0.333333
# 2465                 1      Crawfor   Duplex        0      -0.047619
# 2466                 1      CollgCr     1Fam       96      -0.095238
# 2467                 1      SawyerW     1Fam       81       0.047619
#
#       OverallCondDisc BSMT_HighQual_bin  KitchenQualDisc  Fireplaces  Pool  \
# 0           -0.071429       No basement         0.095238           1     0
# 1           -0.047619          500-1000        -0.380952           0     0
# 2           -0.690476       No basement        -0.190476           0     0
# 3            0.214286          500-1000         0.047619           0     0
# 4            0.238095       No basement        -0.095238           1     0
# ...               ...               ...              ...         ...   ...
# 2463        -0.071429       No basement         0.428571           1     0
# 2464        -0.333333       No basement        -0.333333           1     0
# 2465        -0.214286       No basement        -0.047619           0     0
# 2466         0.238095          500-1000        -0.095238           1     0
# 2467         0.380952             0-500         0.047619           1     0
#
#       BedroomAbvGr
# 0                2
# 1                2
# 2                2
# 3                3
# 4                4
# ...            ...
# 2463             2
# 2464             4
# 2465             4
# 2466             3
# 2467             3
#
# [2468 rows x 20 columns]

# %%
new_dummies = [
    'MasVnrType',
    'Neighborhood',
    'BldgType',
    'BSMT_HighQual_bin',
    'BSMT_LowQual_bin'
]

# %%
df7 = pd.get_dummies(df7, columns = new_dummies, drop_first = True)

# %%
lasso_tuner4 = GridSearchCV(lasso2, params_log, cv=kfold, return_train_score = True)
lasso_tuner4.fit(df7, price_log)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=Lasso(normalize=True, tol=0.001),
#              param_grid={'alpha': [1e-07, 1e-06, 1e-05, 0.0001]},
#              return_train_score=True)

# %%
lasso_tuner4.cv_results_['mean_test_score']
# Out:
# array([0.93379896, 0.9338685 , 0.93344913, 0.90884803])

# %%
vif_min = pd.DataFrame()
vif_min['feature'] = df7.columns
vif_min['vif'] = [variance_inflation_factor(df7.values, i)
                          for i in range(len(df7.columns))]

# %%
vif_min.sort_values(by = 'vif', ascending = False)
# Out:
#                         feature          vif
# 0                 GrLivArea_log  1112.811601
# 1                   LotArea_log   861.847378
# 2                   OverallQual    33.210726
# 14                 BedroomAbvGr    28.423777
# 5                      FullBath    24.791096
# 29           Neighborhood_NAmes    23.593395
# 3               house_age_years    16.203644
# 34         Neighborhood_OldTown    14.079238
# 4                    GarageCars    13.884706
# 21         Neighborhood_CollgCr    13.395188
# 51    BSMT_LowQual_bin_500-1000    12.603139
# 50       BSMT_LowQual_bin_0-500    11.891280
# 23         Neighborhood_Edwards    10.143338
# 36          Neighborhood_Sawyer     8.756239
# 24         Neighborhood_Gilbert     8.702370
# 38         Neighborhood_Somerst     8.037663
# 31          Neighborhood_NWAmes     7.574067
# 33         Neighborhood_NridgHt     7.350421
# 19         Neighborhood_BrkSide     7.024195
# 52   BSMT_LowQual_bin_1000-1500     6.922026
# 37         Neighborhood_SawyerW     6.771532
# 28         Neighborhood_Mitchel     6.565721
# 22         Neighborhood_Crawfor     6.312506
# 7              BsmtExposure_ord     5.333179
# 32         Neighborhood_NoRidge     4.721775
# 26          Neighborhood_IDOTRR     4.452362
# 15              MasVnrType_None     4.326039
# 40          Neighborhood_Timber     3.844991
# 47   BSMT_HighQual_bin_500-1000     3.740038
# 10              OverallCondDisc     3.533564
# 35           Neighborhood_SWISU     3.475466
# 20         Neighborhood_ClearCr     3.175153
# 39         Neighborhood_StoneBr     3.113269
# 12                   Fireplaces     2.924297
# 27         Neighborhood_MeadowV     2.910896
# 53       BSMT_LowQual_bin_1500+     2.869870
# 6                      HalfBath     2.821706
# 48  BSMT_HighQual_bin_1000-1500     2.684153
# 18          Neighborhood_BrDale     2.573412
# 44               BldgType_Twnhs     2.523686
# 45              BldgType_TwnhsE     2.309996
# 30         Neighborhood_NPkVill     2.188268
# 41         Neighborhood_Veenker     2.169540
# 8                       PorchSF     2.061240
# 9                 ExterQualDisc     1.827303
# 46      BSMT_HighQual_bin_0-500     1.694183
# 11              KitchenQualDisc     1.677453
# 17         Neighborhood_Blueste     1.531570
# 49      BSMT_HighQual_bin_1500+     1.496239
# 25          Neighborhood_Greens     1.480385
# 43              BldgType_Duplex     1.467653
# 16             MasVnrType_Stone     1.461317
# 42              BldgType_2fmCon     1.145207
# 13                         Pool     1.042981
