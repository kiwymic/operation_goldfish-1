# %%
import numpy as np
import pandas as pd
from scipy import stats
from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression
import plotly.express as px
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.model_selection import cross_val_score
import time
import re
pd.set_option('display.max_rows', 500)

# %%
import numpy as np
import pandas as pd
import plotly.express as px
from scipy import stats
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm as anova

def EDA_plots(df, features = None, targets = ['SalePrice']):
    '''
    EDA_plots: a function to automate basic preliminary EDA on [features] vs [targets]
    
    args:
        df: a dataframe
        features: a list of column names to run the basic EDA functions on. If nothing is passed, all features will be used.
        targets: a list of column names to use as targets in the basic EDA functions. If nothing is passed, ['SalePrice'] 
                 will be used.
        
    output:
        - Prints scatterplots and boxplots of [features] vs [targets]
        - Prints histograms of [features]
        - Uses crude method of datatype == str to decide whether to treat a feature as categorical or continuous
            - If the data in a column is of string type, dummifies that column and runs multiple linear regressions 
              on the dummies vs [targets]
            - If you would rather do simple anovas than the dummified multiple regressions, there is commented-out
              code which you can uncomment to do anovas instead
            - If the data in a column is not string type, runs simple linear regressions on that column vs [targets] 
              and prints the correlation and R^2 values
    '''
    # default features is None, in which case the function will use all features due to the first 2 lines below
    if features is None:
        features = df.columns
    
    
    for feature in features:
        for target in targets:
            if feature != target and feature != 'PID': # ignore unique identifier
                print('feature: ',feature) # print feature name
                # scatterplot
                scatter = px.scatter(x = df[feature], y = df[target])
                scatter.update_layout(
                    title={
                        'text': f'Scatterplot, {feature} vs {target}',
                        'y':0.95,
                        'x':0.5,
                        'xanchor': 'center',
                        'yanchor': 'top'},
                    xaxis_title = f'{feature}',
                    yaxis_title = f'{target}'
                )
                scatter.show()
                # histogram
                hist = px.histogram(x = df[feature])
                hist.update_layout(
                    title={
                        'text': f'Distribution of {feature}',
                        'y':0.95,
                        'x':0.5,
                        'xanchor': 'center',
                        'yanchor': 'top'},
                    xaxis_title = f'{feature}',
                    yaxis_title = 'Frequency'
                )
                hist.show()
                # boxplot
                box = px.box(x = df[feature], y = df[target])
                box.update_layout(
                    title={
                        'text': f'Boxplot, {feature} vs {target}',
                        'y':0.95,
                        'x':0.5,
                        'xanchor': 'center',
                        'yanchor': 'top'},
                    xaxis_title = f'{feature}',
                    yaxis_title = f'{target}'
                )
                box.show()
                # the dataset does not have unique indices, this fixes that
                temp = df[df[feature].isna() == False].reset_index(drop = True)
                
                if type(temp.loc[0, feature]) != str: # continuous
                    corr = temp[feature].corr(temp[target])
                    print(f'Correlation between {feature} and {target} is {corr}')
                    linreg = stats.linregress(temp[feature], temp[target] )
                    print(linreg)
                    print('r^2 = ',linreg.rvalue**2)
                if type(temp.loc[0, f'{feature}']) == str: # categorical
                    fit = ols(f'{target} ~ C({feature})', data=temp).fit()
                    print(fit.summary()) # comment this out and uncomment the below lines to get simpler anova
                    # anova_table = anova(fit, typ=2)
                    # print(anova_table)
            print()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.formula.api as smf


variables = lm.model.exog
vif = [variance_inflation_factor(variables, i) for i in range(variables.shape[1])]
vif

# %%
df['BldgType'].value_counts()
# Out:
# 1Fam      2070
# TwnhsE     200
# Twnhs       94
# Duplex      78
# 2fmCon      52
# Name: BldgType, dtype: int64

# %%
df = pd.read_csv('./../data/ames_housing_price_data_v4.csv')
radial = pd.read_csv('./../data/house_coordinates_1.0_.csv', index_col = 0)

for col in radial.columns:
    prefix = str(col)[0:4]
    if re.search('^\d\d\d\d_', str(col)):
        radial.rename(columns = {col: col[5:]}, inplace = True)
        
df = pd.merge(radial, df, how = 'right', on = 'PID')
df = df[(df['PID'] != 902207130) & (df['PID'] != 908154205)]
df = df[(df['SaleCondition'] == 'Normal') | (df['SaleCondition'] == 'Partial')]
df.reset_index(drop=True, inplace = True)

price = df['SalePrice']
price_log = df['SalePrice_log']

# %%
list(df.columns)
# Out:
# ['PID',
#  'Address',
#  'Coords4',
#  'latitude',
#  'longitude',
#  'police',
#  'fire_station',
#  'post_box',
#  'post_office',
#  'library',
#  'town_hall',
#  'nursing_home',
#  'graveyard',
#  'university',
#  'school',
#  'pharmacy',
#  'hospital',
#  'doctors',
#  'dentist',
#  'veterinary',
#  'theatre',
#  'cinema',
#  'park',
#  'playground',
#  'dog_park',
#  'sports_centre',
#  'pitch',
#  'swimming_pool',
#  'golf_course',
#  'stadium',
#  'track',
#  'restaurant',
#  'fast_food',
#  'cafe',
#  'pub',
#  'bar',
#  'food_court',
#  'hotel',
#  'motel',
#  'guesthouse',
#  'shelter',
#  'camp_site',
#  'supermarket',
#  'bakery',
#  'mall',
#  'department_store',
#  'general',
#  'convenience',
#  'clothes',
#  'florist',
#  'bookshop',
#  'shoe_shop',
#  'beverages',
#  'optician',
#  'jeweller',
#  'gift_shop',
#  'sports_shop',
#  'stationery',
#  'outdoor_shop',
#  'mobile_phone_shop',
#  'beauty_shop',
#  'car_dealership',
#  'bicycle_shop',
#  'doityourself',
#  'furniture_shop',
#  'computer_shop',
#  'garden_centre',
#  'hairdresser',
#  'car_wash',
#  'laundry',
#  'bank',
#  'atm',
#  'tourist_info',
#  'attraction',
#  'museum',
#  'memorial',
#  'artwork',
#  'picnic_site',
#  'viewpoint',
#  'toilet',
#  'bench',
#  'drinking_water',
#  'fountain',
#  'waste_basket',
#  'camera_surveillance',
#  'tower',
#  'comms_tower',
#  'water_tower',
#  'wastewater_plant',
#  'water_works',
#  'christian',
#  'christian_catholic',
#  'christian_evangelical',
#  'christian_lutheran',
#  'christian_methodist',
#  'jewish',
#  'muslim',
#  'spring',
#  'tree',
#  'beach',
#  'traffic_signals',
#  'stop',
#  'crossing',
#  'motorway_junction',
#  'turning_circle',
#  'street_lamp',
#  'fuel',
#  'parking',
#  'parking_multistorey',
#  'parking_bicycle',
#  'slipway',
#  'pier',
#  'dam',
#  'weir',
#  'bus_stop',
#  'airport',
#  'helipad',
#  'apron',
#  'forest',
#  'park',
#  'residential',
#  'industrial',
#  'cemetery',
#  'meadow',
#  'commercial',
#  'nature_reserve',
#  'recreation_ground',
#  'retail',
#  'orchard',
#  'vineyard',
#  'scrub',
#  'grass',
#  'farmyard',
#  'farmland',
#  'water',
#  'reservoir',
#  'wetland',
#  '__public',
#  '__health',
#  '__leisure',
#  '__catering',
#  '__accommodation_indoor',
#  '__accommodation_outdoor',
#  '__shopping',
#  '__money',
#  '__tourism_destination',
#  '__miscellaneous',
#  '__worship',
#  '__christian_all',
#  '__natural',
#  '__traffic',
#  '__traffic_fuel_and_parking',
#  '__traffic_water',
#  '__transport_air',
#  '__landuse_leisure',
#  '__waterway',
#  'GrLivArea',
#  'SalePrice',
#  'LotFrontage',
#  'LotArea',
#  'Street_paved',
#  'Alley',
#  'LandContour',
#  'Utilities',
#  'LandSlope',
#  'Neighborhood',
#  'BldgType',
#  'OverallQual',
#  'OverallCond',
#  'RoofStyle',
#  'RoofMatl',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'CentralAir',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageFinish',
#  'GarageCars',
#  'GarageArea',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SaleType',
#  'SaleCondition',
#  'SalePrice_log',
#  'HeatingQC_ord',
#  'LotShape_com',
#  'MSZoning_com',
#  'LF_Near_NS_RR',
#  'LF_Near_Positive_Feature',
#  'LF_Adjacent_Arterial_St',
#  'LF_Near_EW_RR',
#  'LF_Adjacent_Feeder_St',
#  'Heating_com',
#  'Electrical_com',
#  'LotConfig_com',
#  'LotFrontage_log',
#  'LotArea_log',
#  'ext_Wood_Siding',
#  'ext_Hard_Board',
#  'ext_Metal_Siding',
#  'ext_Vinyl_Siding',
#  'ext_Wood_Shingles',
#  'ext_Plywood',
#  'ext_Stucco',
#  'ext_Cement_Board',
#  'ext_Face_Brick',
#  'ext_Asbestos_Shingles',
#  'ext_Common_Brick',
#  'ext_Imitation_Stucco',
#  'ext_Other',
#  'BsmtCond_ord',
#  'BsmtQual_ord',
#  'BsmtExposure_ord',
#  'BSMT_GLQ',
#  'BSMT_ALQ',
#  'BSMT_BLQ',
#  'BSMT_LwQ',
#  'BSMT_Rec',
#  'GarageType_com',
#  'number_floors',
#  'attic',
#  'PUD',
#  'Functional_ord',
#  '1stFlrSF_log',
#  '2ndFlrSF_log',
#  'GrLivArea_log',
#  'sold_datetime',
#  'Garage_age_years',
#  'Garage_age_bin',
#  'house_age_years',
#  'Remod_age_years',
#  'Remod_age_bin']

# %%
rad_drops = ['Address', 'Coords4', 'latitude', 'longitude']

# %%
droplist = ['SaleType', 'SaleCondition', 'Garage_age_years', 'Remod_age_years', 'MoSold', 'Utilities', 'MiscFeature']
alwaysdrop = ['PID', 'SalePrice', 'SalePrice_log', 'sold_datetime', '2ndFlrSF_log', 'GrLivArea', '1stFlrSF', 'LotArea', 'LotFrontage_log']
df2 = df.drop((alwaysdrop + droplist + rad_drops), axis = 1)

# %%
to_dummify = [
    'Street_paved',
    'Alley',
    'LandContour',
    'Utilities',
    'LandSlope',
    'Neighborhood',
    'BldgType',
    'OverallQual',
    'OverallCond',
    'RoofStyle',
    'RoofMatl',
    'MasVnrType',
    'ExterQual',
    'ExterCond',
    'Foundation',
    'CentralAir',
    'KitchenQual',
    'FireplaceQu',
    'GarageFinish',
    'GarageQual',
    'GarageCond',
    'PavedDrive',
    'PoolQC',
    'Fence',
    'MiscFeature',
    'MoSold',
    'HeatingQC_ord',
    'LotShape_com',
    'MSZoning_com',
    'Heating_com',
    'Electrical_com',
    'LotConfig_com',
    'BsmtCond_ord',
    'BsmtQual_ord',
    'BsmtExposure_ord',
    'GarageType_com',
    'number_floors',
    'attic',
    'PUD',
    'Functional_ord',
    'Garage_age_bin',
    'Remod_age_bin',
    'SaleType',
    'SaleCondition' 
]

# %%
for item in droplist:
    if item in to_dummify:
        to_dummify.remove(item)

# %%
df3 = pd.get_dummies(df2, columns = to_dummify, drop_first=True)

# %%
kfold = KFold(n_splits=10, shuffle = True, random_state = 1)

# %%
params_log = {'alpha' : [1e-6, 1e-5, 1e-4]
         }

# %%
lasso3 = Lasso(normalize = True, max_iter = 1000, tol = 0.001)
lasso_tuner3 = GridSearchCV(lasso3, params_log, cv=kfold, return_train_score = True)
lasso_tuner3.fit(df3, price_log)
# Out:
# GridSearchCV(cv=KFold(n_splits=10, random_state=1, shuffle=True),
#              estimator=Lasso(normalize=True, tol=0.001),
#              param_grid={'alpha': [1e-06, 1e-05, 0.0001]},
#              return_train_score=True)

# %%
lasso_tuner3.cv_results_['mean_test_score']
# Out:
# array([0.94725832, 0.94742872, 0.92187333])

# %%
lasso_tuner3.cv_results_['mean_train_score']
# Out:
# array([0.96365374, 0.95764765, 0.92836701])

# %%
print(lasso_tuner3.best_params_)
print(max(lasso_tuner3.cv_results_['mean_test_score']))
# Out:
# {'alpha': 1e-05}
# 0.9474287186752373

# %%
feat_imp_rad = pd.Series(data = lasso_tuner3.best_estimator_.coef_, index = df3.columns)
feat_imp_rad = feat_imp_rad.sort_values(ascending = False)
ignored_rad = feat_imp_rad[feat_imp_rad == 0]
feat_imp_rad = feat_imp_rad[feat_imp_rad != 0]
print(len(feat_imp_rad))
print(feat_imp_rad)
print(len(ignored_rad))
print(ignored_rad)
# Out:
# 164
# GrLivArea_log                                                 0.263109
# Neighborhood_GrnHill                                          0.186720
# 1stFlrSF_log                                                  0.134472
# OverallQual_10                                                0.088643
# LotArea_log                                                   0.084640
# OverallQual_9                                                 0.073535
# GarageQual_5                                                  0.056223
# Neighborhood_Crawfor                                          0.043882
# PoolQC_5                                                      0.041758
# OverallQual_8                                                 0.040931
# OverallCond_9                                                 0.038933
# Neighborhood_StoneBr                                          0.034169
# OverallCond_8                                                 0.029129
# Functional_ord_7                                              0.026212
# Neighborhood_Somerst                                          0.023353
# ext_Face_Brick                                                0.021811
# OverallCond_7                                                 0.021512
# Neighborhood_Greens                                           0.019782
# Street_paved_Pave                                             0.019648
# Neighborhood_Blueste                                          0.018316
# Neighborhood_BrkSide                                          0.017467
# ext_Common_Brick                                              0.017143
# BsmtExposure_ord_4                                            0.016936
# OverallQual_7                                                 0.016891
# CentralAir_Y                                                  0.015366
# ExterQual_5                                                   0.014028
# KitchenQual_5                                                 0.013767
# Foundation_Stone                                              0.013351
# Neighborhood_ClearCr                                          0.012951
# BsmtQual_ord_5                                                0.012064
# GarageCars                                                    0.011100
# ext_Stucco                                                    0.011071
# Fireplaces                                                    0.010366
# garden_centre                                                 0.009389
# RoofMatl_Roll                                                 0.009117
# ext_Other                                                     0.008937
# MSZoning_com_Residential, village                             0.008692
# BsmtFullBath                                                  0.007661
# Neighborhood_NridgHt                                          0.007184
# BsmtExposure_ord_3                                            0.007030
# PavedDrive_Paved                                              0.006893
# attic_Unfinished                                              0.006353
# MSZoning_com_Residential, low-density                         0.006142
# FullBath                                                      0.005855
# Neighborhood_NoRidge                                          0.004843
# Foundation_PConc                                              0.004791
# FireplaceQu_4                                                 0.004557
# HeatingQC_ord_5                                               0.004293
# Heating_com_Gas-powered water/steam heating                   0.004233
# LandContour_Hillside (downward slope on both sides)           0.003926
# GarageCond_3                                                  0.003521
# PoolQC_3                                                      0.003512
# stadium                                                       0.002897
# library                                                       0.002487
# GarageQual_4                                                  0.002111
# Electrical_com_Standard circuit breakers, all Romex wiring    0.002088
# MasVnrType_Stone                                              0.002060
# LotConfig_com_Cul-de-sac lot                                  0.002001
# museum                                                        0.001812
# LotConfig_com_Inside lot (1 side frontage)                    0.001528
# ext_Vinyl_Siding                                              0.001502
# HalfBath                                                      0.001481
# apron                                                         0.001318
# viewpoint                                                     0.001287
# BsmtHalfBath                                                  0.001284
# meadow                                                        0.001274
# computer_shop                                                 0.001218
# BsmtCond_ord_4                                                0.001132
# GarageType_com_Attached                                       0.001012
# FireplaceQu_1                                                 0.000779
# PoolQC_4                                                      0.000569
# Alley_Paved                                                   0.000148
# ScreenPorch                                                   0.000069
# university                                                    0.000056
# 2ndFlrSF                                                      0.000050
# TotalBsmtSF                                                   0.000043
# BSMT_GLQ                                                      0.000036
# OpenPorchSF                                                   0.000030
# 3SsnPorch                                                     0.000029
# GarageArea                                                    0.000029
# EnclosedPorch                                                 0.000028
# BSMT_ALQ                                                      0.000024
# WoodDeckSF                                                    0.000018
# MasVnrArea                                                    0.000014
# BSMT_BLQ                                                      0.000013
# water_tower                                                   0.000008
# fountain                                                      0.000007
# BsmtUnfSF                                                    -0.000002
# LotFrontage                                                  -0.000033
# farmyard                                                     -0.000101
# reservoir                                                    -0.000107
# post_box                                                     -0.000222
# BsmtExposure_ord_2                                           -0.000258
# ext_Hard_Board                                               -0.000334
# GarageFinish_RFn                                             -0.000336
# supermarket                                                  -0.000404
# christian_lutheran                                           -0.000424
# Neighborhood_IDOTRR                                          -0.000486
# fire_station                                                 -0.000772
# house_age_years                                              -0.000885
# camera_surveillance                                          -0.001094
# Foundation_Slab                                              -0.001118
# toilet                                                       -0.001118
# Functional_ord_4                                             -0.001164
# general                                                      -0.001233
# hotel                                                        -0.001532
# mobile_phone_shop                                            -0.001664
# Garage_age_bin_20-40                                         -0.002046
# ExterQual_3                                                  -0.002068
# graveyard                                                    -0.002085
# water_works                                                  -0.002154
# christian_catholic                                           -0.002441
# BedroomAbvGr                                                 -0.002850
# Remod_age_bin_15-30                                          -0.002914
# MSZoning_com_Residential, high-density                       -0.002971
# ext_Plywood                                                  -0.003161
# Garage_age_bin_40-60                                         -0.003165
# LandContour_Depression (upward slope on both sides)          -0.003403
# Neighborhood_Gilbert                                         -0.003599
# HeatingQC_ord_3                                              -0.003884
# Remod_age_bin_30-45                                          -0.004118
# GarageQual_2                                                 -0.004267
# BldgType_2fmCon                                              -0.004349
# cinema                                                       -0.004923
# Foundation_Wood                                              -0.005022
# HeatingQC_ord_2                                              -0.005710
# BldgType_Twnhs                                               -0.005841
# Neighborhood_NWAmes                                          -0.006040
# retail                                                       -0.007521
# ext_Imitation_Stucco                                         -0.007909
# GarageCond_2                                                 -0.008683
# KitchenQual_3                                                -0.008871
# stationery                                                   -0.009065
# LF_Near_NS_RR                                                -0.010331
# OverallQual_5                                                -0.010994
# KitchenQual_2                                                -0.011952
# motel                                                        -0.012054
# Neighborhood_SawyerW                                         -0.013015
# RoofStyle_Gabrel Barn                                        -0.013275
# airport                                                      -0.013362
# ext_Asbestos_Shingles                                        -0.013646
# OverallCond_5                                                -0.013729
# street_lamp                                                  -0.014381
# dam                                                          -0.014962
# RoofMatl_Wood Shakes                                         -0.015435
# RoofMatl_Standard (Composite) Shingle                        -0.016275
# Neighborhood_Edwards                                         -0.016988
# Remod_age_bin_45+                                            -0.018108
# ExterCond_2                                                  -0.018432
# LF_Adjacent_Feeder_St                                        -0.020516
# BsmtCond_ord_1                                               -0.023037
# KitchenAbvGr                                                 -0.023861
# LF_Near_EW_RR                                                -0.024699
# GarageQual_1                                                 -0.024716
# BldgType_Duplex                                              -0.026237
# Neighborhood_MeadowV                                         -0.026936
# LF_Adjacent_Arterial_St                                      -0.027821
# OverallQual_4                                                -0.030296
# Functional_ord_3                                             -0.039093
# OverallCond_4                                                -0.045134
# OverallQual_3                                                -0.046230
# OverallCond_2                                                -0.071046
# OverallQual_2                                                -0.075758
# OverallCond_3                                                -0.086638
# dtype: float64
# 205
# BsmtCond_ord_3                                       0.0
# BsmtQual_ord_3                                      -0.0
# BsmtQual_ord_2                                       0.0
# BsmtQual_ord_1                                       0.0
# BsmtCond_ord_5                                      -0.0
# BSMT_LwQ                                            -0.0
# BSMT_Rec                                             0.0
# BsmtCond_ord_2                                      -0.0
# BsmtQual_ord_4                                       0.0
# LotConfig_com_Corner lot                             0.0
# Alley_No alley access                                0.0
# Electrical_com_>60 Amp fuse box, all Romex wiring   -0.0
# Heating_com_Other                                    0.0
# LandContour_Level                                    0.0
# LandSlope_Moderate-severe                            0.0
# MSZoning_com_Residential, medium-density            -0.0
# Neighborhood_BrDale                                 -0.0
# ext_Cement_Board                                     0.0
# ExterCond_4                                          0.0
# ext_Wood_Shingles                                   -0.0
# LotShape_com_Slightly irregular                     -0.0
# Garage_age_bin_No garage                            -0.0
# Garage_age_bin_60+                                   0.0
# Functional_ord_6                                     0.0
# Functional_ord_5                                     0.0
# PUD_1                                               -0.0
# PoolArea                                             0.0
# MiscVal                                              0.0
# attic_No attic                                       0.0
# number_floors_2                                      0.0
# GarageType_com_No garage                            -0.0
# GarageType_com_Detached                             -0.0
# YrSold                                               0.0
# GarageType_com_BuiltIn                               0.0
# GarageType_com_Basement                             -0.0
# LF_Near_Positive_Feature                             0.0
# BsmtExposure_ord_1                                   0.0
# ext_Wood_Siding                                      0.0
# ext_Metal_Siding                                    -0.0
# Neighborhood_CollgCr                                -0.0
# LotShape_com_Regular                                 0.0
# RoofStyle_Shed                                       0.0
# GarageFinish_No garage                              -0.0
# OverallCond_6                                        0.0
# FireplaceQu_5                                        0.0
# FireplaceQu_3                                       -0.0
# FireplaceQu_2                                       -0.0
# RoofStyle_Gable                                      0.0
# RoofStyle_Hip                                       -0.0
# RoofStyle_Mansard                                   -0.0
# RoofMatl_Membrane                                    0.0
# GarageQual_3                                         0.0
# RoofMatl_Metal                                       0.0
# KitchenQual_4                                        0.0
# RoofMatl_Wood Shingles                               0.0
# MasVnrType_Brick Face                               -0.0
# MasVnrType_None                                      0.0
# Foundation_CBlock                                    0.0
# ExterCond_5                                          0.0
# ExterCond_3                                          0.0
# GarageFinish_Unf                                    -0.0
# GarageCond_1                                        -0.0
# HeatingQC_ord_4                                      0.0
# PoolQC_2                                            -0.0
# Fence_No Fence                                      -0.0
# Fence_Minimum Wood/Wire                             -0.0
# Neighborhood_Landmrk                                -0.0
# Neighborhood_Mitchel                                -0.0
# Neighborhood_NAmes                                   0.0
# Fence_Minimum Privacy                               -0.0
# Neighborhood_NPkVill                                 0.0
# Fence_Good Wood                                     -0.0
# Neighborhood_OldTown                                -0.0
# OverallQual_6                                        0.0
# Neighborhood_SWISU                                  -0.0
# PavedDrive_Partial Pavement                         -0.0
# Neighborhood_Sawyer                                 -0.0
# GarageCond_5                                        -0.0
# GarageCond_4                                         0.0
# Neighborhood_Timber                                  0.0
# Neighborhood_Veenker                                -0.0
# BldgType_TwnhsE                                      0.0
# ExterQual_4                                          0.0
# police                                              -0.0
# TotRmsAbvGrd                                         0.0
# car_wash                                            -0.0
# artwork                                              0.0
# memorial                                             0.0
# attraction                                           0.0
# tourist_info                                         0.0
# atm                                                 -0.0
# bank                                                -0.0
# laundry                                              0.0
# hairdresser                                          0.0
# jeweller                                             0.0
# furniture_shop                                       0.0
# doityourself                                        -0.0
# bicycle_shop                                         0.0
# car_dealership                                       0.0
# beauty_shop                                         -0.0
# outdoor_shop                                         0.0
# sports_shop                                         -0.0
# picnic_site                                          0.0
# bench                                               -0.0
# drinking_water                                       0.0
# waste_basket                                         0.0
# motorway_junction                                   -0.0
# crossing                                             0.0
# stop                                                -0.0
# traffic_signals                                      0.0
# beach                                                0.0
# tree                                                -0.0
# spring                                               0.0
# muslim                                               0.0
# jewish                                               0.0
# christian_methodist                                 -0.0
# christian_evangelical                               -0.0
# christian                                           -0.0
# wastewater_plant                                     0.0
# comms_tower                                          0.0
# tower                                                0.0
# gift_shop                                            0.0
# optician                                            -0.0
# fuel                                                 0.0
# veterinary                                          -0.0
# swimming_pool                                       -0.0
# pitch                                                0.0
# sports_centre                                       -0.0
# dog_park                                            -0.0
# playground                                           0.0
# park                                                 0.0
# theatre                                              0.0
# dentist                                             -0.0
# beverages                                            0.0
# doctors                                              0.0
# hospital                                            -0.0
# pharmacy                                            -0.0
# school                                              -0.0
# nursing_home                                        -0.0
# town_hall                                            0.0
# post_office                                         -0.0
# golf_course                                         -0.0
# track                                               -0.0
# restaurant                                          -0.0
# fast_food                                           -0.0
# shoe_shop                                           -0.0
# bookshop                                             0.0
# florist                                              0.0
# clothes                                              0.0
# convenience                                          0.0
# department_store                                    -0.0
# mall                                                -0.0
# bakery                                               0.0
# camp_site                                            0.0
# shelter                                              0.0
# guesthouse                                           0.0
# food_court                                          -0.0
# bar                                                 -0.0
# pub                                                 -0.0
# cafe                                                 0.0
# turning_circle                                       0.0
# Remod_age_bin_No remodel                            -0.0
# grass                                                0.0
# __money                                             -0.0
# helipad                                              0.0
# __health                                            -0.0
# forest                                              -0.0
# __miscellaneous                                      0.0
# __tourism_destination                                0.0
# park                                                 0.0
# residential                                          0.0
# industrial                                          -0.0
# cemetery                                            -0.0
# commercial                                           0.0
# nature_reserve                                      -0.0
# __shopping                                           0.0
# __natural                                           -0.0
# __accommodation_outdoor                              0.0
# recreation_ground                                    0.0
# orchard                                             -0.0
# __accommodation_indoor                              -0.0
# __catering                                          -0.0
# vineyard                                             0.0
# scrub                                               -0.0
# __leisure                                            0.0
# farmland                                            -0.0
# water                                                0.0
# wetland                                              0.0
# __christian_all                                     -0.0
# __worship                                           -0.0
# bus_stop                                             0.0
# __transport_air                                      0.0
# LowQualFinSF                                        -0.0
# parking                                             -0.0
# parking_multistorey                                 -0.0
# parking_bicycle                                     -0.0
# slipway                                              0.0
# pier                                                 0.0
# __landuse_leisure                                    0.0
# __waterway                                          -0.0
# __public                                            -0.0
# weir                                                 0.0
# __traffic_water                                      0.0
# __traffic                                            0.0
# __traffic_fuel_and_parking                          -0.0
# dtype: float64

# %%
grouped_cols = [
    '__public',
    '__health',
    '__leisure',
    '__catering',
    '__accommodation_indoor',
    '__accommodation_outdoor',
    '__shopping',
    '__money',
    '__tourism_destination',
    '__miscellaneous',
    '__worship',
    '__christian_all',
    '__natural',
    '__traffic',
    '__traffic_fuel_and_parking',
    '__traffic_water',
    '__transport_air',
    '__landuse_leisure',
    '__waterway'
]

# %%
EDA_plots(radial, features = radial.columns[1:40], targets = ['SalePrice_log'])
# Out:
# feature:  Coords4
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._unpack_bool_indexer()
#
# KeyError: 'SalePrice_log'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-2e848ced1ca8> in <module>
# ----> 1 EDA_plots(radial, features = radial.columns[1:40], targets = ['SalePrice_log'])
#
# <ipython-input-2-366eb2a800e1> in EDA_plots(df, features, targets)
#      37                 print('feature: ',feature) # print feature name
#      38                 # scatterplot
# ---> 39                 scatter = px.scatter(x = df[feature], y = df[target])
#      40                 scatter.update_layout(
#      41                     title={
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'SalePrice_log'

# %%
#EDA_plots(radial, features = radial.columns[40:80])

# %%
#EDA_plots(radial, features = radial.columns[80:120])

# %% [markdown]
# pos: farmland, farmyard, water

# %%
#EDA_plots(radial, features = radial.columns[120:151])
