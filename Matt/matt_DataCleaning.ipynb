# %%
import numpy as np
import pandas as pd

from scipy import stats
import itertools
from sklearn import linear_model
from numpy import ones,vstack
from numpy.linalg import lstsq

# %%
pd.read_csv('./../data/ames_housing_price_data_v2.csv', index_col = 0)
# Out:
#            GrLivArea  SalePrice  drop_MSSubClass maybe_MSZoning  LotFrontage  \
# PID
# 909176150        856     126000               30             RL          0.0
# 905476230       1049     139500              120             RL         42.0
# 911128020       1001     124900               30        C (all)         60.0
# 535377150       1039     114000               70             RL         80.0
# 534177230       1665     227000               60             RL         70.0
# ...              ...        ...              ...            ...          ...
# 903205040        952     121000               30             RL          0.0
# 905402060       1733     139600               20             RL          0.0
# 909275030       2002     145000               90             RH         82.0
# 907192040       1842     217500               60             RL          0.0
# 906223180       1911     215000               60             RL         80.0
#
# ...
