# %%
import numpy as np
import pandas as pd
import plotly.express as px
from scipy import stats
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm as anova
import itertools
from sklearn import linear_model
from numpy import ones,vstack
from numpy.linalg import lstsq

# %%
df=pd.read_csv('../data/ames_housing_price_data_v2.csv', index_col=0)

# %%
pd.options.display.max_rows=400

# %%
typedict = {'PID' : 'nominal',
            'SalePrice' : 'continuous',
            #Matt
            'LotFrontage' : 'continuous', 
            'LotArea' : 'continuous',
            'maybe_LotShape' : 'nominal',
            'LandSlope' : 'nominal', 
            'LandContour' : 'nominal', 
            'maybe_MSZoning' : 'nominal', 
            'Street_paved' : 'nominal', 
            'Alley' : 'nominal',
            'Neighborhood' : 'nominal', 
            'drop_LotConfig' : 'nominal', 
            'drop_Condition1' : 'nominal', 
            'drop_Condition2' : 'nominal',
            'Foundation' : 'nominal',
            'Utilities' : 'nominal',
            'Heating' : 'nominal',
            'HeatingQC_nom' : 'ordinal',
            'CentralAir' : 'nominal',
            'Electrical' : 'nominal',
            'HeatingQC_ord' : 'ordinal',
            'LotShape_com' : 'nominal',
            'MSZoning_com' : 'nominal',
            'LF_Normal' : 'nominal',
            'LF_Near_NS_RR' : 'nominal',
            'LF_Near_Positive_Feature' : 'nominal',
            'LF_Adjacent_Arterial_St' : 'nominal',
            'LF_Near_EW_RR' : 'nominal',
            'LF_Adjacent_Feeder_St' : 'nominal',
            'LF_Near_Postive_Feature' : 'nominal',
            'Heating_com' : 'nominal',
            'Electrical_com' : 'nominal',
            'LotConfig_com' : 'nominal', 
            'LotFrontage_log' : 'continuous',
            'LotArea_log' : 'continuous',
            #Oren 
            'MiscFeature': 'Nominal',
            'Fireplaces': 'Discrete',
            'FireplaceQu': 'Ordinal',
            'PoolQC': 'Ordinal',
            'PoolArea': 'Continuous',
            'PavedDrive': 'Nominal',
            'ExterQual': 'Ordinal',
            'OverallQual': 'Ordinal',
            'drop_OverallCond': 'Ordinal',
            'MiscVal': 'Continuous',
            'YearBuilt': 'Discrete',
            'YearRemodAdd': 'Discrete',
            'KitchenQual': 'Ordinal',
            'Fence': 'Ordinal',
            'RoofStyle': 'Nominal',
            'RoofMatl': 'Nominal',
            'maybe_Exterior1st': 'Nominal',
            'drop_Exterior2nd': 'Nominal',
            'drop_ExterCond': 'Ordinal',
            'maybe_MasVnrType': 'Nominal',
            'MasVnrArea': 'Continuous',
            #Mo
            #Basement
            'BsmtQual_ord': 'Ordinal',
            'BsmtCond_ord': 'Ordinal',
            'BsmtExposure_ord': 'Ordinal',
            'BsmtQual_ord_lin': 'Ordinal',
            'BsmtCond_ord_lin': 'Ordinal',
            'BsmtExposure_ord_lin': 'Ordinal',
            'TotalBsmtSF': 'Continuous',
            'BSMT_GLQ':'Continuous', 
            'BSMT_Rec':'Continuous',
            'maybe_BsmtUnfSF': 'Continuous',
            'maybe_BSMT_ALQ':'Continuous',
            'maybe_BSMT_BLQ':'Continuous', 
            'maybe_BSMT_LwQ':'Continuous', 
            'drop_BsmtQual': 'Nominal',
            'drop_BsmtCond': 'Nominal',
            'drop_BsmtExposure': 'Nominal',
            'drop_BsmtFinType1': 'Nominal',
            'drop_BsmtFinSF1': 'Continuous',
            'drop_BsmtFinType2': 'Nominal',
            'drop_BsmtFinSF2': 'Continuous',
            #Deck
            'WoodDeckSF':'Continuous', 
            'OpenPorchSF':'Continuous', 
            'ScreenPorch':'Continuous',
            'maybe_EnclosedPorch':'Continuous',
            'maybe_3SsnPorch':'Continuous',
            #Garage
            'GarageFinish':'Nominal', 
            'GarageYrBlt':'Continuous',
            'GarageCars':'Ordinal',
            'GarageArea':'Continuous',
            'GarageType_con':'Nominal',
            'maybe_GarageQual':'Nominal', 
            'maybe_GarageCond':'Nominal',
            'drop_GarageType':'Nominal'
}

# %%
def EDA_plots(df, features = df.columns, targets = ['SalePrice'], diction = ['typedict']):
    # can pass features = [list of features] and targets = [list of targets]
    # to get plots and regressions of different variables
    for feature in features:
        for target in targets:
            if feature != target and feature != 'PID':
                print('feature: ',feature)
                if diction[feature] == 'continuous': 
                    scatter = px.scatter(x = df[f'{feature}'], y = df[f'{target}'])
                    scatter.update_layout(
                        title={
                            'text': f'Scatterplot, {feature} vs {target}',
                            'y':0.95,
                            'x':0.5,
                            'xanchor': 'center',
                            'yanchor': 'top'},
                        xaxis_title = f'{feature}',
                        yaxis_title = f'{target}'
                    )
                    scatter.show()
                if diction[feature] == 'ordinal': 
                    hist = px.histogram(x = df[f'{feature}'])
                    hist.update_layout(
                        title={
                            'text': f'Distribution of {feature}',
                            'y':0.95,
                            'x':0.5,
                            'xanchor': 'center',
                            'yanchor': 'top'},
                        xaxis_title = f'{feature}',
                        yaxis_title = 'Frequency'
                    )
                    hist.show()
                if diction[feature] == 'nominal': 
                    box = px.box(x = df[f'{feature}'], y = df[f'{target}'])
                    box.update_layout(
                        title={
                            'text': f'Boxplot, {feature} vs {target}',
                            'y':0.95,
                            'x':0.5,
                            'xanchor': 'center',
                            'yanchor': 'top'},
                        xaxis_title = f'{feature}',
                        yaxis_title = 'Frequency'
                    )
                    box.show()
#                 temp = df[df[f'{feature}'].isna() == False].reset_index(drop = True)
#                 if type(temp.loc[0, f'{feature}']) != str:
#                     price_corr = temp[f'{feature}'].corr(temp[f'{target}'])
#                     print(f'Correlation between {feature} and {target} is {price_corr}')
#                     linreg = stats.linregress(temp[f'{feature}'], temp[f'{target}'] )
#                     print(linreg)
#                     print('r^2 = ',linreg.rvalue**2)
#                 if type(temp.loc[0, f'{feature}']) == str:
#                     # this is to see full multiple regression on each value of categorical variable
#                     # can comment this out
#                     fit = ols(f'{target} ~ C({feature})', data=temp).fit()
#                     print(fit.summary())
#                     # this is to see anova on whether any value of categorical variable is significantly different
#                     #anova_table = anova(fit, typ=2)
#                     #print(anova_table)
            print()

# %%
EDA_plots(df, features = ['LotArea'])
# Out:
# feature:  LotArea
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-3885e97c6968> in <module>
# ----> 1 EDA_plots(df, features = ['LotArea'])
#
# <ipython-input-25-959c80861558> in EDA_plots(df, features, targets, diction)
#       6             if feature != target and feature != 'PID':
#       7                 print('feature: ',feature)
# ----> 8                 if diction[feature] == 'continuous':
#       9                     scatter = px.scatter(x = df[f'{feature}'], y = df[f'{target}'])
#      10                     scatter.update_layout(
#
# TypeError: list indices must be integers or slices, not str

# %%
typedict['GrLivArea']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-fb78172f2e4a> in <module>
# ----> 1 typedict['GrLivArea']
#
# KeyError: 'GrLivArea'

# %%
df[(df.index==908154205) | (df.index==902207130)].T
# Out:
# PID                                                         908154205  \
# GrLivArea                                                        4676
# SalePrice                                                      184750
# maybe_MSZoning                                                     RL
# LotFrontage                                                     130.0
# LotArea                                                         40094
# Street_paved                                                     Pave
# Alley                                                 No alley access
# maybe_LotShape                                                    IR1
# LandContour               Banked (rise from street level to building)
# Utilities                                                        EGWS
# LandSlope                                                      Gentle
# Neighborhood                                                  Edwards
# BldgType                                                         1Fam
# OverallQual                                                        10
# maybe_OverallCond                                                   5
# YearBuilt                                                        2007
# YearRemodAdd                                                     2008
# RoofStyle                                                         Hip
# RoofMatl                                 Standard (Composite) Shingle
# maybe_MasVnrType                                                Stone
# MasVnrArea                                                      762.0
# ExterQual                                                           5
# maybe_ExterCond                                                     3
# Foundation                                                      PConc
# maybe_BsmtUnfSF                                                 878.0
# TotalBsmtSF                                                    3138.0
# Heating                                                          GasA
# HeatingQC_nom                                                      Ex
# CentralAir                                                          Y
# Electrical                                                      SBrkr
# 1stFlrSF                                                         3138
# 2ndFlrSF                                                         1538
# maybe_LowQualFinSF                                                  0
# BsmtFullBath                                                      1.0
# maybe_BsmtHalfBath                                                0.0
# FullBath                                                            3
# maybe_HalfBath                                                      1
# BedroomAbvGr                                                        3
# KitchenAbvGr                                                        1
# KitchenQual                                                         5
# TotRmsAbvGrd                                                       11
# Fireplaces                                                          1
# FireplaceQu                                                         4
# GarageYrBlt                                                    2007.0
# GarageFinish                                                      Fin
# GarageCars                                                        3.0
# GarageArea                                                      884.0
# maybe_GarageQual                                                   TA
# maybe_GarageCond                                                   TA
# PavedDrive                                                      Paved
# WoodDeckSF                                                        208
# OpenPorchSF                                                       406
# maybe_EnclosedPorch                                                 0
# maybe_3SsnPorch                                                     0
# ScreenPorch                                                         0
# PoolArea                                                            0
# PoolQC                                                            NaN
# Fence                                                        No Fence
# MiscFeature                                                   Nothing
# MiscVal                                                             0
# MoSold                                                             10
# YrSold                                                           2007
# SaleType                                                          New
# SaleCondition                                                 Partial
# SalePrice_log                                                5.266584
# HeatingQC_ord                                                       5
# LotShape_com                                       Slightly irregular
# MSZoning_com                                 Residential, low-density
# LF_Near_NS_RR                                                       0
# LF_Near_Positive_Feature                                            1
# LF_Adjacent_Arterial_St                                             0
# LF_Near_EW_RR                                                       0
# LF_Adjacent_Feeder_St                                               0
# LF_Near_Postive_Feature                                             0
# Heating_com                            Gas-powered forced-air heating
# Electrical_com            Standard circuit breakers, all Romex wiring
# LotConfig_com                            Inside lot (1 side frontage)
# LotFrontage_log                                              2.113943
# LotArea_log                                                  4.603079
# BsmtCond_ord                                                        3
# BsmtQual_ord                                                        5
# BsmtExposure_ord                                                    4
# BSMT_GLQ                                                       2260.0
# maybe_BSMT_ALQ                                                    0.0
# maybe_BSMT_BLQ                                                    0.0
# maybe_BSMT_LwQ                                                    0.0
# BSMT_Rec                                                          0.0
# GarageType_con                                                BuiltIn
# MS_coded                                                      2-Story
# number_floors                                                       2
# attic                                                        No attic
# PUD                                                                 0
# Functional_ord                                                      7
# 1stFlrSF_log                                                 3.496653
# 2ndFlrSF_log                                                 3.187239
# GrLivArea_log                                                3.669875
# sold_datetime                                              2007-10-01
#
# PID                                                         902207130
# GrLivArea                                                         832
# SalePrice                                                       12789
# maybe_MSZoning                                                     RM
# LotFrontage                                                      68.0
# LotArea                                                          9656
# Street_paved                                                     Pave
# Alley                                                 No alley access
# maybe_LotShape                                                    Reg
# LandContour                                                     Level
# Utilities                                                        EGWS
# LandSlope                                                      Gentle
# Neighborhood                                                  OldTown
# BldgType                                                         1Fam
# OverallQual                                                         2
# maybe_OverallCond                                                   2
# YearBuilt                                                        1923
# YearRemodAdd                                                     1970
# RoofStyle                                                       Gable
# RoofMatl                                 Standard (Composite) Shingle
# maybe_MasVnrType                                                 None
# MasVnrArea                                                        0.0
# ExterQual                                                           3
# maybe_ExterCond                                                     2
# Foundation                                                     BrkTil
# maybe_BsmtUnfSF                                                 678.0
# TotalBsmtSF                                                     678.0
# Heating                                                          GasA
# HeatingQC_nom                                                      TA
# CentralAir                                                          N
# Electrical                                                      SBrkr
# 1stFlrSF                                                          832
# 2ndFlrSF                                                            0
# maybe_LowQualFinSF                                                  0
# BsmtFullBath                                                      0.0
# maybe_BsmtHalfBath                                                0.0
# FullBath                                                            1
# maybe_HalfBath                                                      0
# BedroomAbvGr                                                        2
# KitchenAbvGr                                                        1
# KitchenQual                                                         3
# TotRmsAbvGrd                                                        5
# Fireplaces                                                          1
# FireplaceQu                                                         4
# GarageYrBlt                                                    1928.0
# GarageFinish                                                      Unf
# GarageCars                                                        2.0
# GarageArea                                                      780.0
# maybe_GarageQual                                                   Fa
# maybe_GarageCond                                                   Fa
# PavedDrive                                                Dirt Gravel
# WoodDeckSF                                                          0
# OpenPorchSF                                                         0
# maybe_EnclosedPorch                                                 0
# maybe_3SsnPorch                                                     0
# ScreenPorch                                                         0
# PoolArea                                                            0
# PoolQC                                                            NaN
# Fence                                                        No Fence
# MiscFeature                                                   Nothing
# MiscVal                                                             0
# MoSold                                                              6
# YrSold                                                           2010
# SaleType                                                          WD
# SaleCondition                                                 Abnorml
# SalePrice_log                                                4.106837
# HeatingQC_ord                                                       3
# LotShape_com                                                  Regular
# MSZoning_com                              Residential, medium-density
# LF_Near_NS_RR                                                       0
# LF_Near_Positive_Feature                                            0
# LF_Adjacent_Arterial_St                                             0
# LF_Near_EW_RR                                                       0
# LF_Adjacent_Feeder_St                                               0
# LF_Near_Postive_Feature                                             0
# Heating_com                            Gas-powered forced-air heating
# Electrical_com            Standard circuit breakers, all Romex wiring
# LotConfig_com                            Inside lot (1 side frontage)
# LotFrontage_log                                              1.832509
# LotArea_log                                                  3.984797
# BsmtCond_ord                                                        2
# BsmtQual_ord                                                        2
# BsmtExposure_ord                                                    1
# BSMT_GLQ                                                          0.0
# maybe_BSMT_ALQ                                                    0.0
# maybe_BSMT_BLQ                                                    0.0
# maybe_BSMT_LwQ                                                    0.0
# BSMT_Rec                                                          0.0
# GarageType_con                                                 Detchd
# MS_coded                                                      1-Story
# number_floors                                                       1
# attic                                                        No attic
# PUD                                                                 0
# Functional_ord                                                      7
# 1stFlrSF_log                                                 2.920123
# 2ndFlrSF_log                                                      0.0
# GrLivArea_log                                                2.920123
# sold_datetime                                              2010-06-01
