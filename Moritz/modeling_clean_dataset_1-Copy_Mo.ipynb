# %%
import numpy as np
import pandas as pd
from scipy import stats
from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression
import plotly.express as px
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.model_selection import cross_val_score
import time

# %%
pd.set_option('display.max_rows', 500)

# %%
df = pd.read_csv('./../data/ames_housing_price_data_v4.csv')

# %%
def seasonal_adjust(df, mo_avg):
    df['SalePrice_adj'] = 0 * len(df)
    for i in range(len(df)):
        price_norm = mo_avg
        df.loc[i, 'SalePrice_adj'] = (df.loc[i, 'SalePrice']) / mo_avg.loc[df.loc[i, 'MoSold'], 'monthly_avg_ratio']
    return df

# %%
mo_avg = df.groupby('MoSold').agg(monthly_avg = ('SalePrice', 'mean'), monthly_sd = ('SalePrice', 'std'))

# %%
mo_avg['monthly_avg_ratio'] = mo_avg['monthly_avg'] / np.mean(df['SalePrice'])

# %%
df = seasonal_adjust(df, mo_avg)

# %%
df['SalePrice_adj_log'] = np.log10(df['SalePrice_adj'])

# %%
#exclude weird sale types

# %%
df['SaleCondition'].value_counts()
# Out:
# Normal     2413
# Partial      82
# Abnorml      61
# Family       17
# Alloca        4
# AdjLand       2
# Name: SaleCondition, dtype: int64

# %%
df=df[(df['SaleCondition']=='Normal') | (df['SaleCondition']=='Partial')]

# %%
price = df['SalePrice']
price_log = df['SalePrice_log']
price_adj = df['SalePrice_adj']
price_adj_log = df['SalePrice_adj_log']

# %%
log_cols = []
for col in df.columns:
    if '_log' in col:
        log_cols.append(col)
log_cols
# Out:
# ['SalePrice_log',
#  'LotFrontage_log',
#  'LotArea_log',
#  '1stFlrSF_log',
#  '2ndFlrSF_log',
#  'GrLivArea_log',
#  'SalePrice_adj_log']

# %%
to_dummify = [
    'Street_paved',
    'Alley',
    'LandContour',
    'Utilities',
    'LandSlope',
    'Neighborhood',
    'BldgType',
    #'OverallQual',
    #'OverallCond',
    'RoofStyle',
    'RoofMatl',
    'MasVnrType',
    #'ExterQual',
    #'ExterCond',
    'Foundation',
    'CentralAir',
    #'KitchenQual',
    #'FireplaceQu',
    'GarageFinish',
    #'GarageQual',
    #'GarageCond',
    'PavedDrive',
    #'PoolQC',
    'Fence',
    'MiscFeature',
    #'MoSold',#
    #'HeatingQC_ord',
    'LotShape_com',
    'MSZoning_com',
    'Heating_com',
    'Electrical_com',
    'LotConfig_com',
    #'BsmtCond_ord',
    #'BsmtQual_ord',
    'BsmtExposure_ord',
    'GarageType_com',
    #'number_floors',
    'attic',
    'PUD',
    #'Functional_ord',
    'Garage_age_bin',
    'Remod_age_bin',
    'SaleType',#
    'SaleCondition' #
]

# %%
df = pd.get_dummies(df, columns = to_dummify, drop_first = True)

# %%
droplist = ['SaleType', 'SaleCondition', 'Garage_age_years', 'Remod_age_years', 'MoSold']
alwaysdrop = ['PID', 'SalePrice', 'SalePrice_log', 'SalePrice_adj', 'SalePrice_adj_log', 'sold_datetime']
df3 = df.drop((alwaysdrop), axis = 1) #+ droplist

# %%
df3.head().T
# Out:
#                                                               0            1  \
# GrLivArea                                            856.000000  1049.000000
# LotFrontage                                          177.651344    42.000000
# LotArea                                             7890.000000  4235.000000
# OverallQual                                            6.000000     5.000000
# OverallCond                                            6.000000     5.000000
# MasVnrArea                                             0.000000   149.000000
# ExterQual                                              3.000000     4.000000
# ExterCond                                              3.000000     3.000000
# BsmtUnfSF                                            618.000000   104.000000
# TotalBsmtSF                                          856.000000  1049.000000
# 1stFlrSF                                             856.000000  1049.000000
# 2ndFlrSF                                               0.000000     0.000000
# LowQualFinSF                                           0.000000     0.000000
# BsmtFullBath                                           1.000000     1.000000
# BsmtHalfBath                                           0.000000     0.000000
# FullBath                                               1.000000     2.000000
# HalfBath                                               0.000000     0.000000
# BedroomAbvGr                                           2.000000     2.000000
# KitchenAbvGr                                           1.000000     1.000000
# KitchenQual                                            3.000000     4.000000
# TotRmsAbvGrd                                           4.000000     5.000000
# Fireplaces                                             1.000000     0.000000
# FireplaceQu                                            4.000000     0.000000
# GarageCars                                             2.000000     1.000000
# GarageArea                                           399.000000   266.000000
# GarageQual                                             3.000000     3.000000
# GarageCond                                             3.000000     3.000000
# WoodDeckSF                                             0.000000     0.000000
# OpenPorchSF                                            0.000000   105.000000
# EnclosedPorch                                          0.000000     0.000000
# 3SsnPorch                                              0.000000     0.000000
# ScreenPorch                                          166.000000     0.000000
# PoolArea                                               0.000000     0.000000
# PoolQC                                                 0.000000     0.000000
# MiscVal                                                0.000000     0.000000
# MoSold                                                 3.000000     2.000000
# YrSold                                              2010.000000  2009.000000
# HeatingQC_ord                                          3.000000     3.000000
# LF_Near_NS_RR                                          0.000000     0.000000
# LF_Near_Positive_Feature                               0.000000     0.000000
# LF_Adjacent_Arterial_St                                0.000000     0.000000
# LF_Near_EW_RR                                          0.000000     0.000000
# LF_Adjacent_Feeder_St                                  0.000000     0.000000
# LotFrontage_log                                        5.179823     3.737670
# LotArea_log                                            3.897077     3.626853
# ext_Wood_Siding                                        1.000000     0.000000
# ext_Hard_Board                                         0.000000     1.000000
# ext_Metal_Siding                                       0.000000     0.000000
# ext_Vinyl_Siding                                       0.000000     0.000000
# ext_Wood_Shingles                                      0.000000     0.000000
# ext_Plywood                                            0.000000     0.000000
# ext_Stucco                                             0.000000     0.000000
# ext_Cement_Board                                       0.000000     0.000000
# ext_Face_Brick                                         0.000000     0.000000
# ext_Asbestos_Shingles                                  0.000000     0.000000
# ext_Common_Brick                                       0.000000     0.000000
# ext_Imitation_Stucco                                   0.000000     0.000000
# ext_Other                                              0.000000     0.000000
# BsmtCond_ord                                           3.000000     3.000000
# BsmtQual_ord                                           3.000000     4.000000
# BSMT_GLQ                                               0.000000   552.000000
# BSMT_ALQ                                               0.000000   393.000000
# BSMT_BLQ                                               0.000000     0.000000
# BSMT_LwQ                                               0.000000     0.000000
# BSMT_Rec                                             238.000000     0.000000
# number_floors                                          1.000000     1.000000
# Functional_ord                                         7.000000     7.000000
# 1stFlrSF_log                                           2.932474     3.020775
# 2ndFlrSF_log                                           0.000000     0.000000
# GrLivArea_log                                          2.932474     3.020775
# Garage_age_years                                      71.210959    25.104110
# house_age_years                                       71.210959    25.104110
# Remod_age_years                                       60.202740    -1.000000
# Street_paved_Pave                                      1.000000     1.000000
# Alley_No alley access                                  1.000000     1.000000
# Alley_Paved                                            0.000000     0.000000
# LandContour_Depression (upward slope on both si...     0.000000     0.000000
# LandContour_Hillside (downward slope on both si...     0.000000     0.000000
# LandContour_Level                                      1.000000     1.000000
# Utilities_EGWS                                         1.000000     1.000000
# LandSlope_Moderate-severe                              0.000000     0.000000
# Neighborhood_Blueste                                   0.000000     0.000000
# Neighborhood_BrDale                                    0.000000     0.000000
# Neighborhood_BrkSide                                   0.000000     0.000000
# Neighborhood_ClearCr                                   0.000000     0.000000
# Neighborhood_CollgCr                                   0.000000     0.000000
# Neighborhood_Crawfor                                   0.000000     0.000000
# Neighborhood_Edwards                                   0.000000     1.000000
# Neighborhood_Gilbert                                   0.000000     0.000000
# Neighborhood_Greens                                    0.000000     0.000000
# Neighborhood_GrnHill                                   0.000000     0.000000
# Neighborhood_IDOTRR                                    0.000000     0.000000
# Neighborhood_Landmrk                                   0.000000     0.000000
# Neighborhood_MeadowV                                   0.000000     0.000000
# Neighborhood_Mitchel                                   0.000000     0.000000
# Neighborhood_NAmes                                     0.000000     0.000000
# Neighborhood_NPkVill                                   0.000000     0.000000
# Neighborhood_NWAmes                                    0.000000     0.000000
# Neighborhood_NoRidge                                   0.000000     0.000000
# Neighborhood_NridgHt                                   0.000000     0.000000
# Neighborhood_OldTown                                   0.000000     0.000000
# Neighborhood_SWISU                                     1.000000     0.000000
# Neighborhood_Sawyer                                    0.000000     0.000000
# Neighborhood_SawyerW                                   0.000000     0.000000
# Neighborhood_Somerst                                   0.000000     0.000000
# Neighborhood_StoneBr                                   0.000000     0.000000
# Neighborhood_Timber                                    0.000000     0.000000
# Neighborhood_Veenker                                   0.000000     0.000000
# BldgType_2fmCon                                        0.000000     0.000000
# BldgType_Duplex                                        0.000000     0.000000
# BldgType_Twnhs                                         0.000000     0.000000
# BldgType_TwnhsE                                        0.000000     1.000000
# RoofStyle_Gable                                        1.000000     1.000000
# RoofStyle_Gabrel Barn                                  0.000000     0.000000
# RoofStyle_Hip                                          0.000000     0.000000
# RoofStyle_Mansard                                      0.000000     0.000000
# RoofStyle_Shed                                         0.000000     0.000000
# RoofMatl_Membrane                                      0.000000     0.000000
# RoofMatl_Metal                                         0.000000     0.000000
# RoofMatl_Roll                                          0.000000     0.000000
# RoofMatl_Standard (Composite) Shingle                  1.000000     1.000000
# RoofMatl_Wood Shakes                                   0.000000     0.000000
# RoofMatl_Wood Shingles                                 0.000000     0.000000
# MasVnrType_Brick Face                                  0.000000     1.000000
# MasVnrType_None                                        1.000000     0.000000
# MasVnrType_Stone                                       0.000000     0.000000
# Foundation_CBlock                                      1.000000     1.000000
# Foundation_PConc                                       0.000000     0.000000
# Foundation_Slab                                        0.000000     0.000000
# Foundation_Stone                                       0.000000     0.000000
# Foundation_Wood                                        0.000000     0.000000
# CentralAir_Y                                           1.000000     1.000000
# GarageFinish_No garage                                 0.000000     0.000000
# GarageFinish_RFn                                       0.000000     0.000000
# GarageFinish_Unf                                       1.000000     0.000000
# PavedDrive_Partial Pavement                            0.000000     0.000000
# PavedDrive_Paved                                       1.000000     1.000000
# Fence_Good Wood                                        0.000000     0.000000
# Fence_Minimum Privacy                                  0.000000     0.000000
# Fence_Minimum Wood/Wire                                0.000000     0.000000
# Fence_No Fence                                         1.000000     1.000000
# MiscFeature_Nothing                                    1.000000     1.000000
# MiscFeature_Other                                      0.000000     0.000000
# MiscFeature_Shed                                       0.000000     0.000000
# MiscFeature_Tennis Court                               0.000000     0.000000
# LotShape_com_Regular                                   1.000000     1.000000
# LotShape_com_Slightly irregular                        0.000000     0.000000
# MSZoning_com_Residential, high-density                 0.000000     0.000000
# MSZoning_com_Residential, low-density                  1.000000     1.000000
# MSZoning_com_Residential, medium-density               0.000000     0.000000
# MSZoning_com_Residential, village                      0.000000     0.000000
# Heating_com_Gas-powered water/steam heating            0.000000     0.000000
# Heating_com_Other                                      0.000000     0.000000
# Electrical_com_>60 Amp fuse box, all Romex wiring      0.000000     0.000000
# Electrical_com_Standard circuit breakers, all R...     1.000000     1.000000
# LotConfig_com_Corner lot                               1.000000     0.000000
# LotConfig_com_Cul-de-sac lot                           0.000000     0.000000
# LotConfig_com_Inside lot (1 side frontage)             0.000000     1.000000
# BsmtExposure_ord_1                                     1.000000     0.000000
# BsmtExposure_ord_2                                     0.000000     1.000000
# BsmtExposure_ord_3                                     0.000000     0.000000
# BsmtExposure_ord_4                                     0.000000     0.000000
# GarageType_com_Attached                                0.000000     1.000000
# GarageType_com_Basement                                0.000000     0.000000
# GarageType_com_BuiltIn                                 0.000000     0.000000
# GarageType_com_Detached                                1.000000     0.000000
# GarageType_com_No garage                               0.000000     0.000000
# attic_No attic                                         1.000000     1.000000
# attic_Unfinished                                       0.000000     0.000000
# PUD_1                                                  0.000000     1.000000
# Garage_age_bin_20-40                                   0.000000     1.000000
# Garage_age_bin_40-60                                   0.000000     0.000000
# Garage_age_bin_60+                                     1.000000     0.000000
# Garage_age_bin_No garage                               0.000000     0.000000
# Remod_age_bin_15-30                                    0.000000     0.000000
# Remod_age_bin_30-45                                    0.000000     0.000000
# Remod_age_bin_45+                                      1.000000     0.000000
# Remod_age_bin_No remodel                               0.000000     1.000000
# SaleType_CWD                                           0.000000     0.000000
# SaleType_Con                                           0.000000     0.000000
# SaleType_ConLD                                         0.000000     0.000000
# SaleType_ConLI                                         0.000000     0.000000
# SaleType_ConLw                                         0.000000     0.000000
# SaleType_New                                           0.000000     0.000000
# SaleType_Oth                                           0.000000     0.000000
# SaleType_VWD                                           0.000000     0.000000
# SaleType_WD                                            1.000000     1.000000
# SaleCondition_Partial                                  0.000000     0.000000
#
#                                                               2            3  \
# GrLivArea                                           1001.000000  1039.000000
# LotFrontage                                           60.000000    80.000000
# LotArea                                             6060.000000  8146.000000
# OverallQual                                            5.000000     4.000000
# OverallCond                                            9.000000     8.000000
# MasVnrArea                                             0.000000     0.000000
# ExterQual                                              4.000000     4.000000
# ExterCond                                              3.000000     4.000000
# BsmtUnfSF                                            100.000000   405.000000
# TotalBsmtSF                                          837.000000   405.000000
# 1stFlrSF                                            1001.000000   717.000000
# 2ndFlrSF                                               0.000000   322.000000
# LowQualFinSF                                           0.000000     0.000000
# BsmtFullBath                                           0.000000     0.000000
# BsmtHalfBath                                           0.000000     0.000000
# FullBath                                               1.000000     1.000000
# HalfBath                                               0.000000     0.000000
# BedroomAbvGr                                           2.000000     2.000000
# KitchenAbvGr                                           1.000000     1.000000
# KitchenQual                                            4.000000     3.000000
# TotRmsAbvGrd                                           5.000000     6.000000
# Fireplaces                                             0.000000     0.000000
# FireplaceQu                                            0.000000     0.000000
# GarageCars                                             1.000000     1.000000
# GarageArea                                           216.000000   281.000000
# GarageQual                                             3.000000     3.000000
# GarageCond                                             1.000000     3.000000
# WoodDeckSF                                           154.000000     0.000000
# OpenPorchSF                                            0.000000     0.000000
# EnclosedPorch                                         42.000000   168.000000
# 3SsnPorch                                             86.000000     0.000000
# ScreenPorch                                            0.000000   111.000000
# PoolArea                                               0.000000     0.000000
# PoolQC                                                 0.000000     0.000000
# MiscVal                                                0.000000     0.000000
# MoSold                                                11.000000     5.000000
# YrSold                                              2007.000000  2009.000000
# HeatingQC_ord                                          5.000000     4.000000
# LF_Near_NS_RR                                          0.000000     0.000000
# LF_Near_Positive_Feature                               0.000000     0.000000
# LF_Adjacent_Arterial_St                                0.000000     0.000000
# LF_Near_EW_RR                                          0.000000     0.000000
# LF_Adjacent_Feeder_St                                  0.000000     0.000000
# LotFrontage_log                                        4.094345     4.382027
# LotArea_log                                            3.782473     3.910944
# ext_Wood_Siding                                        0.000000     0.000000
# ext_Hard_Board                                         0.000000     0.000000
# ext_Metal_Siding                                       1.000000     1.000000
# ext_Vinyl_Siding                                       0.000000     0.000000
# ext_Wood_Shingles                                      0.000000     0.000000
# ext_Plywood                                            0.000000     0.000000
# ext_Stucco                                             0.000000     0.000000
# ext_Cement_Board                                       0.000000     0.000000
# ext_Face_Brick                                         0.000000     0.000000
# ext_Asbestos_Shingles                                  0.000000     0.000000
# ext_Common_Brick                                       0.000000     0.000000
# ext_Imitation_Stucco                                   0.000000     0.000000
# ext_Other                                              0.000000     0.000000
# BsmtCond_ord                                           3.000000     3.000000
# BsmtQual_ord                                           3.000000     2.000000
# BSMT_GLQ                                               0.000000     0.000000
# BSMT_ALQ                                             737.000000     0.000000
# BSMT_BLQ                                               0.000000     0.000000
# BSMT_LwQ                                               0.000000     0.000000
# BSMT_Rec                                               0.000000     0.000000
# number_floors                                          1.000000     2.000000
# Functional_ord                                         7.000000     7.000000
# 1stFlrSF_log                                           3.000434     2.855519
# 2ndFlrSF_log                                           0.000000     2.509203
# GrLivArea_log                                          3.000434     3.016616
# Garage_age_years                                      77.884932    69.378082
# house_age_years                                       77.884932   109.402740
# Remod_age_years                                        0.832877     6.334247
# Street_paved_Pave                                      1.000000     1.000000
# Alley_No alley access                                  1.000000     1.000000
# Alley_Paved                                            0.000000     0.000000
# LandContour_Depression (upward slope on both si...     0.000000     0.000000
# LandContour_Hillside (downward slope on both si...     0.000000     0.000000
# LandContour_Level                                      1.000000     1.000000
# Utilities_EGWS                                         1.000000     1.000000
# LandSlope_Moderate-severe                              0.000000     0.000000
# Neighborhood_Blueste                                   0.000000     0.000000
# Neighborhood_BrDale                                    0.000000     0.000000
# Neighborhood_BrkSide                                   0.000000     0.000000
# Neighborhood_ClearCr                                   0.000000     0.000000
# Neighborhood_CollgCr                                   0.000000     0.000000
# Neighborhood_Crawfor                                   0.000000     0.000000
# Neighborhood_Edwards                                   0.000000     0.000000
# Neighborhood_Gilbert                                   0.000000     0.000000
# Neighborhood_Greens                                    0.000000     0.000000
# Neighborhood_GrnHill                                   0.000000     0.000000
# Neighborhood_IDOTRR                                    1.000000     0.000000
# Neighborhood_Landmrk                                   0.000000     0.000000
# Neighborhood_MeadowV                                   0.000000     0.000000
# Neighborhood_Mitchel                                   0.000000     0.000000
# Neighborhood_NAmes                                     0.000000     0.000000
# Neighborhood_NPkVill                                   0.000000     0.000000
# Neighborhood_NWAmes                                    0.000000     0.000000
# Neighborhood_NoRidge                                   0.000000     0.000000
# Neighborhood_NridgHt                                   0.000000     0.000000
# Neighborhood_OldTown                                   0.000000     1.000000
# Neighborhood_SWISU                                     0.000000     0.000000
# Neighborhood_Sawyer                                    0.000000     0.000000
# Neighborhood_SawyerW                                   0.000000     0.000000
# Neighborhood_Somerst                                   0.000000     0.000000
# Neighborhood_StoneBr                                   0.000000     0.000000
# Neighborhood_Timber                                    0.000000     0.000000
# Neighborhood_Veenker                                   0.000000     0.000000
# BldgType_2fmCon                                        0.000000     0.000000
# BldgType_Duplex                                        0.000000     0.000000
# BldgType_Twnhs                                         0.000000     0.000000
# BldgType_TwnhsE                                        0.000000     0.000000
# RoofStyle_Gable                                        0.000000     1.000000
# RoofStyle_Gabrel Barn                                  0.000000     0.000000
# RoofStyle_Hip                                          1.000000     0.000000
# RoofStyle_Mansard                                      0.000000     0.000000
# RoofStyle_Shed                                         0.000000     0.000000
# RoofMatl_Membrane                                      0.000000     0.000000
# RoofMatl_Metal                                         0.000000     0.000000
# RoofMatl_Roll                                          0.000000     0.000000
# RoofMatl_Standard (Composite) Shingle                  1.000000     1.000000
# RoofMatl_Wood Shakes                                   0.000000     0.000000
# RoofMatl_Wood Shingles                                 0.000000     0.000000
# MasVnrType_Brick Face                                  0.000000     0.000000
# MasVnrType_None                                        1.000000     1.000000
# MasVnrType_Stone                                       0.000000     0.000000
# Foundation_CBlock                                      0.000000     0.000000
# Foundation_PConc                                       0.000000     0.000000
# Foundation_Slab                                        0.000000     0.000000
# Foundation_Stone                                       0.000000     0.000000
# Foundation_Wood                                        0.000000     0.000000
# CentralAir_Y                                           1.000000     1.000000
# GarageFinish_No garage                                 0.000000     0.000000
# GarageFinish_RFn                                       0.000000     0.000000
# GarageFinish_Unf                                       1.000000     1.000000
# PavedDrive_Partial Pavement                            0.000000     0.000000
# PavedDrive_Paved                                       0.000000     0.000000
# Fence_Good Wood                                        0.000000     0.000000
# Fence_Minimum Privacy                                  0.000000     0.000000
# Fence_Minimum Wood/Wire                                0.000000     0.000000
# Fence_No Fence                                         1.000000     1.000000
# MiscFeature_Nothing                                    1.000000     1.000000
# MiscFeature_Other                                      0.000000     0.000000
# MiscFeature_Shed                                       0.000000     0.000000
# MiscFeature_Tennis Court                               0.000000     0.000000
# LotShape_com_Regular                                   1.000000     1.000000
# LotShape_com_Slightly irregular                        0.000000     0.000000
# MSZoning_com_Residential, high-density                 0.000000     0.000000
# MSZoning_com_Residential, low-density                  0.000000     1.000000
# MSZoning_com_Residential, medium-density               0.000000     0.000000
# MSZoning_com_Residential, village                      0.000000     0.000000
# Heating_com_Gas-powered water/steam heating            0.000000     0.000000
# Heating_com_Other                                      0.000000     0.000000
# Electrical_com_>60 Amp fuse box, all Romex wiring      0.000000     0.000000
# Electrical_com_Standard circuit breakers, all R...     1.000000     1.000000
# LotConfig_com_Corner lot                               0.000000     1.000000
# LotConfig_com_Cul-de-sac lot                           0.000000     0.000000
# LotConfig_com_Inside lot (1 side frontage)             1.000000     0.000000
# BsmtExposure_ord_1                                     1.000000     1.000000
# BsmtExposure_ord_2                                     0.000000     0.000000
# BsmtExposure_ord_3                                     0.000000     0.000000
# BsmtExposure_ord_4                                     0.000000     0.000000
# GarageType_com_Attached                                0.000000     0.000000
# GarageType_com_Basement                                0.000000     0.000000
# GarageType_com_BuiltIn                                 0.000000     0.000000
# GarageType_com_Detached                                1.000000     1.000000
# GarageType_com_No garage                               0.000000     0.000000
# attic_No attic                                         1.000000     1.000000
# attic_Unfinished                                       0.000000     0.000000
# PUD_1                                                  0.000000     0.000000
# Garage_age_bin_20-40                                   0.000000     0.000000
# Garage_age_bin_40-60                                   0.000000     0.000000
# Garage_age_bin_60+                                     1.000000     1.000000
# Garage_age_bin_No garage                               0.000000     0.000000
# Remod_age_bin_15-30                                    0.000000     0.000000
# Remod_age_bin_30-45                                    0.000000     0.000000
# Remod_age_bin_45+                                      0.000000     0.000000
# Remod_age_bin_No remodel                               0.000000     0.000000
# SaleType_CWD                                           0.000000     0.000000
# SaleType_Con                                           0.000000     0.000000
# SaleType_ConLD                                         0.000000     0.000000
# SaleType_ConLI                                         0.000000     0.000000
# SaleType_ConLw                                         0.000000     0.000000
# SaleType_New                                           0.000000     0.000000
# SaleType_Oth                                           0.000000     0.000000
# SaleType_VWD                                           0.000000     0.000000
# SaleType_WD                                            1.000000     1.000000
# SaleCondition_Partial                                  0.000000     0.000000
#
#                                                               4
# GrLivArea                                           1665.000000
# LotFrontage                                           70.000000
# LotArea                                             8400.000000
# OverallQual                                            8.000000
# OverallCond                                            6.000000
# MasVnrArea                                             0.000000
# ExterQual                                              4.000000
# ExterCond                                              3.000000
# BsmtUnfSF                                            167.000000
# TotalBsmtSF                                          810.000000
# 1stFlrSF                                             810.000000
# 2ndFlrSF                                             855.000000
# LowQualFinSF                                           0.000000
# BsmtFullBath                                           1.000000
# BsmtHalfBath                                           0.000000
# FullBath                                               2.000000
# HalfBath                                               1.000000
# BedroomAbvGr                                           3.000000
# KitchenAbvGr                                           1.000000
# KitchenQual                                            4.000000
# TotRmsAbvGrd                                           6.000000
# Fireplaces                                             0.000000
# FireplaceQu                                            0.000000
# GarageCars                                             2.000000
# GarageArea                                           528.000000
# GarageQual                                             3.000000
# GarageCond                                             3.000000
# WoodDeckSF                                             0.000000
# OpenPorchSF                                           45.000000
# EnclosedPorch                                          0.000000
# 3SsnPorch                                              0.000000
# ScreenPorch                                            0.000000
# PoolArea                                               0.000000
# PoolQC                                                 0.000000
# MiscVal                                                0.000000
# MoSold                                                11.000000
# YrSold                                              2009.000000
# HeatingQC_ord                                          5.000000
# LF_Near_NS_RR                                          0.000000
# LF_Near_Positive_Feature                               0.000000
# LF_Adjacent_Arterial_St                                0.000000
# LF_Near_EW_RR                                          0.000000
# LF_Adjacent_Feeder_St                                  0.000000
# LotFrontage_log                                        4.248495
# LotArea_log                                            3.924279
# ext_Wood_Siding                                        0.000000
# ext_Hard_Board                                         0.000000
# ext_Metal_Siding                                       0.000000
# ext_Vinyl_Siding                                       1.000000
# ext_Wood_Shingles                                      0.000000
# ext_Plywood                                            0.000000
# ext_Stucco                                             0.000000
# ext_Cement_Board                                       0.000000
# ext_Face_Brick                                         0.000000
# ext_Asbestos_Shingles                                  0.000000
# ext_Common_Brick                                       0.000000
# ext_Imitation_Stucco                                   0.000000
# ext_Other                                              0.000000
# BsmtCond_ord                                           3.000000
# BsmtQual_ord                                           4.000000
# BSMT_GLQ                                             643.000000
# BSMT_ALQ                                               0.000000
# BSMT_BLQ                                               0.000000
# BSMT_LwQ                                               0.000000
# BSMT_Rec                                               0.000000
# number_floors                                          2.000000
# Functional_ord                                         7.000000
# 1stFlrSF_log                                           2.908485
# 2ndFlrSF_log                                           2.932474
# GrLivArea_log                                          3.221414
# Garage_age_years                                       8.838356
# house_age_years                                        8.838356
# Remod_age_years                                       -1.000000
# Street_paved_Pave                                      1.000000
# Alley_No alley access                                  1.000000
# Alley_Paved                                            0.000000
# LandContour_Depression (upward slope on both si...     0.000000
# LandContour_Hillside (downward slope on both si...     0.000000
# LandContour_Level                                      1.000000
# Utilities_EGWS                                         1.000000
# LandSlope_Moderate-severe                              0.000000
# Neighborhood_Blueste                                   0.000000
# Neighborhood_BrDale                                    0.000000
# Neighborhood_BrkSide                                   0.000000
# Neighborhood_ClearCr                                   0.000000
# Neighborhood_CollgCr                                   0.000000
# Neighborhood_Crawfor                                   0.000000
# Neighborhood_Edwards                                   0.000000
# Neighborhood_Gilbert                                   0.000000
# Neighborhood_Greens                                    0.000000
# Neighborhood_GrnHill                                   0.000000
# Neighborhood_IDOTRR                                    0.000000
# Neighborhood_Landmrk                                   0.000000
# Neighborhood_MeadowV                                   0.000000
# Neighborhood_Mitchel                                   0.000000
# Neighborhood_NAmes                                     0.000000
# Neighborhood_NPkVill                                   0.000000
# Neighborhood_NWAmes                                    1.000000
# Neighborhood_NoRidge                                   0.000000
# Neighborhood_NridgHt                                   0.000000
# Neighborhood_OldTown                                   0.000000
# Neighborhood_SWISU                                     0.000000
# Neighborhood_Sawyer                                    0.000000
# Neighborhood_SawyerW                                   0.000000
# Neighborhood_Somerst                                   0.000000
# Neighborhood_StoneBr                                   0.000000
# Neighborhood_Timber                                    0.000000
# Neighborhood_Veenker                                   0.000000
# BldgType_2fmCon                                        0.000000
# BldgType_Duplex                                        0.000000
# BldgType_Twnhs                                         0.000000
# BldgType_TwnhsE                                        0.000000
# RoofStyle_Gable                                        1.000000
# RoofStyle_Gabrel Barn                                  0.000000
# RoofStyle_Hip                                          0.000000
# RoofStyle_Mansard                                      0.000000
# RoofStyle_Shed                                         0.000000
# RoofMatl_Membrane                                      0.000000
# RoofMatl_Metal                                         0.000000
# RoofMatl_Roll                                          0.000000
# RoofMatl_Standard (Composite) Shingle                  1.000000
# RoofMatl_Wood Shakes                                   0.000000
# RoofMatl_Wood Shingles                                 0.000000
# MasVnrType_Brick Face                                  0.000000
# MasVnrType_None                                        1.000000
# MasVnrType_Stone                                       0.000000
# Foundation_CBlock                                      0.000000
# Foundation_PConc                                       1.000000
# Foundation_Slab                                        0.000000
# Foundation_Stone                                       0.000000
# Foundation_Wood                                        0.000000
# CentralAir_Y                                           1.000000
# GarageFinish_No garage                                 0.000000
# GarageFinish_RFn                                       0.000000
# GarageFinish_Unf                                       0.000000
# PavedDrive_Partial Pavement                            0.000000
# PavedDrive_Paved                                       1.000000
# Fence_Good Wood                                        0.000000
# Fence_Minimum Privacy                                  0.000000
# Fence_Minimum Wood/Wire                                0.000000
# Fence_No Fence                                         1.000000
# MiscFeature_Nothing                                    1.000000
# MiscFeature_Other                                      0.000000
# MiscFeature_Shed                                       0.000000
# MiscFeature_Tennis Court                               0.000000
# LotShape_com_Regular                                   1.000000
# LotShape_com_Slightly irregular                        0.000000
# MSZoning_com_Residential, high-density                 0.000000
# MSZoning_com_Residential, low-density                  1.000000
# MSZoning_com_Residential, medium-density               0.000000
# MSZoning_com_Residential, village                      0.000000
# Heating_com_Gas-powered water/steam heating            0.000000
# Heating_com_Other                                      0.000000
# Electrical_com_>60 Amp fuse box, all Romex wiring      0.000000
# Electrical_com_Standard circuit breakers, all R...     1.000000
# LotConfig_com_Corner lot                               0.000000
# LotConfig_com_Cul-de-sac lot                           0.000000
# LotConfig_com_Inside lot (1 side frontage)             1.000000
# BsmtExposure_ord_1                                     1.000000
# BsmtExposure_ord_2                                     0.000000
# BsmtExposure_ord_3                                     0.000000
# BsmtExposure_ord_4                                     0.000000
# GarageType_com_Attached                                1.000000
# GarageType_com_Basement                                0.000000
# GarageType_com_BuiltIn                                 0.000000
# GarageType_com_Detached                                0.000000
# GarageType_com_No garage                               0.000000
# attic_No attic                                         1.000000
# attic_Unfinished                                       0.000000
# PUD_1                                                  0.000000
# Garage_age_bin_20-40                                   0.000000
# Garage_age_bin_40-60                                   0.000000
# Garage_age_bin_60+                                     0.000000
# Garage_age_bin_No garage                               0.000000
# Remod_age_bin_15-30                                    0.000000
# Remod_age_bin_30-45                                    0.000000
# Remod_age_bin_45+                                      0.000000
# Remod_age_bin_No remodel                               1.000000
# SaleType_CWD                                           0.000000
# SaleType_Con                                           0.000000
# SaleType_ConLD                                         0.000000
# SaleType_ConLI                                         0.000000
# SaleType_ConLw                                         0.000000
# SaleType_New                                           0.000000
# SaleType_Oth                                           0.000000
# SaleType_VWD                                           0.000000
# SaleType_WD                                            1.000000
# SaleCondition_Partial                                  0.000000

# %%
from sklearn import ensemble
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

#randomForest = ensemble.RandomForestClassifier()
model = ensemble.RandomForestRegressor()

x_train, x_test, y_train, y_test = train_test_split(df3, price, test_size=0.3)

# %%
model.set_params(min_samples_leaf=2,min_samples_split=2,max_features=50,n_estimators=3000)
model.fit(x_train,y_train)
print(model.score(x_train, y_train))
print(model.score(x_test, y_test))
features_importance=pd.DataFrame({'Features':x_train.columns,'Score':model.feature_importances_}).sort_values('Score')
# Out:
# 0.9765539680776146
# 0.8986533866354087

# %%
features_filtered=features_importance[features_importance['Score']<0.000354]

alwaysdrop = ['PID', 'SalePrice', 'SalePrice_log', 'SalePrice_adj', 'SalePrice_adj_log', 'sold_datetime']

droplist = list(features_filtered['Features']) + alwaysdrop
price = df['SalePrice']

avg_price_df=pd.read_csv('../data/house_surrounding_avg_prices.csv')
avg_price_df2=avg_price_df[['PID','AvgPrice-0.25']].drop_duplicates() #,'AvgPrice-0.5'
df3=df.merge(avg_price_df2,how='left')
df3=df3.merge(feature_df, how='left')

df3 = df3.drop(droplist, axis = 1) #+ droplist
df3=df3.fillna(0)
df3.shape

# %%
# Out:
# (2495, 208)

# %%
# grid_para_tree = [{
#     "min_samples_leaf": range(3, 10),
#     "min_samples_split": np.linspace(start=5, stop=20, num=5, dtype=int),
#     "n_estimators": [300],
#     "max_features":[30,35,40,45,50,55,60] #'auto', 'sqrt', 'log2', 5, 10, ,70,100,150
# }]

# grid_search_tree = GridSearchCV(
#     model, grid_para_tree, cv=5, n_jobs=-1)

# %time grid_search_tree.fit(x_train, y_train)
# print(grid_search_tree.score(x_train, y_train))
# print(grid_search_tree.score(x_test, y_test))
# grid_search_tree.best_params_
# #grid_search_tree.cv_results_['mean_test_score']

# %%
model3 = ensemble.RandomForestRegressor()

x_train, x_test, y_train, y_test = train_test_split(df3, price, test_size=0.3)

model3.set_params(min_samples_leaf=3,min_samples_split=3,max_features=50,n_estimators=3000)
model3.fit(x_train,y_train)
print("-"*50)
print(model3.score(x_train, y_train))
print(model3.score(x_test, y_test))
print("-"*50)
# Out:
# --------------------------------------------------
# 0.9733309399452857
# 0.9015840434010829
# --------------------------------------------------

# %%
features_filtered=features_importance[features_importance['Score']<0.000354]


feature_df=pd.read_csv('../data/house_coordinates_1.0.csv')
feature_df=feature_df.drop(['Address','Coords4','latitude','longitude'],axis=1)

features_importance2=pd.DataFrame({'Features':x_train.columns,'Score':model3.feature_importances_}).sort_values('Score')

features_filtered2=features_importance[features_importance['Score']<0.0001]


alwaysdrop = ['PID', 'SalePrice', 'SalePrice_log', 'SalePrice_adj', 'SalePrice_adj_log', 'sold_datetime']

droplist = list(features_filtered['Features']) + alwaysdrop
price = df['SalePrice']

avg_price_df=pd.read_csv('../data/house_surrounding_avg_prices.csv')
avg_price_df2=avg_price_df[['PID','AvgPrice-0.25']].drop_duplicates() #,'AvgPrice-0.5'
df3=df.merge(avg_price_df2,how='left')
df3=df3.merge(feature_df, how='left')

df3 = df3.drop(droplist, axis = 1) #+ droplist
df3=df3.fillna(0)
df3.shape
# Out:
# CPU times: user 6.29 s, sys: 684 ms, total: 6.98 s
# Wall time: 7min 25s
# 0.9684912914952565
# 0.9177168623256049
# {'max_features': 50,
#  'min_samples_leaf': 3,
#  'min_samples_split': 5,
#  'n_estimators': 300}

# %%
grid_search_tree.best_params_
# Out:
# {'max_features': 50,
#  'min_samples_leaf': 3,
#  'min_samples_split': 5,
#  'n_estimators': 300}

# %%
# Out:
#                                               Features     Score
# 170                                         4141_beach  0.000000
# 117                                       2510_general  0.000000
# 112                                     2422_camp_site  0.000000
# 176                                   5209_street_lamp  0.000000
# 200                                      7216_vineyard  0.000000
# 109                                         2402_motel  0.000000
# 168                                        4101_spring  0.000000
# 159                              2961_wastewater_plant  0.000000
# 81                                      2008_town_hall  0.000000
# 187                                       5655_helipad  0.000000
# 148                                   2741_picnic_site  0.000000
# 137                                 2547_garden_centre  0.000005
# 183                                           5311_dam  0.000005
# 199                                       7215_orchard  0.000005
# 95                                       2206_dog_park  0.000008
# 188                                         5656_apron  0.000008
# 100                                       2256_stadium  0.000010
# 186                                       5651_airport  0.000011
# 160                                   2964_water_works  0.000011
# 128                                    2523_stationery  0.000011
# 162                            3102_christian_catholic  0.000020
# 107                                    2306_food_court  0.000021
# 154                                  2906_waste_basket  0.000021
# 132                                2541_car_dealership  0.000023
# 110                                    2404_guesthouse  0.000024
# 182                                          5303_pier  0.000025
# 136                                 2546_computer_shop  0.000026
# 144                                    2721_attraction  0.000027
# 181                                       5301_slipway  0.000034
# 135                                2544_furniture_shop  0.000035
# 80                                        2007_library  0.000038
# 172                                          5203_stop  0.000043
# 184                                          5332_weir  0.000043
# 194                                        7208_meadow  0.000050
# 92                                         2203_cinema  0.000056
# 115                                          2504_mall  0.000057
# 90                                     2129_veterinary  0.000059
# 121                                      2515_bookshop  0.000062
# 133                                  2542_bicycle_shop  0.000064
# 123                                     2518_beverages  0.000066
# 166                                        3200_jewish  0.000067
# 143                                  2701_tourist_info  0.000068
# 87                                       2110_hospital  0.000070
# 198                                        7212_retail  0.000071
# 163                         3103_christian_evangelical  0.000073
# 50                                Neighborhood_Crawfor  0.000078
# 126                                     2521_gift_shop  0.000079
# 105                                           2304_pub  0.000082
# 114                                        2502_bakery  0.000085
# 131                                   2529_beauty_shop  0.000089
# 76                                         2001_police  0.000091
# 84                                     2081_university  0.000092
# 91                                        2201_theatre  0.000092
# 125                                      2520_jeweller  0.000098
# 53                                Neighborhood_NridgHt  0.000102
# 120                                       2513_florist  0.000103
# 89                                        2121_dentist  0.000103
# 82                                   2013_nursing_home  0.000103
# 134                                  2543_doityourself  0.000106
# 129                                  2524_outdoor_shop  0.000110
# 127                                   2522_sports_shop  0.000113
# 51                                Neighborhood_Edwards  0.000116
# 77                                   2002_fire_station  0.000117
# 167                                        3300_muslim  0.000118
# 156                                         2950_tower  0.000121
# 122                                     2517_shoe_shop  0.000121
# 130                             2525_mobile_phone_shop  0.000131
# 179                           5262_parking_multistorey  0.000138
# 157                                   2951_comms_tower  0.000145
# 119                                       2512_clothes  0.000151
# 145                                        2722_museum  0.000151
# 78                                       2004_post_box  0.000156
# 140                                       2568_laundry  0.000159
# 206                                     8201_reservoir  0.000163
# 192                                    7204_industrial  0.000164
# 197                             7211_recreation_ground  0.000170
# 165                           3105_christian_methodist  0.000177
# 79                                    2005_post_office  0.000181
# 108                                         2401_hotel  0.000184
# 83                                      2015_graveyard  0.000185
# 99                                    2255_golf_course  0.000188
# 155                           2907_camera_surveillance  0.000188
# 47   LandContour_Depression (upward slope on both s...  0.000192
# 142                                           2602_atm  0.000193
# 196                                7210_nature_reserve  0.000201
# 150                                        2901_toilet  0.000201
# 193                                      7206_cemetery  0.000207
# 124                                      2519_optician  0.000208
# 174                             5206_motorway_junction  0.000216
# 61                                    GarageFinish_RFn  0.000219
# 40                                      Functional_ord  0.000219
# 49                           LandSlope_Moderate-severe  0.000221
# 58                                   Foundation_CBlock  0.000224
# 68          LotConfig_com_Inside lot (1 side frontage)  0.000229
# 52                                Neighborhood_NoRidge  0.000233
# 57                                    MasVnrType_Stone  0.000235
# 116                              2505_department_store  0.000242
# 48                                   LandContour_Level  0.000242
# 62                                    GarageFinish_Unf  0.000255
# 64                                LotShape_com_Regular  0.000261
# 65                     LotShape_com_Slightly irregular  0.000263
# 139                                      2564_car_wash  0.000266
# 88                                        2120_doctors  0.000267
# 149                                     2742_viewpoint  0.000280
# 104                                          2303_cafe  0.000280
# 74                            Remod_age_bin_No remodel  0.000281
# 138                                   2561_hairdresser  0.000281
# 207                                       8221_wetland  0.000286
# 26                                       EnclosedPorch  0.000292
# 96                                  2251_sports_centre  0.000293
# 152                                2903_drinking_water  0.000296
# 38                                            BSMT_Rec  0.000300
# 56                               MasVnrType_Brick Face  0.000304
# 67            MSZoning_com_Residential, medium-density  0.000311
# 118                                   2511_convenience  0.000311
# 101                                         2258_track  0.000312
# 39                                       number_floors  0.000317
# 55                                       RoofStyle_Hip  0.000326
# 106                                           2305_bar  0.000332
# 33                                    ext_Vinyl_Siding  0.000345
# 73                                   Remod_age_bin_45+  0.000352
# 158                                   2952_water_tower  0.000362
# 54                                     RoofStyle_Gable  0.000374
# 85                                         2082_school  0.000401
# 63                                    PavedDrive_Paved  0.000411
# 22                                          GarageQual  0.000449
# 66               MSZoning_com_Residential, low-density  0.000470
# 86                                       2101_pharmacy  0.000474
# 113                                   2501_supermarket  0.000487
# 190                                          7202_park  0.000503
# 69                                  BsmtExposure_ord_1  0.000525
# 203                                      7228_farmyard  0.000535
# 164                            3104_christian_lutheran  0.000535
# 93                                           2204_park  0.000538
# 15                                        KitchenAbvGr  0.000544
# 71                             GarageType_com_Attached  0.000551
# 177                                          5250_fuel  0.000563
# 153                                      2904_fountain  0.000609
# 72                             GarageType_com_Detached  0.000635
# 23                                          GarageCond  0.000644
# 34                                        BsmtCond_ord  0.000647
# 59                                    Foundation_PConc  0.000656
# 147                                       2725_artwork  0.000702
# 13                                            HalfBath  0.000710
# 98                                  2253_swimming_pool  0.000720
# 151                                         2902_bench  0.000743
# 111                                       2421_shelter  0.000749
# 161                                     3100_christian  0.000764
# 141                                          2601_bank  0.000783
# 146                                      2724_memorial  0.000793
# 37                                            BSMT_ALQ  0.000806
# 169                                          4121_tree  0.000814
# 30                                       HeatingQC_ord  0.000828
# 195                                    7209_commercial  0.000832
# 94                                     2205_playground  0.000862
# 29                                              YrSold  0.000896
# 180                               5270_parking_bicycle  0.000968
# 102                                    2301_restaurant  0.000977
# 70                                  BsmtExposure_ord_4  0.000991
# 171                               5201_traffic_signals  0.001015
# 201                                         7217_scrub  0.001047
# 97                                          2252_pitch  0.001149
# 27                                         ScreenPorch  0.001188
# 14                                        BedroomAbvGr  0.001197
# 204                                      7229_farmland  0.001254
# 189                                        7201_forest  0.001271
# 175                                5207_turning_circle  0.001293
# 103                                     2302_fast_food  0.001356
# 185                                      5621_bus_stop  0.001496
# 178                                       5260_parking  0.001572
# 205                                         8200_water  0.001714
# 60                                        CentralAir_Y  0.001866
# 202                                         7218_grass  0.001909
# 46                                     Remod_age_years  0.001949
# 17                                        TotRmsAbvGrd  0.002067
# 11                                        BsmtFullBath  0.002076
# 191                                   7203_residential  0.002164
# 28                                              MoSold  0.002225
# 4                                          OverallCond  0.002310
# 31                                     LotFrontage_log  0.002380
# 1                                          LotFrontage  0.002404
# 24                                          WoodDeckSF  0.002872
# 25                                         OpenPorchSF  0.002878
# 173                                      5204_crossing  0.002913
# 44                                    Garage_age_years  0.003237
# 7                                            BsmtUnfSF  0.003744
# 18                                          Fireplaces  0.003746
# 19                                         FireplaceQu  0.004117
# 2                                              LotArea  0.006518
# 32                                         LotArea_log  0.006570
# 12                                            FullBath  0.007362
# 42                                        2ndFlrSF_log  0.008105
# 10                                            2ndFlrSF  0.008232
# 5                                           MasVnrArea  0.010361
# 16                                         KitchenQual  0.013622
# 35                                        BsmtQual_ord  0.016183
# 36                                            BSMT_GLQ  0.021304
# 45                                     house_age_years  0.022969
# 41                                        1stFlrSF_log  0.029118
# 21                                          GarageArea  0.029144
# 9                                             1stFlrSF  0.029404
# 8                                          TotalBsmtSF  0.036175
# 6                                            ExterQual  0.042546
# 20                                          GarageCars  0.053517
# 0                                            GrLivArea  0.078452
# 43                                       GrLivArea_log  0.078754
# 75                                       AvgPrice-0.25  0.161875
# 3                                          OverallQual  0.238271

# %%
model2 = ensemble.RandomForestRegressor()

x_train, x_test, y_train, y_test = train_test_split(df3, price, test_size=0.3)
feat=int(len(df3.columns)/3)
model2.set_params(min_samples_leaf=2,min_samples_split=2,max_features=feat,n_estimators=3000)
model2.fit(x_train,y_train)
print("-"*50)
print(model2.score(x_train, y_train))
print(model2.score(x_test, y_test))
print("-"*50)
# Out:
# --------------------------------------------------
# 0.9758587204462502
# 0.9210692714530684
# --------------------------------------------------

# %%
grid_para_tree = [{
    "min_samples_leaf": range(3, 10),
    "min_samples_split": np.linspace(start=5, stop=20, num=5, dtype=int),
    "n_estimators": [300],
    "max_features":[30,35,40,45,50,55,60] #'auto', 'sqrt', 'log2', 5, 10, ,70,100,150
}]

grid_search_tree = GridSearchCV(
    model, grid_para_tree, cv=5, n_jobs=-1)

# %time grid_search_tree.fit(x_train, y_train)
print(grid_search_tree.score(x_train, y_train))
print(grid_search_tree.score(x_test, y_test))
grid_search_tree.best_params_
#grid_search_tree.cv_results_['mean_test_score']
# Out:
# CPU times: user 4.5 s, sys: 538 ms, total: 5.04 s
# Wall time: 3min 6s
# 0.9658030781619812
# 0.9165626755107035
# {'max_features': 35,
#  'min_samples_leaf': 3,
#  'min_samples_split': 2,
#  'n_estimators': 300}

# %%
0.9660492504801086
0.9188001671125462
